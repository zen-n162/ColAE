# %% [markdown]
# # Collaborative Superpixelwise Autoencoderの実装
#
# **[書誌情報]**
# - タイトル
#     - A Collaborative Superpixelwise Autoencoder for Unsupervised Dimension Deduction in Hyperspectral Images
# - 著者
#     - Chao Yao, Lingfeng Zheng, Longchao Feng, Fan Yang, Zehua Guo, Miao Ma
# - 出版
#     - Received: 21 July 2023 / Revised: 23 August 2023 / Accepted: 24 August 2023 / Published: 27 August 2023
# - DOI: https://doi.org/10.3390/rs15174211
#
# **[Abstract]**
# - [論文紹介スライド](https://drive.google.com/file/d/1nj9pMiVVg5Q-G_UObhXD0QsFzxGZKAlV/view?usp=sharing)
# - Superpixel-based approaches
#     - サンプルをグループに分け、小さなグループにDR(Dimension Reduction)技術を適応
#     - 良い点
#         - HSIデータの**スペクトル空間情報**を柔軟に扱うことができる
#     - 課題
#         - 同じクラスからのサンプルが異なるSuperpixelに存在する可能性があるという事実を無視することにより、クラス内格差を増加させ、結果的に性能を低下させることがわかった
# - Collaborative superpixelwise Auto-Encoder (**ColAE**)
#     - クラス内格差を低減するため、たとえ異なるsuperpixelに位置するとしても、同じクラスからのサンプルが符号空間（code空間）において同様の表現を持つように制限する**多様体損失**を導入する
#
# **[実装の概要]**
# - HSIデータの読み込み
# - ColAEの実装
# 1. Superpixel segmentation with ERS
#
#  1.1. PCA
#
#  1.2. ERS -> SLIC
#
# 2. Collaborative AEs
#
#  2.1. LLE
#
#  2.2. パラメータを $\Theta^{(0)}$ に初期化
#
#  2.3. AEの損失関数と多様体損失関数の２つの損失関数を計算し、即時のoptimizerを用いて $g^(t)$ の勾配を計算し、$\Theta^{(t+1)} = \Theta^(t) + \alpha g^(t) $ でパラメータを更新
#
#  2.4. $\Theta^(t)$ によって符号空間を計算し、 $Y \in \mathbb{R}^{L \times W \times H}$ を再形成する

# %% [markdown]
# #### Pyhton version -----

# %%
# !sudo apt install python3.7
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.7 1
# !sudo update-alternatives --config python3

# %% [markdown]
# #### ----------

# %% [markdown]
# ## HSIデータの読み込み
#
# [HISUI](https://www.jspacesystems.or.jp/project/observation/hisui/)のデータを[Tellus](https://www.tellusxdp.com/ja/catalog/data/hisui.html)からダウンロードして使用
#
# [使用したデータのダウンロード先リンク](https://www.tellusxdp.com/traveler/viewer/?q=%257B%2522center%2522%253A%255B139.67269389063912%252C35.62839714641322%255D%252C%2522zoom%2522%253A10.828120584428342%252C%2522searchMapState%2522%253A%257B%2522nameState%2522%253A%257B%2522name%2522%253A%2522%2522%252C%2522mode%2522%253Anull%257D%252C%2522observationDateRange%2522%253A%257B%2522start%2522%253Anull%252C%2522end%2522%253Anull%252C%2522active%2522%253Afalse%257D%252C%2522publishedDateRange%2522%253A%257B%2522start%2522%253Anull%252C%2522end%2522%253Anull%252C%2522active%2522%253Afalse%257D%252C%2522aoiState%2522%253A%257B%2522geometry%2522%253A%257B%2522type%2522%253A%2522Polygon%2522%252C%2522coordinates%2522%253A%255B%255B%255B127.16499790831209%252C5.308236535699957%255D%252C%255B168.8696729544158%252C5.308236535699957%255D%252C%255B168.8696729544158%252C44.85495239409777%255D%252C%255B127.16499790831209%252C44.85495239409777%255D%252C%255B127.16499790831209%252C5.308236535699957%255D%255D%255D%257D%252C%2522mode%2522%253A%2522intersect%2522%257D%252C%2522condition%2522%253A%257B%2522dataset%2522%253A%255B%252268f7270f-414f-4587-aaee-01389678d425%2522%252C%2522f1979af1-7585-4251-8225-965d61b4373a%2522%255D%252C%2522properties%2522%253A%257B%257D%252C%2522datasetsType%2522%253A%2522public%2522%257D%252C%2522order%2522%253A%257B%2522field%2522%253A%2522properties.end_datetime%2522%252C%2522direction%2522%253A%2522desc%2522%257D%252C%2522onlyDownloadableFile%2522%253A%257B%2522active%2522%253Afalse%252C%2522value%2522%253Afalse%257D%252C%2522scene%2522%253A%2522detail%2522%252C%2522consoleOpened%2522%253Atrue%252C%2522selectedData%2522%253A%257B%2522dataset%2522%253A%252268f7270f-414f-4587-aaee-01389678d425%2522%252C%2522data%2522%253A%2522bcbda156-8ee9-49db-947b-782f221496b0%2522%257D%257D%257D) (ログインが必要)

# %% [markdown]
# ### データの読み込み

# %%
import numpy as np
import os
import glob
import cv2
from osgeo import gdal
import matplotlib.pyplot as plt
import torch
import time

from livelossplot import PlotLosses

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f'device: {device}')

# 波長順にsort
import re
def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

# ファイルの読み込み
data_name = 'Port'
files = sorted(glob.glob('../Dataset/HISUI/'+data_name+'/*.tif'), key=natural_keys)
print(f'len: {len(files)}')

datas = []
for i, file in enumerate(files):
    # 画像読み込み
    data = cv2.imread(file, cv2.IMREAD_GRAYSCALE)

    data_expanded = np.expand_dims(data, axis=0)
    datas.append(data_expanded)

imgs = np.concatenate(datas, axis=0)
imgs = imgs.astype(np.float32)/255.
#imgs = np.array(imgs.ReadAsArray(), np.float32) # [0~1]にスケーリング正規化かつfloat64->float32へ変換
band_size = imgs.shape[0] # band number
print(f'dtype: {imgs.dtype}, shape: {imgs.shape}, min: {np.min(imgs)}, max: {np.max(imgs)}')
plt.imshow(imgs[0], cmap='gray')
# Out:
# device: cuda:0
# len: 181
# dtype: float32, shape: (181, 501, 501), min: 0.0, max: 1.0

# %%
# file_path = '/content/drive/MyDrive/Intern/Intern_S2023/ColAE/HSI_data_inTokyo'
# format = 'tif'
# print(file_path+'/*.'+format)

# %%
# im = cv2.imread('/content/drive/MyDrive/Intern/Intern_S2023/ColAE/imgs_ers_input.jpg')
# im = im.transpose(2, 0, 1)
# print(len(im))
# print(f'{len(im[0])}x{len(im[0][0])}')

# %%
# print(imgs.dtype)

# %%
# #--nChannel
# %cd

# %%
# %cd '/content/drive/MyDrive/Intern/Intern_S2023/ColAE'
# #!git clone https://github.com/kanezaki/pytorch-unsupervised-segmentation.git
# %cd 'pytorch-unsupervised-segmentation'
# !ls

# %%
# band_num = len(imgs)

# %%
# print(type(band_num))

# %%
# !python demo.py --input file_path --nChannel 180 --format tif --mode origin

# %% [markdown]
# ## 1. Superpixel segmentation with ERS

# %% [markdown]
# ### 1.1 Principal Componet Analysis (PCA)

# %%
# 画像をバンドごとに平坦化
# 波長 82 band
imgs_pca_input = imgs.reshape(band_size, -1).transpose()

print(imgs_pca_input.shape)
# Out:
# (251001, 181)

# %%
# 画像180x1794x1891（band, h, w）にPCAを適用
from sklearn.decomposition import PCA

# chanel: 82　->　3（主成分）
pca = PCA(3)
imgs_pca_output = pca.fit_transform(imgs_pca_input)

imgs_pca_output.shape
# Out:
# (251001, 3)

# %% [markdown]
# #### 表示

# %%
# plt.style.use('seaborn-whitegrid')
# fig = plt.figure(figsize = (10,6))
# ax = fig.add_subplot(1,1,1,projection='3d')
# ax.set_xlabel('PC_1')
# ax.set_ylabel('PC_2')
# ax.set_zlabel('PC_3')
# c_map = plt.cm.get_cmap('jet', 10)
# mappable = ax.scatter(imgs_pca_output[:, 0], imgs_pca_output[:, 1], imgs_pca_output[:, 2], s = 15, cmap = c_map, marker='.')
# fig.colorbar(mappable, ax=ax)
# plt.show()

# %% [markdown]
# ### 1.2 Entropy Rate Superpixel Segmentation (ERS)
#
# ERSを用いて、Superpixel Segmentaionを作成
#
# GitHub: https://github.com/mingyuliutw/EntropyRateSuperpixel
#
# [ERSを採用する理由]
# - HSI分類タスクにおいての有望な性能が示されている
#
#  1. Jiang+ (2018): [A superpixelwise PCA approach for unsupervised feature extraction of hyperspectral imagery](https://doi.org/10.1109/TGRS.2018.2828029)
#
#  → 前処理プロセスとして用いるため計算量を少なくする必要がある。（具体的に、他の手法と比較してどれだけ計算量が少なく、かつどれだけの性能なのか調べる必要がある。）
#  2. Zhang+ (2022): [Spectral-spatial and superpixelwise PCA for unspervised feature extraction of hyperspectral imaagery](https://doi.org/10.1109/TGRS.2021.3057701)
#
#
# - 適用的領域生成とテクスチャ保存における固有の能力がある
#
# \\
# また今後として、マルチスケールスーパーピクセルに拡張でき、精度向上が期待できる。

# %%
# # Githubからclone
# %cd /content/drive/MyDrive/Intern/Intern_S2023/ColAE
# !pwd
# !ls
# #!git clone https://github.com/mingyuliutw/EntropyRateSuperpixel.git
# %cd '/content/drive/MyDrive/Intern/Intern_S2023/ColAE/EntropyRateSuperpixel/'

# %%
# # PCAによって180から3chanelにした擬似カラー画像
# imgs_ers_input = imgs_pca_output.reshape(imgs.shape[1], imgs.shape[2], -1)
# print(imgs_ers_input.shape)
# plt.imshow(imgs_ers_input)

# # Matlab に読み込むように保存
# imgs_ers_input_path = '/content/drive/MyDrive/Intern/Intern_S2023/ColAE/imgs_ers_input.jpg'

# # BGR to RGB
# imgs_ers_input_rgb = imgs_ers_input[:, :, [2, 1, 0]]
# cv2.imwrite(imgs_ers_input_path, imgs_ers_input_rgb, [cv2.IMWRITE_JPEG_QUALITY, 100])

# %%
# imgs_ers_input_path = '/content/drive/MyDrive/Intern/Intern_S2023/ColAE/imgs_ers_input.jpg'
# tmp = cv2.imread(imgs_ers_input_path)
# # BGR to RGB
# tmp_rgb = tmp[:, :, [2, 1, 0]]
# plt.imshow(tmp_rgb)

# %% [markdown]
# #### ERSのGitHubコードがMATLABで使えそうなので、MATLABで作成したSuperpixel Segementaion by using ERSを読み込む

# %%
# !ls

# %% [markdown]
# Python3のバージョンによる以下のようなエラーが発生するための解決する方法の提供先
#
# ModuleNotFoundError: No module named 'erspy'
#
# GitHub: https://github.com/aniku777tw/ERS-EntropyRateSuperpixel

# %%
# %cd /content/drive/MyDrive/Intern/Intern_S2023/ColAE
# !pwd
# !ls
# #!git clone https://github.com/aniku777tw/ERS-EntropyRateSuperpixel.git
# %cd '/content/drive/MyDrive/Intern/Intern_S2023/ColAE/ERS-EntropyRateSuperpixel'

# %%
# !python --version

# %%
# %cd ERS_Python
# !ls

# %%
# !python compile_cpp.py build

# %%
# %cd ..
# !ls

# %%
# !python demoERS.py

# %%
# from ERSModule import *
# import cv2
# import numpy as np

# def colormap(input,colors):
# 	height = input.shape[0]
# 	width  = input.shape[1]
# 	output = np.zeros([height,width,3],np.uint8)
# 	for y in range(0,height):
# 		for x in range(0,width):
# 			id = int(input[y,x])
# 			for k in range(0,3):
# 				output[y,x,k] = colors[id,k]
# 	return output

# nC = 100

# # BGR to RGB
# imgs_ers_input_rgb = imgs_ers_input[:, :, [2, 1, 0]]
# #grayImg = cv2.cvtColor(imgs_ers_input_rgb,cv2.COLOR_BGR2GRAY)
# # print grayImg.shape
# seg = ERS()
# segmentation = seg.ComputeSegmentation(np.uint8(imgs_ers_input_rgb), nC)[0]

# colors = np.uint8(np.random.rand(nC,3)*255)
# output = colormap(segmentation,colors)
# cv2.imshow("img", imgs_ers_input_rgb)
# cv2.imshow("segmentation",output)
# cv2.waitKey()
# cv2.destroyAllWindows()

# %% [markdown]
# ### 1.2 Simple Linear Iterative Clustering (SLIC) （ERSの代わり）
#
# SLICを用いて、Superpixel Segmentaionを実施
#
# Stutz+ (2016)が推奨しているSuperpixel Segmentaion手法の１つ
#
# scikit-imageやOpenCVで実装が公開されている
#
# [利用例]
# - アノテーションの効率化

# %%
# PCAによって180から3chanelにした擬似カラー画像
imgs_slic_input = imgs_pca_output.reshape(imgs.shape[1], imgs.shape[2], -1)

# BGR to RGB
#imgs_slic_input_rgb = imgs_slic_input[:, :, [2, 1, 0]]
imgs_slic_input_rgb = imgs_slic_input

print(imgs_slic_input_rgb.shape)
plt.imshow(imgs_slic_input_rgb)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (501, 501, 3)

# %%
# Superpixel Segmentaion のパラメータ
height, width, channels = imgs_slic_input.shape[:3]
region_size = 23
ruler = 5
min_element_size = 18
num_iterations = 10  # 反復回数

# 64ビットから32ビットへの変換
imgs_slic_input_32f = np.float32(imgs_slic_input_rgb)
imgs_slic_input_hsv = cv2.cvtColor(imgs_slic_input_32f, cv2.COLOR_BGR2HSV)

slic = cv2.ximgproc.createSuperpixelSLIC(imgs_slic_input_hsv, cv2.ximgproc.SLIC, region_size, float(ruler))

# 画像のスーパーピクセルセグメンテーションを計算
# 入力画像は,HSVまたはL*a*b*
slic.iterate(num_iterations)
slic.enforceLabelConnectivity(min_element_size);

labels = slic.getLabels()

# スーパーピクセルセグメンテーションの境界を取得
contour_mask = slic.getLabelContourMask(False)
imgs_slic_output = imgs_slic_input_rgb.copy()
imgs_slic_output[0 < contour_mask] = (255, 255, 0)

# セグメンテーション数の取得
# ColAE論文中の J (nseg) にあたる（Jが100前後の時が性能が良い）
# 論文中のDataset（Indian: 145x145, UoPavia: 610x340, Salinas: 512x217）
## と比較して今回のデータは　1640x998　と3倍ほど大きいので J も少し大きい値でもいいか？
J = slic.getNumberOfSuperpixels()

lbavgimg = np.zeros((height, width, channels), dtype=np.uint8)
meanimg = np.zeros((J, channels+1), dtype=np.float32)

# 画像表示
print(f'J (nSeg) = {J}')
plt.imshow(imgs_slic_output)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# J (nSeg) = 435

# %% [markdown]
# ## 2. Collaborative AEs

# %% [markdown]
# ### セグメンテーションごとにベクトルを作成
#
# $$
# X = ({X^1, X^2, ..., X^J})
# $$
#
# , where
# $$
# X^i = ({X_1}^i, {X_2}^i, ..., {X_{N_i}}^i)
# $$
# $$X^i \in \mathbb{R}^{B \times {N_i}}$$
#
# $N_i$ : i番目のSuperpixelのサンプル数

# %%
print(f'size: {labels.shape}')
print(f'画像pixelごとのseglabel: {labels}')
# Out:
# size: (501, 501)
# 画像pixelごとのseglabel: [[  0   0   0 ...  19  19  19]
#  [ 20  20  20 ...  19  19  19]
#  [ 20  20  20 ...  19  19  19]
#  ...
#  [418 418 418 ... 433 433 433]
#  [418 418 418 ... 433 433 433]
#  [418 418 418 ... 433 433 433]]

# %%
band_num, height, width = imgs.shape[:3]

# ベクトル N_j x 波長180

# セグメンテーション毎のベクトル X_i 作成 (J, N_j, B)
class_data = [[] for _ in range(J)]
save_pixel_index = [[] for _ in range(J)]

# ピクセルごとにクラスごとのデータを追加
for y in range(height):
    for x in range(width):
        class_idx = labels[y, x]  # クラスを取得
        pixel_data = imgs[:, y, x]  # 長さがBの一次元配列を生成（仮のデータ）
        class_data[class_idx].append(pixel_data)
        save_pixel_index[class_idx].append([y, x])

# クラスごとのデータを NumPy 配列に変換
X = np.array([np.array(class_data[j]) for j in range(J)], dtype=object)
pixel = np.array([np.array(save_pixel_index[j]) for j in range(J)], dtype=object)

# セグメンテーション毎（クラスごと）のpixel数 N_j
N = [0]*J
for index, x_i in enumerate(X):
    N[index] = X[index].shape[0]
    #print(f'X[{i}].shape: {X[i].shape[0]}', end=' ')

# X の形状を表示
print(f'X.shape（J個のベクトル）: {X.shape}')
i = 0 # i番目のSuperpixel
print(f'{i}番目のsuperpixelのサンプル数: {N[i]}')
print(f'{i}番目のsuperpixelのサンプル: {X[i]}')
print(f'X[i].shape: {X[i].shape}')

N = np.array(N)
#N = torch.Tensor(N).to(device)# to torch.Tensor
#N = torch.from_numpy(N).to(dtype=torch.float32, device=device) # .to(device).to(torch.float32)
#N.requires_grad = True

# # == 過学習を防ぐためにSuperpixelの順番を shuffle ==
# # ======= 必要か?, 空間情報どうなる？ =======
# np.random.shuffle(X)
# for index, x_i in enumerate(X):
#     # 各Superpixel内の順番も shuffle
#     np.random.shuffle(X[i])

#     N[index] = X[i].shape[0]
# # =======================================

# # X の形状を表示
# print('\n==== シャッフル後 ====')
# print(f'X.shape（J個のベクトル）: {X.shape}')
# i = 0 # i番目のSuperpixel
# print(f'{i}番目のsuperpixelのサンプル数: {N[i]}')
# print(f'{i}番目のsuperpixelのサンプル: {X[i]}')

# print(f'X[i].shape: {X[i].shape}')
# Out:
# X.shape（J個のベクトル）: (435,)
# 0番目のsuperpixelのサンプル数: 122
# 0番目のsuperpixelのサンプル: [[0.28235295 0.04313726 0.05098039 ... 0.03137255 0.03137255 0.0627451 ]
#  [0.28627452 0.05490196 0.05882353 ... 0.05098039 0.04313726 0.07450981]
#  [0.2784314  0.07058824 0.05098039 ... 0.0627451  0.0627451  0.08627451]
#  ...
#  [0.21176471 0.08627451 0.08235294 ... 0.09019608 0.07450981 0.08627451]
#  [0.21960784 0.08627451 0.08235294 ... 0.09019608 0.08235294 0.10196079]
#  [0.22352941 0.09411765 0.07058824 ... 0.07450981 0.07058824 0.09803922]]
# X[i].shape: (122, 181)

# %%
for i in range(J):
    print(f'{i}:{N[i]}', end=' ')
print()
# Out:
# 0:122 1:744 2:680 3:722 4:869 5:462 6:637 7:101 8:682 9:345 10:977 11:259 12:186 13:356 14:136 15:916 16:649 17:299 18:796 19:447 20:677 21:132 22:97 23:147 24:481 25:130 26:551 27:430 28:267 29:543 30:1152 31:720 32:1229 33:170 34:178 35:281 36:713 37:589 38:478 39:155 40:166 41:1020 42:167 43:97 44:593 45:205 46:247 47:1127 48:127 49:735 50:379 51:145 52:572 53:912 54:606 55:292 56:815 57:1101 58:935 59:1075 60:330 61:780 62:1236 63:859 64:155 65:720 66:230 67:1269 68:194 69:228 70:1222 71:485 72:132 73:777 74:521 75:1159 76:166 77:247 78:439 79:1369 80:982 81:1263 82:846 83:859 84:120 85:269 86:2013 87:770 88:152 89:565 90:1425 91:1276 92:1466 93:838 94:1509 95:660 96:211 97:1448 98:406 99:1522 100:137 101:311 102:1489 103:492 104:523 105:1072 106:824 107:1109 108:1339 109:90 110:603 111:198 112:1126 113:730 114:932 115:808 116:207 117:359 118:197 119:124 120:625 121:638 122:374 123:1183 124:769 125:668 126:771 127:1669 128:723 129:513 130:1055 131:1256 132:1041 133:666 134:874 135:713 136:262 137:987 138:1403 139:1767 140:1060 141:471 142:1136 143:1397 144:1275 145:910 146:910 147:1489 148:98 149:1663 150:245 151:1056 152:762 153:198 154:439 155:315 156:1277 157:221 158:1082 159:126 160:1350 161:143 162:333 163:1417 164:919 165:1272 166:1255 167:774 168:1359 169:1094 170:382 171:1191 172:1147 173:790 174:1030 175:1239 176:835 177:418 178:483 179:885 180:996 181:199 182:1032 183:599 184:1061 185:159 186:293 187:418 188:470 189:256 190:868 191:221 192:1586 193:241 194:736 195:877 196:421 197:426 198:322 199:240 200:249 201:608 202:737 203:253 204:997 205:237 206:99 207:1763 208:156 209:227 210:632 211:197 212:236 213:471 214:953 215:1203 216:1106 217:117 218:1115 219:652 220:568 221:215 222:742 223:229 224:378 225:212 226:358 227:208 228:960 229:785 230:174 231:1026 232:189 233:1237 234:239 235:100 236:135 237:904 238:198 239:184 240:137 241:168 242:1205 243:117 244:652 245:1124 246:904 247:132 248:721 249:649 250:434 251:406 252:460 253:95 254:532 255:126 256:790 257:138 258:258 259:361 260:162 261:131 262:115 263:1659 264:309 265:157 266:211 267:122 268:331 269:103 270:1095 271:348 272:160 273:147 274:434 275:837 276:214 277:132 278:171 279:321 280:601 281:248 282:198 283:205 284:184 285:234 286:480 287:1609 288:1586 289:246 290:800 291:268 292:169 293:294 294:905 295:119 296:263 297:93 298:137 299:832 300:494 301:887 302:177 303:102 304:116 305:347 306:256 307:529 308:266 309:357 310:487 311:304 312:585 313:94 314:1078 315:186 316:445 317:829 318:357 319:706 320:210 321:138 322:115 323:986 324:341 325:101 326:388 327:593 328:1000 329:1042 330:109 331:388 332:1194 333:168 334:330 335:190 336:257 337:119 338:349 339:670 340:955 341:226 342:440 343:901 344:892 345:136 346:1652 347:322 348:785 349:646 350:124 351:254 352:902 353:1020 354:227 355:142 356:187 357:120 358:110 359:167 360:284 361:760 362:122 363:791 364:1328 365:958 366:146 367:1085 368:1097 369:220 370:285 371:872 372:104 373:1087 374:914 375:164 376:331 377:1026 378:111 379:994 380:469 381:101 382:635 383:134 384:274 385:272 386:997 387:1034 388:289 389:285 390:642 391:121 392:173 393:331 394:1208 395:323 396:479 397:116 398:183 399:398 400:190 401:868 402:449 403:1261 404:323 405:179 406:292 407:397 408:585 409:1289 410:1176 411:288 412:591 413:330 414:626 415:992 416:137 417:615 418:654 419:955 420:988 421:93 422:355 423:368 424:367 425:92 426:323 427:237 428:252 429:506 430:377 431:110 432:154 433:227 434:193

# %% [markdown]
# ### Locally Linear Embedding (LLE)
#
# 各Superpixel内の平均ベクトルの基本的な多様体構造を捕らえる
#
#
# 多様体学習についての参考 Web (https://www.hellocybernetics.tech/entry/2017/07/06/133450)
#
# 多様体学習の主な手法
# - LLE
#     - 長所
#         - 大域的な位置関係を保持できる
#     - 短所
#         - 多様体が複数ある場合、互いの位置関係をうまく保存できない。
#         - 圧縮後のデータ位置を再構成する計算量がデータ数の2乗に比例するため、大規模なデータに適用しづらい。
#     - Other LLE
#         - Hessian LLE
#         - Modified LLE
#         - Local Tangent Space Alignment (LTSA)
# - 多次元尺度法 (multi-dimensional scaling, MDS)
# - Isomap
# - t-SEN (t-distributed Stochastic Neighbor Embedding)
# - UMAP (Uniform Manifold Approximation and Projection)

# %% [markdown]
# #### 各Superpixel内の平均ベクトルを作成

# %%
# i番目のSuperpixelの平均ベクトル x J
#mu = [0]*J
mu = [[] for _ in range(J)]
for i in range(J):
    mu[i] = np.mean(X[i], axis=0)

mu = np.array(mu)
print(f'平均ベクトル: {mu.shape}')
# Out:
# 平均ベクトル: (435, 181)

# %% [markdown]
# #### 多様体損失
#
# 多様体構造を作るための入力として各Superpixelの平均ベクトル(mean vectors)を用いる
#
# 以下の式を最小化
#
# $$
# \matrix L(\matrix{Y}) = \sum_{i}
# {\|
#  \sum_{j} \frac{1}{N_{j}} \mathbf{y_{\textit{j}}^{\textit{i}}}
#   - \sum_{k} \mathbf{w_{\textit{ik}}} \sum_{j} \frac{1}{N_{k}} \mathbf{y_{\textit{j}}^{\textit{k}}}
#  \|}^{2}
# $$

# %%
# from sklearn.manifold import LocallyLinearEmbedding

# # 潜在空間のサイズ
# L = 30
# K = 5
# method = 'standard' # 通常のLLE

# embedding = LocallyLinearEmbedding(n_neighbors=K, n_components=L, method=method)

# M = embedding.fit_transform(mu[:J])

# # LLEの再構成誤差（多様体損失）
# monifold_loss = embedding.reconstruction_error_

# print(f'M shape: {M.shape}')
# print(f'monifold_loss: {monifold_loss}')
# print(f'M: {M}')

# %%
# LLEの実装しているコード
# %cd ~/BachelorResearch/ColAE/
# !git clone https://github.com/bghojogh/Generative-LLE.git
# %cd Generative-LLE
# Out:
# /home/zennakamura/BachelorResearch/ColAE
# fatal: destination path 'Generative-LLE' already exists and is not an empty directory.
# /home/zennakamura/BachelorResearch/ColAE/Generative-LLE
# /home/zennakamura/anaconda3/envs/torch/lib/python3.11/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /home/zennakamura/anaconda3/envs/torch/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# LLE
from functions import my_LLE

# 潜在空間のサイズ
L = 30
# K-最近傍の数 (固定比率 R=0.2 のとき)
K = J * 0.2
K = int(K)
print(f'K={K}')

# My_LLEの入力のため転置
mu_transpose = mu.transpose()

embedding = my_LLE.My_LLE(X=mu_transpose, n_neighbors=K, n_components=L,
                          path_save='~/BachelorResearch/ColAE/LLE')
# Out:
# K=87

# %%
X_transformed = embedding.fit_transform(calculate_again=True)
print(f'X shape: {mu_transpose.shape}')
print(f'Y shape: {X_transformed.shape}')

# 式（2）に従った各平均ベクトルの重み
W = embedding.W_linearEmbedding
print(f'W.shape: {W.shape}')
W = torch.from_numpy(W).to(dtype=torch.float32, device=device)
W.requires_grad = True

# K-最近傍のインデックス
neighbor_indices = embedding.neighbor_indices
print(f'neighbor_indices.shape: {neighbor_indices.shape}')
# Out:
# X shape: (181, 435)
# Y shape: (30, 435)
# W.shape: (435, 435)
# neighbor_indices.shape: (435, 87)

# %% [markdown]
# ### Auto-Encoder (AE)
#
# 各SuperpixelごとにAutoencoderを実装
#
# 余裕があれば、Variational Autoencoder（変分AE）にする、他も試してみる

# %%
# 入力サイズ BxN_i
i = 0 # i番目のSuperpixel
print(f'Input size ({band_num}x{N[i]}): {band_num*N[i]}')
# 潜在空間のサイズ
L = 30
print(f'Latent space size ({L}x{N[i]}): {L*N[i]}')
# Out:
# Input size (181x122): 22082
# Latent space size (30x122): 3660

# %% [markdown]
# #### Auto-Encoderの定義

# %%
import torch.nn as nn

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f'device: {device}')

class Encoder(nn.Module):
    def __init__(self, input_size, latent_size):
        super(Encoder, self).__init__()
        self.L = latent_size # 潜在空間の次元数 LxN_i
        self.fc1 = nn.Linear(input_size, input_size//2)
        self.fc2 = nn.Linear(input_size//2, self.L) # L = (band_num//3)//2
        # 重みを初期化
        nn.init.xavier_normal_(self.fc1.weight)
        nn.init.xavier_normal_(self.fc2.weight)
        nn.init.zeros_(self.fc1.bias)
        nn.init.zeros_(self.fc2.bias)

    def forward(self, x):
        x = x.float()
        #x = torch.tensor(x)
        x = torch.tanh(self.fc1(x))
        x = self.fc2(x)
        return x

class Decoder(nn.Module):
    def __init__(self, input_size, latent_size):
        super(Decoder, self).__init__()
        self.L = latent_size # 潜在空間の次元数 LxN_i
        self.fc1 = nn.Linear(self.L, input_size//2)
        self.fc2 = nn.Linear(input_size//2, input_size) # band_num = ((L*2)*3)
        # 重みを初期化
        nn.init.xavier_normal_(self.fc1.weight)
        nn.init.xavier_normal_(self.fc2.weight)
        nn.init.zeros_(self.fc1.bias)
        nn.init.zeros_(self.fc2.bias)

    def forward(self, x):
        x = x.float()
        #x = torch.tensor(x)
        x = torch.tanh(self.fc1(x))
        x = self.fc2(x)
        return x

class AutoEncoder(nn.Module):
    def __init__(self, input_size, latent_size):
        super().__init__()
        self.L = L
        self.enc = Encoder(input_size, latent_size).to(device)
        self.dec = Decoder(input_size, latent_size).to(device)

    def forward(self, x):
        #x = torch.tensor(x)
        encoded = self.enc(x) # Encode
        decoded = self.dec(encoded) # Decode
        return encoded, decoded
# Out:
# device: cuda:0

# %% [markdown]
# #### Auto-Encoderの学習
#
# 再構成誤差と多様体損失の２つの損失関数を用いて学習
#
# $$\mathbf{R}(\mathbf{\ominus}) =
# \sum_{i}\sum_{j} {\|{\mathbf{x_{\textit{j}}^{\textit{i}}}} - \mathbf{\hat{x}_{\textit{j}}^{\textit{i}}}\|}^{2} + \eta \sum_{i}
# {\|
#  \sum_{j} \frac{1}{N_{i}} \mathbf{y_{\textit{j}}^{\textit{i}}}
#   - \sum_{k} \mathbf{\textit{w}_{\textit{ik}}} \sum_{j} \frac{1}{N_{k}} \mathbf{y_{\textit{j}}^{\textit{k}}}
#  \|}^{2}
#  $$

# %% [markdown]
# #### 損失関数, 最適化手法の定義

# %% [markdown]
# #### D-Adaptation
#
# DOI: https://arxiv.org/abs/2301.07733
# Github: https://github.com/facebookresearch/dadaptation

# %%
# MSE Loss funcion (再構成誤差)
AE_loss_function = torch.nn.MSELoss()
monifold_loss_function = torch.nn.MSELoss()

# 乱数のシードを固定して再現性を確保
torch.manual_seed(0)

# %%
#import dadaptation

# %%
model = [[] for _ in range(J)]
optimizer = [[] for _ in range(J)]
scheduler = [[] for _ in range(J)]

epochs = 500 # epoch数

for i in range(J):
    # i番目のModel
    model[i] = AutoEncoder(band_num, L).to(device)

    # i番目のOptimizer
    optimizer[i] = torch.optim.Adam(model[i].parameters(), lr=1e-3, weight_decay=1e-5)
    #optimizer[i] = dadaptation.dadapt_adam.DAdaptAdam(model[i].parameters(), lr=1.0, decouple=False, weight_decay=1e-5)
    scheduler[i] = torch.optim.lr_scheduler.LinearLR(optimizer[i], start_factor=0.5, end_factor=1e-3, total_iters=(epochs-5))

# %% [markdown]
# ##### 学習

# %%
save_path = '~/BachelorResearch/ColAE/'+data_name
# %cd {save_path}
weight_path = f'weight'

if not os.path.exists(weight_path):
    print(f'{weight_path} is not exists')
    os.makedirs(weight_path, exist_ok=True)
# Out:
# /home/zennakamura/BachelorResearch/ColAE/Port
# /home/zennakamura/anaconda3/envs/torch/lib/python3.11/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /home/zennakamura/anaconda3/envs/torch/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
#from sklearn.manifold import LocallyLinearEmbedding

L = 30 # 符号空間（code space）の次元数
#eta =  0.75 # 損失のバランス係数
eta =  1.25 # 損失のバランス係数

# i-th Superpixelの符号空間の平均ベクトル x J
mu_y_ = [[] for _ in range(J)]
mu_y = [[] for _ in range(J)]

# K-近傍
y_ik_ = [[0] for _ in range(J)]
y_ik = [[0] for _ in range(J)]

start_ColAE = time.time() #
#liveloss = PlotLosses() # livelossplot
plot_AE_loss = []
plot_monifold_loss = []

# 学習
for epoch in range(epochs):
    print(f'Epoch {epoch}/{epochs-1}\t(J={J})')
    print('\t', end='')
    #logs = {} # livelossplot

    AE_loss = 0.0 # AEの損失
    monifold_loss = 0.0 # 多様体損失(LLE)
    loss = 0.0 # ColAEの損失

    # 潜在空間(Latent Space)ベクトル
    Y_ = [[] for _ in range(J)]
    Y = [[] for _ in range(J)]

    for i in range(J):
# ========== train ===========
        # modelのパラメータの読み込み
        #weight_path = f'~/BachelorResearch/ColAE/weight/ColAE_weight_{i}.pth'
        if os.path.exists(os.path.join(weight_path, f'ColAE_weight_{i}.pth')):
            model[i].load_state_dict(torch.load(os.path.join(weight_path, f'ColAE_weight_{i}.pth')))

        model[i].train() # モデルを訓練モードに設定

        for j, input in enumerate(X[i]): # BxN_i から 長さBのベクトルごとに

            # Encoder input
            input = torch.from_numpy(input).to(dtype=torch.float32, device=device)
            input.requires_grad = True

            # Encoder output (Latent Space) and Decoder output
            latent, reconstructed = model[i](input)

            # L(latentの次元) x N_i
            latent = np.array(latent.detach().cpu())
            Y_[i].append(latent)

            #  ======= 損失計算 =======
            # Loss function for the i-th AE (式9, 10)
            AE_loss_ = AE_loss_function(reconstructed, input)
            AE_loss_.retain_grad()
            AE_loss += AE_loss_
            AE_loss.retain_grad()
            # ======================

        #print(f'AE_{i} Train Loss: {AE_loss_:.5f},', end=' ')
        #print(f'{i},', end='')
        # i番目のSuperpixelの潜在空間ベクトル
        Y[i] = np.array(Y_[i])

    print()

    # ======= 損失計算 =======
    # 再構成誤差, 多様体損失 (式8)
    # i-th Superpixelの符号空間の平均ベクトル x J
    for i in range(J):
        mu_y_[i] = np.mean(Y[i], axis=0)
        mu_y_[i] = np.array(mu_y_[i])
        mu_y[i] = torch.from_numpy(mu_y_[i]).to(dtype=torch.float32, device=device)
        mu_y[i].requires_grad = True

    for i in range(J):
        for k in neighbor_indices[i].astype('int32'):
            # y_i のK-最近傍の線型結合
            y_ik_[i] = np.array(y_ik_[i])
            y_ik[i] = torch.from_numpy(y_ik_[i]).to(dtype=torch.float32, device=device)
            y_ik[i].requires_grad = True
            y_ik[i] = y_ik[i] + W[i][k] * mu_y[k]
            y_ik[i].retain_grad()

        monifold_loss_ = monifold_loss_function(mu_y[i], y_ik[i])
        monifold_loss_.retain_grad()
        # LLEの再構成誤差（多様体損失）
        monifold_loss +=  monifold_loss_
        monifold_loss.retain_grad()

    # ColAEの損失(式11)
    loss = AE_loss + eta*monifold_loss
    loss.retain_grad()
    # ======================

    for i in range(J):
        # 全Superpixelの多様体構造を保つようにパラメータ更新
        optimizer[i].zero_grad()
    loss.backward() # 誤差逆伝播法に基づいて各パラメータの勾配を計算
    #monifold_loss.backward()
    for i in range(J):
        optimizer[i].step() # 勾配の値に基づいて選択した最適化手法によりパラメータ W, b を更新
        scheduler[i].step()

        # modelのパラメータの保存（epochごとに使う）
        #weight_path = f'~/BachelorResearch/ColAE/weight/ColAE_weight_{i}.pth'
        torch.save(model[i].state_dict(), os.path.join(weight_path, f'ColAE_weight_{i}.pth'))
    print(f'\tAE Loss: {AE_loss:.6f}, Monifold Loss: {monifold_loss:.6f}, ColAE Loss: {loss:.6f}')
    #logs['AE_loss'] = AE_loss.to('cpu').detach().numpy()
    #logs['Monifold_loss'] = monifold_loss.to('cpu').detach().numpy()
    #liveloss.update(logs)
    #liveloss.send()
    plot_AE_loss.append(AE_loss.to('cpu').detach().numpy())
    plot_monifold_loss.append(monifold_loss.to('cpu').detach().numpy())

end_ColAE = time.time() #
time_diff = end_ColAE-start_ColAE
print(f'Running time of ColAE is {time_diff}')
# ========== train ===========
# Out:
# Epoch 0/499	(J=435)
#
# 	AE Loss: 1366.802734, Monifold Loss: 300.139282, ColAE Loss: 1741.976807
# Epoch 1/499	(J=435)
#
# 	AE Loss: 1235.447266, Monifold Loss: 304.207642, ColAE Loss: 1615.706787
# Epoch 2/499	(J=435)
#
# 	AE Loss: 876.114136, Monifold Loss: 304.384827, ColAE Loss: 1256.595215
# Epoch 3/499	(J=435)
#
# 	AE Loss: 783.898865, Monifold Loss: 304.337463, ColAE Loss: 1164.320679
# Epoch 4/499	(J=435)
#
# 	AE Loss: 698.801392, Monifold Loss: 304.590576, ColAE Loss: 1079.539551
# Epoch 5/499	(J=435)
#
# 	AE Loss: 576.655334, Monifold Loss: 305.182068, ColAE Loss: 958.132935
# Epoch 6/499	(J=435)
#
# 	AE Loss: 482.731232, Monifold Loss: 306.016541, ColAE Loss: 865.251953
# Epoch 7/499	(J=435)
#
# 	AE Loss: 433.560028, Monifold Loss: 306.934753, ColAE Loss: 817.228516
# Epoch 8/499	(J=435)
#
# 	AE Loss: 400.552948, Monifold Loss: 307.611115, ColAE Loss: 785.066833
# Epoch 9/499	(J=435)
#
# 	AE Loss: 360.742920, Monifold Loss: 307.917755, ColAE Loss: 745.640137
# Epoch 10/499	(J=435)
#
# 	AE Loss: 317.041138, Monifold Loss: 307.915619, ColAE Loss: 701.935669
# Epoch 11/499	(J=435)
#
# 	AE Loss: 281.305481, Monifold Loss: 307.730377, ColAE Loss: 665.968445
# Epoch 12/499	(J=435)
#
# 	AE Loss: 257.389435, Monifold Loss: 307.493652, ColAE Loss: 641.756470
# Epoch 13/499	(J=435)
#
# 	AE Loss: 240.199982, Monifold Loss: 307.296783, ColAE Loss: 624.320923
# Epoch 14/499	(J=435)
#
# 	AE Loss: 223.690369, Monifold Loss: 307.181824, ColAE Loss: 607.667664
# Epoch 15/499	(J=435)
#
# 	AE Loss: 206.166550, Monifold Loss: 307.144562, ColAE Loss: 590.097229
# Epoch 16/499	(J=435)
#
# 	AE Loss: 189.410477, Monifold Loss: 307.150879, ColAE Loss: 573.349060
# Epoch 17/499	(J=435)
#
# 	AE Loss: 175.350708, Monifold Loss: 307.155426, ColAE Loss: 559.294983
# Epoch 18/499	(J=435)
#
# 	AE Loss: 164.229767, Monifold Loss: 307.121185, ColAE Loss: 548.131226
# Epoch 19/499	(J=435)
#
# 	AE Loss: 154.968185, Monifold Loss: 307.032501, ColAE Loss: 538.758789
# Epoch 20/499	(J=435)
#
# 	AE Loss: 146.466583, Monifold Loss: 306.897644, ColAE Loss: 530.088623
# Epoch 21/499	(J=435)
#
# 	AE Loss: 138.408936, Monifold Loss: 306.737549, ColAE Loss: 521.830872
# Epoch 22/499	(J=435)
#
# 	AE Loss: 131.019775, Monifold Loss: 306.575256, ColAE Loss: 514.238831
# Epoch 23/499	(J=435)
#
# 	AE Loss: 124.483826, Monifold Loss: 306.428864, ColAE Loss: 507.519897
# Epoch 24/499	(J=435)
#
# 	AE Loss: 118.794136, Monifold Loss: 306.305328, ColAE Loss: 501.675781
# Epoch 25/499	(J=435)
#
# 	AE Loss: 113.869537, Monifold Loss: 306.202820, ColAE Loss: 496.623077
# Epoch 26/499	(J=435)
#
# 	AE Loss: 109.532394, Monifold Loss: 306.111267, ColAE Loss: 492.171509
# Epoch 27/499	(J=435)
#
# 	AE Loss: 105.498962, Monifold Loss: 306.020142, ColAE Loss: 488.024139
# Epoch 28/499	(J=435)
#
# 	AE Loss: 101.583389, Monifold Loss: 305.924988, ColAE Loss: 483.989624
# Epoch 29/499	(J=435)
#
# 	AE Loss: 97.947449, Monifold Loss: 305.825348, ColAE Loss: 480.229126
# Epoch 30/499	(J=435)
#
# 	AE Loss: 94.837311, Monifold Loss: 305.726318, ColAE Loss: 476.995209
# Epoch 31/499	(J=435)
#
# 	AE Loss: 92.157455, Monifold Loss: 305.627136, ColAE Loss: 474.191406
# Epoch 32/499	(J=435)
#
# 	AE Loss: 89.622223, Monifold Loss: 305.527893, ColAE Loss: 471.532074
# Epoch 33/499	(J=435)
#
# 	AE Loss: 87.205566, Monifold Loss: 305.428162, ColAE Loss: 468.990784
# Epoch 34/499	(J=435)
#
# 	AE Loss: 85.078629, Monifold Loss: 305.326080, ColAE Loss: 466.736206
# Epoch 35/499	(J=435)
#
# 	AE Loss: 83.209862, Monifold Loss: 305.218201, ColAE Loss: 464.732635
# Epoch 36/499	(J=435)
#
# 	AE Loss: 81.418243, Monifold Loss: 305.099579, ColAE Loss: 462.792725
# Epoch 37/499	(J=435)
#
# 	AE Loss: 79.674683, Monifold Loss: 304.968109, ColAE Loss: 460.884827
# Epoch 38/499	(J=435)
#
# 	AE Loss: 78.120880, Monifold Loss: 304.828308, ColAE Loss: 459.156281
# Epoch 39/499	(J=435)
#
# 	AE Loss: 76.801437, Monifold Loss: 304.688873, ColAE Loss: 457.662537
# Epoch 40/499	(J=435)
#
# 	AE Loss: 75.578987, Monifold Loss: 304.555695, ColAE Loss: 456.273590
# Epoch 41/499	(J=435)
#
# 	AE Loss: 74.321259, Monifold Loss: 304.430054, ColAE Loss: 454.858826
# Epoch 42/499	(J=435)
#
# 	AE Loss: 73.063797, Monifold Loss: 304.308197, ColAE Loss: 453.449036
# Epoch 43/499	(J=435)
#
# 	AE Loss: 71.896461, Monifold Loss: 304.184021, ColAE Loss: 452.126495
# Epoch 44/499	(J=435)
#
# 	AE Loss: 70.828140, Monifold Loss: 304.051941, ColAE Loss: 450.893066
# Epoch 45/499	(J=435)
#
# 	AE Loss: 69.812538, Monifold Loss: 303.907440, ColAE Loss: 449.696838
# Epoch 46/499	(J=435)
#
# 	AE Loss: 68.818359, Monifold Loss: 303.750641, ColAE Loss: 448.506653
# Epoch 47/499	(J=435)
#
# 	AE Loss: 67.841278, Monifold Loss: 303.587067, ColAE Loss: 447.325104
# Epoch 48/499	(J=435)
#
# 	AE Loss: 66.882095, Monifold Loss: 303.424896, ColAE Loss: 446.163208
# Epoch 49/499	(J=435)
#
# 	AE Loss: 65.957932, Monifold Loss: 303.270630, ColAE Loss: 445.046204
# Epoch 50/499	(J=435)
#
# 	AE Loss: 65.081276, Monifold Loss: 303.126740, ColAE Loss: 443.989685
# Epoch 51/499	(J=435)
#
# 	AE Loss: 64.260521, Monifold Loss: 302.991577, ColAE Loss: 443.000000
# Epoch 52/499	(J=435)
#
# 	AE Loss: 63.503368, Monifold Loss: 302.862488, ColAE Loss: 442.081482
# Epoch 53/499	(J=435)
#
# 	AE Loss: 62.800297, Monifold Loss: 302.735626, ColAE Loss: 441.219818
# Epoch 54/499	(J=435)
#
# 	AE Loss: 62.126987, Monifold Loss: 302.608582, ColAE Loss: 440.387726
# Epoch 55/499	(J=435)
#
# 	AE Loss: 61.485500, Monifold Loss: 302.478851, ColAE Loss: 439.584076
# Epoch 56/499	(J=435)
#
# 	AE Loss: 60.893730, Monifold Loss: 302.347626, ColAE Loss: 438.828278
# Epoch 57/499	(J=435)
#
# 	AE Loss: 60.349403, Monifold Loss: 302.216400, ColAE Loss: 438.119904
# Epoch 58/499	(J=435)
#
# 	AE Loss: 59.824745, Monifold Loss: 302.087219, ColAE Loss: 437.433746
# Epoch 59/499	(J=435)
#
# 	AE Loss: 59.313602, Monifold Loss: 301.961456, ColAE Loss: 436.765411
# Epoch 60/499	(J=435)
#
# 	AE Loss: 58.824062, Monifold Loss: 301.838501, ColAE Loss: 436.122192
# Epoch 61/499	(J=435)
#
# 	AE Loss: 58.344578, Monifold Loss: 301.719147, ColAE Loss: 435.493500
# Epoch 62/499	(J=435)
#
# 	AE Loss: 57.877045, Monifold Loss: 301.600555, ColAE Loss: 434.877747
# Epoch 63/499	(J=435)
#
# 	AE Loss: 57.425610, Monifold Loss: 301.480316, ColAE Loss: 434.276001
# Epoch 64/499	(J=435)
#
# 	AE Loss: 56.988598, Monifold Loss: 301.358093, ColAE Loss: 433.686218
# Epoch 65/499	(J=435)
#
# 	AE Loss: 56.559402, Monifold Loss: 301.235168, ColAE Loss: 433.103333
# Epoch 66/499	(J=435)
#
# 	AE Loss: 56.141914, Monifold Loss: 301.112091, ColAE Loss: 432.532013
# Epoch 67/499	(J=435)
#
# 	AE Loss: 55.740639, Monifold Loss: 300.990814, ColAE Loss: 431.979156
# Epoch 68/499	(J=435)
#
# 	AE Loss: 55.357765, Monifold Loss: 300.870300, ColAE Loss: 431.445648
# Epoch 69/499	(J=435)
#
# 	AE Loss: 54.988319, Monifold Loss: 300.750092, ColAE Loss: 430.925934
# Epoch 70/499	(J=435)
#
# 	AE Loss: 54.630554, Monifold Loss: 300.629181, ColAE Loss: 430.417023
# Epoch 71/499	(J=435)
#
# 	AE Loss: 54.281635, Monifold Loss: 300.508301, ColAE Loss: 429.917023
# Epoch 72/499	(J=435)
#
# 	AE Loss: 53.943691, Monifold Loss: 300.389832, ColAE Loss: 429.431000
# Epoch 73/499	(J=435)
#
# 	AE Loss: 53.615910, Monifold Loss: 300.274323, ColAE Loss: 428.958801
# Epoch 74/499	(J=435)
#
# 	AE Loss: 53.296425, Monifold Loss: 300.160950, ColAE Loss: 428.497589
# Epoch 75/499	(J=435)
#
# 	AE Loss: 52.985451, Monifold Loss: 300.047760, ColAE Loss: 428.045135
# Epoch 76/499	(J=435)
#
# 	AE Loss: 52.681477, Monifold Loss: 299.933258, ColAE Loss: 427.598053
# Epoch 77/499	(J=435)
#
# 	AE Loss: 52.387287, Monifold Loss: 299.817078, ColAE Loss: 427.158661
# Epoch 78/499	(J=435)
#
# 	AE Loss: 52.099880, Monifold Loss: 299.699890, ColAE Loss: 426.724762
# Epoch 79/499	(J=435)
#
# 	AE Loss: 51.816055, Monifold Loss: 299.582947, ColAE Loss: 426.294739
# Epoch 80/499	(J=435)
#
# 	AE Loss: 51.539150, Monifold Loss: 299.467163, ColAE Loss: 425.873108
# Epoch 81/499	(J=435)
#
# 	AE Loss: 51.270012, Monifold Loss: 299.351685, ColAE Loss: 425.459625
# Epoch 82/499	(J=435)
#
# 	AE Loss: 51.006966, Monifold Loss: 299.236603, ColAE Loss: 425.052704
# Epoch 83/499	(J=435)
#
# 	AE Loss: 50.750240, Monifold Loss: 299.121674, ColAE Loss: 424.652344
# Epoch 84/499	(J=435)
#
# 	AE Loss: 50.496597, Monifold Loss: 299.006500, ColAE Loss: 424.254700
# Epoch 85/499	(J=435)
#
# 	AE Loss: 50.248306, Monifold Loss: 298.891357, ColAE Loss: 423.862488
# Epoch 86/499	(J=435)
#
# 	AE Loss: 50.005978, Monifold Loss: 298.774658, ColAE Loss: 423.474304
# Epoch 87/499	(J=435)
#
# 	AE Loss: 49.768391, Monifold Loss: 298.657043, ColAE Loss: 423.089691
# Epoch 88/499	(J=435)
#
# 	AE Loss: 49.536064, Monifold Loss: 298.539032, ColAE Loss: 422.709869
# Epoch 89/499	(J=435)
#
# 	AE Loss: 49.309063, Monifold Loss: 298.421722, ColAE Loss: 422.336212
# Epoch 90/499	(J=435)
#
# 	AE Loss: 49.085781, Monifold Loss: 298.305847, ColAE Loss: 421.968109
# Epoch 91/499	(J=435)
#
# 	AE Loss: 48.866837, Monifold Loss: 298.190186, ColAE Loss: 421.604553
# Epoch 92/499	(J=435)
#
# 	AE Loss: 48.653481, Monifold Loss: 298.074371, ColAE Loss: 421.246429
# Epoch 93/499	(J=435)
#
# 	AE Loss: 48.444996, Monifold Loss: 297.957275, ColAE Loss: 420.891602
# Epoch 94/499	(J=435)
#
# 	AE Loss: 48.239697, Monifold Loss: 297.839111, ColAE Loss: 420.538574
# Epoch 95/499	(J=435)
#
# 	AE Loss: 48.037582, Monifold Loss: 297.719360, ColAE Loss: 420.186768
# Epoch 96/499	(J=435)
#
# 	AE Loss: 47.840065, Monifold Loss: 297.598633, ColAE Loss: 419.838348
# Epoch 97/499	(J=435)
#
# 	AE Loss: 47.645718, Monifold Loss: 297.476532, ColAE Loss: 419.491394
# Epoch 98/499	(J=435)
#
# 	AE Loss: 47.454525, Monifold Loss: 297.352234, ColAE Loss: 419.144836
# Epoch 99/499	(J=435)
#
# 	AE Loss: 47.267529, Monifold Loss: 297.224548, ColAE Loss: 418.798218
# Epoch 100/499	(J=435)
#
# 	AE Loss: 47.081604, Monifold Loss: 297.092346, ColAE Loss: 418.447021
# Epoch 101/499	(J=435)
#
# 	AE Loss: 46.900562, Monifold Loss: 296.952881, ColAE Loss: 418.091675
# Epoch 102/499	(J=435)
#
# 	AE Loss: 46.721817, Monifold Loss: 296.803223, ColAE Loss: 417.725830
# Epoch 103/499	(J=435)
#
# 	AE Loss: 46.545567, Monifold Loss: 296.641449, ColAE Loss: 417.347382
# Epoch 104/499	(J=435)
#
# 	AE Loss: 46.371796, Monifold Loss: 296.462830, ColAE Loss: 416.950348
# Epoch 105/499	(J=435)
#
# 	AE Loss: 46.200165, Monifold Loss: 296.263824, ColAE Loss: 416.529938
# Epoch 106/499	(J=435)
#
# 	AE Loss: 46.030827, Monifold Loss: 296.039795, ColAE Loss: 416.080566
# Epoch 107/499	(J=435)
#
# 	AE Loss: 45.862801, Monifold Loss: 295.791443, ColAE Loss: 415.602112
# Epoch 108/499	(J=435)
#
# 	AE Loss: 45.695274, Monifold Loss: 295.529907, ColAE Loss: 415.107666
# Epoch 109/499	(J=435)
#
# 	AE Loss: 45.525520, Monifold Loss: 295.275604, ColAE Loss: 414.620026
# Epoch 110/499	(J=435)
#
# 	AE Loss: 45.351814, Monifold Loss: 295.039520, ColAE Loss: 414.151215
# Epoch 111/499	(J=435)
#
# 	AE Loss: 45.174385, Monifold Loss: 294.816376, ColAE Loss: 413.694855
# Epoch 112/499	(J=435)
#
# 	AE Loss: 44.993069, Monifold Loss: 294.594421, ColAE Loss: 413.236115
# Epoch 113/499	(J=435)
#
# 	AE Loss: 44.808571, Monifold Loss: 294.368591, ColAE Loss: 412.769318
# Epoch 114/499	(J=435)
#
# 	AE Loss: 44.609951, Monifold Loss: 294.181335, ColAE Loss: 412.336639
# Epoch 115/499	(J=435)
#
# 	AE Loss: 44.396881, Monifold Loss: 294.013428, ColAE Loss: 411.913666
# Epoch 116/499	(J=435)
#
# 	AE Loss: 44.182072, Monifold Loss: 293.796478, ColAE Loss: 411.427673
# Epoch 117/499	(J=435)
#
# 	AE Loss: 43.974361, Monifold Loss: 293.541016, ColAE Loss: 410.900635
# Epoch 118/499	(J=435)
#
# 	AE Loss: 43.727917, Monifold Loss: 293.302429, ColAE Loss: 410.355957
# Epoch 119/499	(J=435)
#
# 	AE Loss: 43.536385, Monifold Loss: 293.067017, ColAE Loss: 409.870148
# Epoch 120/499	(J=435)
#
# 	AE Loss: 43.298023, Monifold Loss: 292.806519, ColAE Loss: 409.306183
# Epoch 121/499	(J=435)
#
# 	AE Loss: 43.063755, Monifold Loss: 292.520081, ColAE Loss: 408.713837
# Epoch 122/499	(J=435)
#
# 	AE Loss: 42.827503, Monifold Loss: 292.212219, ColAE Loss: 408.092773
# Epoch 123/499	(J=435)
#
# 	AE Loss: 42.597225, Monifold Loss: 291.904694, ColAE Loss: 407.478088
# Epoch 124/499	(J=435)
#
# 	AE Loss: 42.388214, Monifold Loss: 291.571625, ColAE Loss: 406.852753
# Epoch 125/499	(J=435)
#
# 	AE Loss: 42.160568, Monifold Loss: 291.193878, ColAE Loss: 406.152893
# Epoch 126/499	(J=435)
#
# 	AE Loss: 41.967499, Monifold Loss: 290.797485, ColAE Loss: 405.464355
# Epoch 127/499	(J=435)
#
# 	AE Loss: 41.745857, Monifold Loss: 290.411835, ColAE Loss: 404.760651
# Epoch 128/499	(J=435)
#
# 	AE Loss: 41.571880, Monifold Loss: 290.017120, ColAE Loss: 404.093262
# Epoch 129/499	(J=435)
#
# 	AE Loss: 41.362865, Monifold Loss: 289.601105, ColAE Loss: 403.364227
# Epoch 130/499	(J=435)
#
# 	AE Loss: 41.203606, Monifold Loss: 289.167511, ColAE Loss: 402.662994
# Epoch 131/499	(J=435)
#
# 	AE Loss: 41.005489, Monifold Loss: 288.727234, ColAE Loss: 401.914551
# Epoch 132/499	(J=435)
#
# 	AE Loss: 40.852318, Monifold Loss: 288.250885, ColAE Loss: 401.165924
# Epoch 133/499	(J=435)
#
# 	AE Loss: 40.668797, Monifold Loss: 287.741516, ColAE Loss: 400.345673
# Epoch 134/499	(J=435)
#
# 	AE Loss: 40.521877, Monifold Loss: 287.226776, ColAE Loss: 399.555359
# Epoch 135/499	(J=435)
#
# 	AE Loss: 40.348522, Monifold Loss: 286.722046, ColAE Loss: 398.751068
# Epoch 136/499	(J=435)
#
# 	AE Loss: 40.204445, Monifold Loss: 286.199890, ColAE Loss: 397.954315
# Epoch 137/499	(J=435)
#
# 	AE Loss: 40.042004, Monifold Loss: 285.629272, ColAE Loss: 397.078583
# Epoch 138/499	(J=435)
#
# 	AE Loss: 39.901089, Monifold Loss: 285.035034, ColAE Loss: 396.194885
# Epoch 139/499	(J=435)
#
# 	AE Loss: 39.746990, Monifold Loss: 284.488678, ColAE Loss: 395.357819
# Epoch 140/499	(J=435)
#
# 	AE Loss: 39.606869, Monifold Loss: 283.948517, ColAE Loss: 394.542511
# Epoch 141/499	(J=435)
#
# 	AE Loss: 39.460716, Monifold Loss: 283.344421, ColAE Loss: 393.641266
# Epoch 142/499	(J=435)
#
# 	AE Loss: 39.322861, Monifold Loss: 282.735565, ColAE Loss: 392.742310
# Epoch 143/499	(J=435)
#
# 	AE Loss: 39.183826, Monifold Loss: 282.155243, ColAE Loss: 391.877899
# Epoch 144/499	(J=435)
#
# 	AE Loss: 39.046165, Monifold Loss: 281.600433, ColAE Loss: 391.046722
# Epoch 145/499	(J=435)
#
# 	AE Loss: 38.912205, Monifold Loss: 281.018005, ColAE Loss: 390.184723
# Epoch 146/499	(J=435)
#
# 	AE Loss: 38.777615, Monifold Loss: 280.433929, ColAE Loss: 389.320038
# Epoch 147/499	(J=435)
#
# 	AE Loss: 38.650055, Monifold Loss: 279.820068, ColAE Loss: 388.425140
# Epoch 148/499	(J=435)
#
# 	AE Loss: 38.518723, Monifold Loss: 279.307709, ColAE Loss: 387.653381
# Epoch 149/499	(J=435)
#
# 	AE Loss: 38.389164, Monifold Loss: 278.751587, ColAE Loss: 386.828644
# Epoch 150/499	(J=435)
#
# 	AE Loss: 38.259064, Monifold Loss: 278.169006, ColAE Loss: 385.970306
# Epoch 151/499	(J=435)
#
# 	AE Loss: 38.138622, Monifold Loss: 277.625732, ColAE Loss: 385.170776
# Epoch 152/499	(J=435)
#
# 	AE Loss: 38.008778, Monifold Loss: 277.098907, ColAE Loss: 384.382416
# Epoch 153/499	(J=435)
#
# 	AE Loss: 37.888805, Monifold Loss: 276.585052, ColAE Loss: 383.620117
# Epoch 154/499	(J=435)
#
# 	AE Loss: 37.766102, Monifold Loss: 276.100525, ColAE Loss: 382.891785
# Epoch 155/499	(J=435)
#
# 	AE Loss: 37.641319, Monifold Loss: 275.560211, ColAE Loss: 382.091583
# Epoch 156/499	(J=435)
#
# 	AE Loss: 37.521038, Monifold Loss: 275.021698, ColAE Loss: 381.298157
# Epoch 157/499	(J=435)
#
# 	AE Loss: 37.392578, Monifold Loss: 274.606689, ColAE Loss: 380.650940
# Epoch 158/499	(J=435)
#
# 	AE Loss: 37.264217, Monifold Loss: 274.158234, ColAE Loss: 379.962006
# Epoch 159/499	(J=435)
#
# 	AE Loss: 37.127655, Monifold Loss: 273.613647, ColAE Loss: 379.144714
# Epoch 160/499	(J=435)
#
# 	AE Loss: 36.977829, Monifold Loss: 273.154694, ColAE Loss: 378.421204
# Epoch 161/499	(J=435)
#
# 	AE Loss: 36.804981, Monifold Loss: 272.755371, ColAE Loss: 377.749207
# Epoch 162/499	(J=435)
#
# 	AE Loss: 36.587681, Monifold Loss: 272.284943, ColAE Loss: 376.943848
# Epoch 163/499	(J=435)
#
# 	AE Loss: 36.303444, Monifold Loss: 271.801575, ColAE Loss: 376.055389
# Epoch 164/499	(J=435)
#
# 	AE Loss: 35.946251, Monifold Loss: 271.299042, ColAE Loss: 375.070068
# Epoch 165/499	(J=435)
#
# 	AE Loss: 35.645187, Monifold Loss: 270.773071, ColAE Loss: 374.111511
# Epoch 166/499	(J=435)
#
# 	AE Loss: 35.546711, Monifold Loss: 270.496674, ColAE Loss: 373.667572
# Epoch 167/499	(J=435)
#
# 	AE Loss: 35.225716, Monifold Loss: 270.494171, ColAE Loss: 373.343414
# Epoch 168/499	(J=435)
#
# 	AE Loss: 34.989216, Monifold Loss: 270.122498, ColAE Loss: 372.642365
# Epoch 169/499	(J=435)
#
# 	AE Loss: 34.807858, Monifold Loss: 269.501617, ColAE Loss: 371.684875
# Epoch 170/499	(J=435)
#
# 	AE Loss: 34.639683, Monifold Loss: 269.041718, ColAE Loss: 370.941833
# Epoch 171/499	(J=435)
#
# 	AE Loss: 34.333958, Monifold Loss: 268.946533, ColAE Loss: 370.517120
# Epoch 172/499	(J=435)
#
# 	AE Loss: 34.208549, Monifold Loss: 268.921356, ColAE Loss: 370.360260
# Epoch 173/499	(J=435)
#
# 	AE Loss: 34.078545, Monifold Loss: 268.623413, ColAE Loss: 369.857819
# Epoch 174/499	(J=435)
#
# 	AE Loss: 33.860107, Monifold Loss: 268.205750, ColAE Loss: 369.117310
# Epoch 175/499	(J=435)
#
# 	AE Loss: 33.692612, Monifold Loss: 267.826752, ColAE Loss: 368.476074
# Epoch 176/499	(J=435)
#
# 	AE Loss: 33.616390, Monifold Loss: 267.476959, ColAE Loss: 367.962585
# Epoch 177/499	(J=435)
#
# 	AE Loss: 33.464310, Monifold Loss: 267.162933, ColAE Loss: 367.417969
# Epoch 178/499	(J=435)
#
# 	AE Loss: 33.289116, Monifold Loss: 266.864075, ColAE Loss: 366.869202
# Epoch 179/499	(J=435)
#
# 	AE Loss: 33.172520, Monifold Loss: 266.645142, ColAE Loss: 366.478943
# Epoch 180/499	(J=435)
#
# 	AE Loss: 33.065639, Monifold Loss: 266.416901, ColAE Loss: 366.086761
# Epoch 181/499	(J=435)
#
# 	AE Loss: 32.904217, Monifold Loss: 266.035522, ColAE Loss: 365.448608
# Epoch 182/499	(J=435)
#
# 	AE Loss: 32.770866, Monifold Loss: 265.614746, ColAE Loss: 364.789307
# Epoch 183/499	(J=435)
#
# 	AE Loss: 32.673294, Monifold Loss: 265.290924, ColAE Loss: 364.286926
# Epoch 184/499	(J=435)
#
# 	AE Loss: 32.554424, Monifold Loss: 265.065063, ColAE Loss: 363.885742
# Epoch 185/499	(J=435)
#
# 	AE Loss: 32.414570, Monifold Loss: 264.816376, ColAE Loss: 363.435059
# Epoch 186/499	(J=435)
#
# 	AE Loss: 32.315865, Monifold Loss: 264.594696, ColAE Loss: 363.059235
# Epoch 187/499	(J=435)
#
# 	AE Loss: 32.219440, Monifold Loss: 264.439575, ColAE Loss: 362.768921
# Epoch 188/499	(J=435)
#
# 	AE Loss: 32.100868, Monifold Loss: 264.148285, ColAE Loss: 362.286224
# Epoch 189/499	(J=435)
#
# 	AE Loss: 32.000149, Monifold Loss: 263.816589, ColAE Loss: 361.770905
# Epoch 190/499	(J=435)
#
# 	AE Loss: 31.913494, Monifold Loss: 263.581116, ColAE Loss: 361.389862
# Epoch 191/499	(J=435)
#
# 	AE Loss: 31.819542, Monifold Loss: 263.414703, ColAE Loss: 361.087921
# Epoch 192/499	(J=435)
#
# 	AE Loss: 31.719530, Monifold Loss: 263.242401, ColAE Loss: 360.772552
# Epoch 193/499	(J=435)
#
# 	AE Loss: 31.633392, Monifold Loss: 263.126862, ColAE Loss: 360.541962
# Epoch 194/499	(J=435)
#
# 	AE Loss: 31.551573, Monifold Loss: 263.020905, ColAE Loss: 360.327698
# Epoch 195/499	(J=435)
#
# 	AE Loss: 31.455460, Monifold Loss: 262.811188, ColAE Loss: 359.969421
# Epoch 196/499	(J=435)
#
# 	AE Loss: 31.367094, Monifold Loss: 262.638275, ColAE Loss: 359.664948
# Epoch 197/499	(J=435)
#
# 	AE Loss: 31.285954, Monifold Loss: 262.509369, ColAE Loss: 359.422668
# Epoch 198/499	(J=435)
#
# 	AE Loss: 31.201336, Monifold Loss: 262.383209, ColAE Loss: 359.180328
# Epoch 199/499	(J=435)
#
# 	AE Loss: 31.112295, Monifold Loss: 262.316803, ColAE Loss: 359.008301
# Epoch 200/499	(J=435)
#
# 	AE Loss: 31.031008, Monifold Loss: 262.287537, ColAE Loss: 358.890442
# Epoch 201/499	(J=435)
#
# 	AE Loss: 30.950405, Monifold Loss: 262.223541, ColAE Loss: 358.729828
# Epoch 202/499	(J=435)
#
# 	AE Loss: 30.866468, Monifold Loss: 262.098175, ColAE Loss: 358.489166
# Epoch 203/499	(J=435)
#
# 	AE Loss: 30.784479, Monifold Loss: 262.015137, ColAE Loss: 358.303406
# Epoch 204/499	(J=435)
#
# 	AE Loss: 30.707134, Monifold Loss: 261.933716, ColAE Loss: 358.124268
# Epoch 205/499	(J=435)
#
# 	AE Loss: 30.628750, Monifold Loss: 261.835999, ColAE Loss: 357.923737
# Epoch 206/499	(J=435)
#
# 	AE Loss: 30.548962, Monifold Loss: 261.795013, ColAE Loss: 357.792725
# Epoch 207/499	(J=435)
#
# 	AE Loss: 30.473391, Monifold Loss: 261.734619, ColAE Loss: 357.641663
# Epoch 208/499	(J=435)
#
# 	AE Loss: 30.399515, Monifold Loss: 261.668610, ColAE Loss: 357.485260
# Epoch 209/499	(J=435)
#
# 	AE Loss: 30.323580, Monifold Loss: 261.589111, ColAE Loss: 357.309967
# Epoch 210/499	(J=435)
#
# 	AE Loss: 30.248838, Monifold Loss: 261.471069, ColAE Loss: 357.087677
# Epoch 211/499	(J=435)
#
# 	AE Loss: 30.177166, Monifold Loss: 261.350281, ColAE Loss: 356.865021
# Epoch 212/499	(J=435)
#
# 	AE Loss: 30.104361, Monifold Loss: 261.274658, ColAE Loss: 356.697693
# Epoch 213/499	(J=435)
#
# 	AE Loss: 30.031786, Monifold Loss: 261.200531, ColAE Loss: 356.532471
# Epoch 214/499	(J=435)
#
# 	AE Loss: 29.960732, Monifold Loss: 261.086609, ColAE Loss: 356.319000
# Epoch 215/499	(J=435)
#
# 	AE Loss: 29.890709, Monifold Loss: 261.009979, ColAE Loss: 356.153198
# Epoch 216/499	(J=435)
#
# 	AE Loss: 29.819719, Monifold Loss: 260.887634, ColAE Loss: 355.929291
# Epoch 217/499	(J=435)
#
# 	AE Loss: 29.748734, Monifold Loss: 260.774261, ColAE Loss: 355.716553
# Epoch 218/499	(J=435)
#
# 	AE Loss: 29.678917, Monifold Loss: 260.644226, ColAE Loss: 355.484222
# Epoch 219/499	(J=435)
#
# 	AE Loss: 29.608372, Monifold Loss: 260.524384, ColAE Loss: 355.263855
# Epoch 220/499	(J=435)
#
# 	AE Loss: 29.536911, Monifold Loss: 260.407562, ColAE Loss: 355.046387
# Epoch 221/499	(J=435)
#
# 	AE Loss: 29.465580, Monifold Loss: 260.307922, ColAE Loss: 354.850464
# Epoch 222/499	(J=435)
#
# 	AE Loss: 29.396120, Monifold Loss: 260.190094, ColAE Loss: 354.633728
# Epoch 223/499	(J=435)
#
# 	AE Loss: 29.330002, Monifold Loss: 260.064331, ColAE Loss: 354.410400
# Epoch 224/499	(J=435)
#
# 	AE Loss: 29.263588, Monifold Loss: 259.964478, ColAE Loss: 354.219177
# Epoch 225/499	(J=435)
#
# 	AE Loss: 29.196457, Monifold Loss: 259.805023, ColAE Loss: 353.952759
# Epoch 226/499	(J=435)
#
# 	AE Loss: 29.130793, Monifold Loss: 259.703705, ColAE Loss: 353.760437
# Epoch 227/499	(J=435)
#
# 	AE Loss: 29.067324, Monifold Loss: 259.530701, ColAE Loss: 353.480713
# Epoch 228/499	(J=435)
#
# 	AE Loss: 29.002138, Monifold Loss: 259.423523, ColAE Loss: 353.281555
# Epoch 229/499	(J=435)
#
# 	AE Loss: 28.937063, Monifold Loss: 259.300446, ColAE Loss: 353.062622
# Epoch 230/499	(J=435)
#
# 	AE Loss: 28.873728, Monifold Loss: 259.172852, ColAE Loss: 352.839783
# Epoch 231/499	(J=435)
#
# 	AE Loss: 28.812275, Monifold Loss: 259.038849, ColAE Loss: 352.610840
# Epoch 232/499	(J=435)
#
# 	AE Loss: 28.750771, Monifold Loss: 258.850555, ColAE Loss: 352.313965
# Epoch 233/499	(J=435)
#
# 	AE Loss: 28.690594, Monifold Loss: 258.724396, ColAE Loss: 352.096069
# Epoch 234/499	(J=435)
#
# 	AE Loss: 28.630405, Monifold Loss: 258.569855, ColAE Loss: 351.842712
# Epoch 235/499	(J=435)
#
# 	AE Loss: 28.570763, Monifold Loss: 258.452423, ColAE Loss: 351.636292
# Epoch 236/499	(J=435)
#
# 	AE Loss: 28.514166, Monifold Loss: 258.331604, ColAE Loss: 351.428650
# Epoch 237/499	(J=435)
#
# 	AE Loss: 28.456486, Monifold Loss: 258.203766, ColAE Loss: 351.211182
# Epoch 238/499	(J=435)
#
# 	AE Loss: 28.399174, Monifold Loss: 258.054474, ColAE Loss: 350.967255
# Epoch 239/499	(J=435)
#
# 	AE Loss: 28.343445, Monifold Loss: 257.889954, ColAE Loss: 350.705872
# Epoch 240/499	(J=435)
#
# 	AE Loss: 28.289209, Monifold Loss: 257.767334, ColAE Loss: 350.498383
# Epoch 241/499	(J=435)
#
# 	AE Loss: 28.236067, Monifold Loss: 257.631744, ColAE Loss: 350.275726
# Epoch 242/499	(J=435)
#
# 	AE Loss: 28.185675, Monifold Loss: 257.556610, ColAE Loss: 350.131439
# Epoch 243/499	(J=435)
#
# 	AE Loss: 28.131229, Monifold Loss: 257.341705, ColAE Loss: 349.808350
# Epoch 244/499	(J=435)
#
# 	AE Loss: 28.073376, Monifold Loss: 257.282257, ColAE Loss: 349.676178
# Epoch 245/499	(J=435)
#
# 	AE Loss: 28.020472, Monifold Loss: 257.128235, ColAE Loss: 349.430756
# Epoch 246/499	(J=435)
#
# 	AE Loss: 27.971285, Monifold Loss: 256.961517, ColAE Loss: 349.173187
# Epoch 247/499	(J=435)
#
# 	AE Loss: 27.917599, Monifold Loss: 256.905548, ColAE Loss: 349.049530
# Epoch 248/499	(J=435)
#
# 	AE Loss: 27.864164, Monifold Loss: 256.757965, ColAE Loss: 348.811615
# Epoch 249/499	(J=435)
#
# 	AE Loss: 27.816320, Monifold Loss: 256.607178, ColAE Loss: 348.575287
# Epoch 250/499	(J=435)
#
# 	AE Loss: 27.765774, Monifold Loss: 256.544495, ColAE Loss: 348.446381
# Epoch 251/499	(J=435)
#
# 	AE Loss: 27.713213, Monifold Loss: 256.395844, ColAE Loss: 348.208038
# Epoch 252/499	(J=435)
#
# 	AE Loss: 27.665499, Monifold Loss: 256.261169, ColAE Loss: 347.991974
# Epoch 253/499	(J=435)
#
# 	AE Loss: 27.618322, Monifold Loss: 256.199890, ColAE Loss: 347.868195
# Epoch 254/499	(J=435)
#
# 	AE Loss: 27.567322, Monifold Loss: 256.055023, ColAE Loss: 347.636108
# Epoch 255/499	(J=435)
#
# 	AE Loss: 27.520216, Monifold Loss: 255.952484, ColAE Loss: 347.460815
# Epoch 256/499	(J=435)
#
# 	AE Loss: 27.474218, Monifold Loss: 255.874146, ColAE Loss: 347.316895
# Epoch 257/499	(J=435)
#
# 	AE Loss: 27.425798, Monifold Loss: 255.737732, ColAE Loss: 347.097992
# Epoch 258/499	(J=435)
#
# 	AE Loss: 27.379158, Monifold Loss: 255.638779, ColAE Loss: 346.927612
# Epoch 259/499	(J=435)
#
# 	AE Loss: 27.334438, Monifold Loss: 255.571808, ColAE Loss: 346.799194
# Epoch 260/499	(J=435)
#
# 	AE Loss: 27.288183, Monifold Loss: 255.437653, ColAE Loss: 346.585236
# Epoch 261/499	(J=435)
#
# 	AE Loss: 27.242321, Monifold Loss: 255.346603, ColAE Loss: 346.425568
# Epoch 262/499	(J=435)
#
# 	AE Loss: 27.198614, Monifold Loss: 255.278534, ColAE Loss: 346.296783
# Epoch 263/499	(J=435)
#
# 	AE Loss: 27.154202, Monifold Loss: 255.140564, ColAE Loss: 346.079926
# Epoch 264/499	(J=435)
#
# 	AE Loss: 27.109709, Monifold Loss: 255.060944, ColAE Loss: 345.935883
# Epoch 265/499	(J=435)
#
# 	AE Loss: 27.066784, Monifold Loss: 254.969833, ColAE Loss: 345.779053
# Epoch 266/499	(J=435)
#
# 	AE Loss: 27.024033, Monifold Loss: 254.855255, ColAE Loss: 345.593079
# Epoch 267/499	(J=435)
#
# 	AE Loss: 26.980764, Monifold Loss: 254.779205, ColAE Loss: 345.454773
# Epoch 268/499	(J=435)
#
# 	AE Loss: 26.938356, Monifold Loss: 254.683395, ColAE Loss: 345.292603
# Epoch 269/499	(J=435)
#
# 	AE Loss: 26.896893, Monifold Loss: 254.570816, ColAE Loss: 345.110413
# Epoch 270/499	(J=435)
#
# 	AE Loss: 26.855183, Monifold Loss: 254.497986, ColAE Loss: 344.977692
# Epoch 271/499	(J=435)
#
# 	AE Loss: 26.813284, Monifold Loss: 254.388367, ColAE Loss: 344.798767
# Epoch 272/499	(J=435)
#
# 	AE Loss: 26.772840, Monifold Loss: 254.282013, ColAE Loss: 344.625336
# Epoch 273/499	(J=435)
#
# 	AE Loss: 26.732328, Monifold Loss: 254.212204, ColAE Loss: 344.497589
# Epoch 274/499	(J=435)
#
# 	AE Loss: 26.691788, Monifold Loss: 254.100143, ColAE Loss: 344.316956
# Epoch 275/499	(J=435)
#
# 	AE Loss: 26.651804, Monifold Loss: 254.010422, ColAE Loss: 344.164825
# Epoch 276/499	(J=435)
#
# 	AE Loss: 26.612442, Monifold Loss: 253.920654, ColAE Loss: 344.013245
# Epoch 277/499	(J=435)
#
# 	AE Loss: 26.573118, Monifold Loss: 253.815491, ColAE Loss: 343.842468
# Epoch 278/499	(J=435)
#
# 	AE Loss: 26.533964, Monifold Loss: 253.722961, ColAE Loss: 343.687653
# Epoch 279/499	(J=435)
#
# 	AE Loss: 26.495787, Monifold Loss: 253.631653, ColAE Loss: 343.535339
# Epoch 280/499	(J=435)
#
# 	AE Loss: 26.457481, Monifold Loss: 253.524704, ColAE Loss: 343.363373
# Epoch 281/499	(J=435)
#
# 	AE Loss: 26.419420, Monifold Loss: 253.444458, ColAE Loss: 343.225006
# Epoch 282/499	(J=435)
#
# 	AE Loss: 26.381334, Monifold Loss: 253.348526, ColAE Loss: 343.067017
# Epoch 283/499	(J=435)
#
# 	AE Loss: 26.344042, Monifold Loss: 253.244308, ColAE Loss: 342.899445
# Epoch 284/499	(J=435)
#
# 	AE Loss: 26.306793, Monifold Loss: 253.160095, ColAE Loss: 342.756927
# Epoch 285/499	(J=435)
#
# 	AE Loss: 26.269789, Monifold Loss: 253.057388, ColAE Loss: 342.591522
# Epoch 286/499	(J=435)
#
# 	AE Loss: 26.232973, Monifold Loss: 252.964310, ColAE Loss: 342.438354
# Epoch 287/499	(J=435)
#
# 	AE Loss: 26.196714, Monifold Loss: 252.871109, ColAE Loss: 342.285614
# Epoch 288/499	(J=435)
#
# 	AE Loss: 26.160540, Monifold Loss: 252.774078, ColAE Loss: 342.128143
# Epoch 289/499	(J=435)
#
# 	AE Loss: 26.124203, Monifold Loss: 252.694229, ColAE Loss: 341.992004
# Epoch 290/499	(J=435)
#
# 	AE Loss: 26.087898, Monifold Loss: 252.588974, ColAE Loss: 341.824097
# Epoch 291/499	(J=435)
#
# 	AE Loss: 26.051594, Monifold Loss: 252.499573, ColAE Loss: 341.676056
# Epoch 292/499	(J=435)
#
# 	AE Loss: 26.015776, Monifold Loss: 252.413177, ColAE Loss: 341.532257
# Epoch 293/499	(J=435)
#
# 	AE Loss: 25.980618, Monifold Loss: 252.304749, ColAE Loss: 341.361542
# Epoch 294/499	(J=435)
#
# 	AE Loss: 25.945749, Monifold Loss: 252.226074, ColAE Loss: 341.228333
# Epoch 295/499	(J=435)
#
# 	AE Loss: 25.912060, Monifold Loss: 252.120453, ColAE Loss: 341.062622
# Epoch 296/499	(J=435)
#
# 	AE Loss: 25.877747, Monifold Loss: 252.040176, ColAE Loss: 340.927979
# Epoch 297/499	(J=435)
#
# 	AE Loss: 25.843863, Monifold Loss: 251.923050, ColAE Loss: 340.747681
# Epoch 298/499	(J=435)
#
# 	AE Loss: 25.810698, Monifold Loss: 251.828476, ColAE Loss: 340.596283
# Epoch 299/499	(J=435)
#
# 	AE Loss: 25.777889, Monifold Loss: 251.734467, ColAE Loss: 340.445984
# Epoch 300/499	(J=435)
#
# 	AE Loss: 25.745029, Monifold Loss: 251.639236, ColAE Loss: 340.294067
# Epoch 301/499	(J=435)
#
# 	AE Loss: 25.712580, Monifold Loss: 251.543228, ColAE Loss: 340.141632
# Epoch 302/499	(J=435)
#
# 	AE Loss: 25.680546, Monifold Loss: 251.448563, ColAE Loss: 339.991241
# Epoch 303/499	(J=435)
#
# 	AE Loss: 25.648554, Monifold Loss: 251.357407, ColAE Loss: 339.845306
# Epoch 304/499	(J=435)
#
# 	AE Loss: 25.617088, Monifold Loss: 251.264786, ColAE Loss: 339.698090
# Epoch 305/499	(J=435)
#
# 	AE Loss: 25.585951, Monifold Loss: 251.172089, ColAE Loss: 339.551056
# Epoch 306/499	(J=435)
#
# 	AE Loss: 25.554955, Monifold Loss: 251.083817, ColAE Loss: 339.409729
# Epoch 307/499	(J=435)
#
# 	AE Loss: 25.524368, Monifold Loss: 251.006592, ColAE Loss: 339.282593
# Epoch 308/499	(J=435)
#
# 	AE Loss: 25.493969, Monifold Loss: 250.922363, ColAE Loss: 339.146912
# Epoch 309/499	(J=435)
#
# 	AE Loss: 25.463432, Monifold Loss: 250.835617, ColAE Loss: 339.007965
# Epoch 310/499	(J=435)
#
# 	AE Loss: 25.433222, Monifold Loss: 250.760788, ColAE Loss: 338.884216
# Epoch 311/499	(J=435)
#
# 	AE Loss: 25.403551, Monifold Loss: 250.668274, ColAE Loss: 338.738892
# Epoch 312/499	(J=435)
#
# 	AE Loss: 25.374243, Monifold Loss: 250.604462, ColAE Loss: 338.629822
# Epoch 313/499	(J=435)
#
# 	AE Loss: 25.345123, Monifold Loss: 250.511276, ColAE Loss: 338.484222
# Epoch 314/499	(J=435)
#
# 	AE Loss: 25.316189, Monifold Loss: 250.457352, ColAE Loss: 338.387878
# Epoch 315/499	(J=435)
#
# 	AE Loss: 25.287527, Monifold Loss: 250.378357, ColAE Loss: 338.260498
# Epoch 316/499	(J=435)
#
# 	AE Loss: 25.259146, Monifold Loss: 250.316299, ColAE Loss: 338.154541
# Epoch 317/499	(J=435)
#
# 	AE Loss: 25.230764, Monifold Loss: 250.235092, ColAE Loss: 338.024628
# Epoch 318/499	(J=435)
#
# 	AE Loss: 25.202816, Monifold Loss: 250.164536, ColAE Loss: 337.908478
# Epoch 319/499	(J=435)
#
# 	AE Loss: 25.175089, Monifold Loss: 250.085938, ColAE Loss: 337.782501
# Epoch 320/499	(J=435)
#
# 	AE Loss: 25.147440, Monifold Loss: 250.019150, ColAE Loss: 337.671356
# Epoch 321/499	(J=435)
#
# 	AE Loss: 25.120144, Monifold Loss: 249.951614, ColAE Loss: 337.559662
# Epoch 322/499	(J=435)
#
# 	AE Loss: 25.093082, Monifold Loss: 249.885406, ColAE Loss: 337.449829
# Epoch 323/499	(J=435)
#
# 	AE Loss: 25.065868, Monifold Loss: 249.819275, ColAE Loss: 337.339966
# Epoch 324/499	(J=435)
#
# 	AE Loss: 25.039257, Monifold Loss: 249.739426, ColAE Loss: 337.213531
# Epoch 325/499	(J=435)
#
# 	AE Loss: 25.012949, Monifold Loss: 249.672974, ColAE Loss: 337.104156
# Epoch 326/499	(J=435)
#
# 	AE Loss: 24.986731, Monifold Loss: 249.592773, ColAE Loss: 336.977692
# Epoch 327/499	(J=435)
#
# 	AE Loss: 24.960581, Monifold Loss: 249.526657, ColAE Loss: 336.868896
# Epoch 328/499	(J=435)
#
# 	AE Loss: 24.934645, Monifold Loss: 249.454132, ColAE Loss: 336.752289
# Epoch 329/499	(J=435)
#
# 	AE Loss: 24.908825, Monifold Loss: 249.382812, ColAE Loss: 336.637329
# Epoch 330/499	(J=435)
#
# 	AE Loss: 24.883427, Monifold Loss: 249.312012, ColAE Loss: 336.523438
# Epoch 331/499	(J=435)
#
# 	AE Loss: 24.858227, Monifold Loss: 249.229935, ColAE Loss: 336.395630
# Epoch 332/499	(J=435)
#
# 	AE Loss: 24.833334, Monifold Loss: 249.156113, ColAE Loss: 336.278473
# Epoch 333/499	(J=435)
#
# 	AE Loss: 24.808437, Monifold Loss: 249.076370, ColAE Loss: 336.153900
# Epoch 334/499	(J=435)
#
# 	AE Loss: 24.783602, Monifold Loss: 249.001801, ColAE Loss: 336.035858
# Epoch 335/499	(J=435)
#
# 	AE Loss: 24.758900, Monifold Loss: 248.925568, ColAE Loss: 335.915863
# Epoch 336/499	(J=435)
#
# 	AE Loss: 24.734533, Monifold Loss: 248.847824, ColAE Loss: 335.794312
# Epoch 337/499	(J=435)
#
# 	AE Loss: 24.710382, Monifold Loss: 248.771225, ColAE Loss: 335.674408
# Epoch 338/499	(J=435)
#
# 	AE Loss: 24.686531, Monifold Loss: 248.691269, ColAE Loss: 335.550598
# Epoch 339/499	(J=435)
#
# 	AE Loss: 24.662868, Monifold Loss: 248.611786, ColAE Loss: 335.427612
# Epoch 340/499	(J=435)
#
# 	AE Loss: 24.639133, Monifold Loss: 248.533554, ColAE Loss: 335.306061
# Epoch 341/499	(J=435)
#
# 	AE Loss: 24.615646, Monifold Loss: 248.456360, ColAE Loss: 335.186096
# Epoch 342/499	(J=435)
#
# 	AE Loss: 24.592392, Monifold Loss: 248.379486, ColAE Loss: 335.066772
# Epoch 343/499	(J=435)
#
# 	AE Loss: 24.569363, Monifold Loss: 248.302658, ColAE Loss: 334.947693
# Epoch 344/499	(J=435)
#
# 	AE Loss: 24.546522, Monifold Loss: 248.221481, ColAE Loss: 334.823364
# Epoch 345/499	(J=435)
#
# 	AE Loss: 24.523968, Monifold Loss: 248.142181, ColAE Loss: 334.701691
# Epoch 346/499	(J=435)
#
# 	AE Loss: 24.501465, Monifold Loss: 248.060928, ColAE Loss: 334.577637
# Epoch 347/499	(J=435)
#
# 	AE Loss: 24.479347, Monifold Loss: 247.981079, ColAE Loss: 334.455688
# Epoch 348/499	(J=435)
#
# 	AE Loss: 24.457125, Monifold Loss: 247.905273, ColAE Loss: 334.338715
# Epoch 349/499	(J=435)
#
# 	AE Loss: 24.435287, Monifold Loss: 247.825424, ColAE Loss: 334.217041
# Epoch 350/499	(J=435)
#
# 	AE Loss: 24.413656, Monifold Loss: 247.747894, ColAE Loss: 334.098541
# Epoch 351/499	(J=435)
#
# 	AE Loss: 24.392126, Monifold Loss: 247.667999, ColAE Loss: 333.977112
# Epoch 352/499	(J=435)
#
# 	AE Loss: 24.370634, Monifold Loss: 247.587601, ColAE Loss: 333.855133
# Epoch 353/499	(J=435)
#
# 	AE Loss: 24.349644, Monifold Loss: 247.509872, ColAE Loss: 333.736969
# Epoch 354/499	(J=435)
#
# 	AE Loss: 24.328575, Monifold Loss: 247.429398, ColAE Loss: 333.615326
# Epoch 355/499	(J=435)
#
# 	AE Loss: 24.307779, Monifold Loss: 247.352692, ColAE Loss: 333.498627
# Epoch 356/499	(J=435)
#
# 	AE Loss: 24.287292, Monifold Loss: 247.272049, ColAE Loss: 333.377350
# Epoch 357/499	(J=435)
#
# 	AE Loss: 24.266783, Monifold Loss: 247.197174, ColAE Loss: 333.263245
# Epoch 358/499	(J=435)
#
# 	AE Loss: 24.246349, Monifold Loss: 247.115570, ColAE Loss: 333.140808
# Epoch 359/499	(J=435)
#
# 	AE Loss: 24.226353, Monifold Loss: 247.037415, ColAE Loss: 333.023102
# Epoch 360/499	(J=435)
#
# 	AE Loss: 24.206509, Monifold Loss: 246.962234, ColAE Loss: 332.909302
# Epoch 361/499	(J=435)
#
# 	AE Loss: 24.186914, Monifold Loss: 246.883087, ColAE Loss: 332.790771
# Epoch 362/499	(J=435)
#
# 	AE Loss: 24.167183, Monifold Loss: 246.806488, ColAE Loss: 332.675293
# Epoch 363/499	(J=435)
#
# 	AE Loss: 24.147823, Monifold Loss: 246.733841, ColAE Loss: 332.565125
# Epoch 364/499	(J=435)
#
# 	AE Loss: 24.128588, Monifold Loss: 246.654037, ColAE Loss: 332.446136
# Epoch 365/499	(J=435)
#
# 	AE Loss: 24.109632, Monifold Loss: 246.579056, ColAE Loss: 332.333435
# Epoch 366/499	(J=435)
#
# 	AE Loss: 24.090523, Monifold Loss: 246.504105, ColAE Loss: 332.220642
# Epoch 367/499	(J=435)
#
# 	AE Loss: 24.071812, Monifold Loss: 246.426285, ColAE Loss: 332.104675
# Epoch 368/499	(J=435)
#
# 	AE Loss: 24.053106, Monifold Loss: 246.354965, ColAE Loss: 331.996796
# Epoch 369/499	(J=435)
#
# 	AE Loss: 24.034832, Monifold Loss: 246.281189, ColAE Loss: 331.886322
# Epoch 370/499	(J=435)
#
# 	AE Loss: 24.016670, Monifold Loss: 246.208496, ColAE Loss: 331.777283
# Epoch 371/499	(J=435)
#
# 	AE Loss: 23.998713, Monifold Loss: 246.135040, ColAE Loss: 331.667511
# Epoch 372/499	(J=435)
#
# 	AE Loss: 23.981079, Monifold Loss: 246.066376, ColAE Loss: 331.564056
# Epoch 373/499	(J=435)
#
# 	AE Loss: 23.963373, Monifold Loss: 245.988739, ColAE Loss: 331.449310
# Epoch 374/499	(J=435)
#
# 	AE Loss: 23.945873, Monifold Loss: 245.921310, ColAE Loss: 331.347504
# Epoch 375/499	(J=435)
#
# 	AE Loss: 23.928581, Monifold Loss: 245.850235, ColAE Loss: 331.241394
# Epoch 376/499	(J=435)
#
# 	AE Loss: 23.911455, Monifold Loss: 245.775848, ColAE Loss: 331.131287
# Epoch 377/499	(J=435)
#
# 	AE Loss: 23.894514, Monifold Loss: 245.711029, ColAE Loss: 331.033295
# Epoch 378/499	(J=435)
#
# 	AE Loss: 23.877630, Monifold Loss: 245.639572, ColAE Loss: 330.927094
# Epoch 379/499	(J=435)
#
# 	AE Loss: 23.861013, Monifold Loss: 245.570206, ColAE Loss: 330.823792
# Epoch 380/499	(J=435)
#
# 	AE Loss: 23.844564, Monifold Loss: 245.506271, ColAE Loss: 330.727417
# Epoch 381/499	(J=435)
#
# 	AE Loss: 23.828381, Monifold Loss: 245.436264, ColAE Loss: 330.623688
# Epoch 382/499	(J=435)
#
# 	AE Loss: 23.812183, Monifold Loss: 245.371445, ColAE Loss: 330.526489
# Epoch 383/499	(J=435)
#
# 	AE Loss: 23.796125, Monifold Loss: 245.308151, ColAE Loss: 330.431305
# Epoch 384/499	(J=435)
#
# 	AE Loss: 23.780220, Monifold Loss: 245.241669, ColAE Loss: 330.332306
# Epoch 385/499	(J=435)
#
# 	AE Loss: 23.764507, Monifold Loss: 245.180237, ColAE Loss: 330.239777
# Epoch 386/499	(J=435)
#
# 	AE Loss: 23.748804, Monifold Loss: 245.117401, ColAE Loss: 330.145569
# Epoch 387/499	(J=435)
#
# 	AE Loss: 23.733370, Monifold Loss: 245.054031, ColAE Loss: 330.050903
# Epoch 388/499	(J=435)
#
# 	AE Loss: 23.718130, Monifold Loss: 244.995132, ColAE Loss: 329.962067
# Epoch 389/499	(J=435)
#
# 	AE Loss: 23.703074, Monifold Loss: 244.933548, ColAE Loss: 329.869995
# Epoch 390/499	(J=435)
#
# 	AE Loss: 23.688210, Monifold Loss: 244.873901, ColAE Loss: 329.780579
# Epoch 391/499	(J=435)
#
# 	AE Loss: 23.673544, Monifold Loss: 244.817307, ColAE Loss: 329.695190
# Epoch 392/499	(J=435)
#
# 	AE Loss: 23.658901, Monifold Loss: 244.757874, ColAE Loss: 329.606232
# Epoch 393/499	(J=435)
#
# 	AE Loss: 23.644667, Monifold Loss: 244.701370, ColAE Loss: 329.521362
# Epoch 394/499	(J=435)
#
# 	AE Loss: 23.630438, Monifold Loss: 244.646103, ColAE Loss: 329.438049
# Epoch 395/499	(J=435)
#
# 	AE Loss: 23.616051, Monifold Loss: 244.588608, ColAE Loss: 329.351807
# Epoch 396/499	(J=435)
#
# 	AE Loss: 23.601988, Monifold Loss: 244.534439, ColAE Loss: 329.270050
# Epoch 397/499	(J=435)
#
# 	AE Loss: 23.588337, Monifold Loss: 244.480698, ColAE Loss: 329.189209
# Epoch 398/499	(J=435)
#
# 	AE Loss: 23.574642, Monifold Loss: 244.425797, ColAE Loss: 329.106903
# Epoch 399/499	(J=435)
#
# 	AE Loss: 23.561119, Monifold Loss: 244.374023, ColAE Loss: 329.028656
# Epoch 400/499	(J=435)
#
# 	AE Loss: 23.547760, Monifold Loss: 244.322220, ColAE Loss: 328.950531
# Epoch 401/499	(J=435)
#
# 	AE Loss: 23.534601, Monifold Loss: 244.269867, ColAE Loss: 328.871948
# Epoch 402/499	(J=435)
#
# 	AE Loss: 23.521439, Monifold Loss: 244.219635, ColAE Loss: 328.795959
# Epoch 403/499	(J=435)
#
# 	AE Loss: 23.508591, Monifold Loss: 244.169281, ColAE Loss: 328.720215
# Epoch 404/499	(J=435)
#
# 	AE Loss: 23.495888, Monifold Loss: 244.119171, ColAE Loss: 328.644836
# Epoch 405/499	(J=435)
#
# 	AE Loss: 23.483236, Monifold Loss: 244.070847, ColAE Loss: 328.571808
# Epoch 406/499	(J=435)
#
# 	AE Loss: 23.470663, Monifold Loss: 244.022186, ColAE Loss: 328.498413
# Epoch 407/499	(J=435)
#
# 	AE Loss: 23.458237, Monifold Loss: 243.974472, ColAE Loss: 328.426331
# Epoch 408/499	(J=435)
#
# 	AE Loss: 23.446157, Monifold Loss: 243.927612, ColAE Loss: 328.355682
# Epoch 409/499	(J=435)
#
# 	AE Loss: 23.434099, Monifold Loss: 243.880630, ColAE Loss: 328.284912
# Epoch 410/499	(J=435)
#
# 	AE Loss: 23.422203, Monifold Loss: 243.834702, ColAE Loss: 328.215576
# Epoch 411/499	(J=435)
#
# 	AE Loss: 23.410496, Monifold Loss: 243.789490, ColAE Loss: 328.147369
# Epoch 412/499	(J=435)
#
# 	AE Loss: 23.398882, Monifold Loss: 243.744171, ColAE Loss: 328.079102
# Epoch 413/499	(J=435)
#
# 	AE Loss: 23.387426, Monifold Loss: 243.699646, ColAE Loss: 328.011993
# Epoch 414/499	(J=435)
#
# 	AE Loss: 23.376108, Monifold Loss: 243.656082, ColAE Loss: 327.946198
# Epoch 415/499	(J=435)
#
# 	AE Loss: 23.365053, Monifold Loss: 243.612518, ColAE Loss: 327.880707
# Epoch 416/499	(J=435)
#
# 	AE Loss: 23.353981, Monifold Loss: 243.569672, ColAE Loss: 327.816071
# Epoch 417/499	(J=435)
#
# 	AE Loss: 23.343014, Monifold Loss: 243.527679, ColAE Loss: 327.752625
# Epoch 418/499	(J=435)
#
# 	AE Loss: 23.332262, Monifold Loss: 243.485413, ColAE Loss: 327.689026
# Epoch 419/499	(J=435)
#
# 	AE Loss: 23.321486, Monifold Loss: 243.444183, ColAE Loss: 327.626709
# Epoch 420/499	(J=435)
#
# 	AE Loss: 23.310970, Monifold Loss: 243.403549, ColAE Loss: 327.565399
# Epoch 421/499	(J=435)
#
# 	AE Loss: 23.300764, Monifold Loss: 243.363235, ColAE Loss: 327.504791
# Epoch 422/499	(J=435)
#
# 	AE Loss: 23.290548, Monifold Loss: 243.323456, ColAE Loss: 327.444885
# Epoch 423/499	(J=435)
#
# 	AE Loss: 23.280489, Monifold Loss: 243.284302, ColAE Loss: 327.385864
# Epoch 424/499	(J=435)
#
# 	AE Loss: 23.270647, Monifold Loss: 243.245621, ColAE Loss: 327.327698
# Epoch 425/499	(J=435)
#
# 	AE Loss: 23.260862, Monifold Loss: 243.207336, ColAE Loss: 327.270020
# Epoch 426/499	(J=435)
#
# 	AE Loss: 23.251190, Monifold Loss: 243.169708, ColAE Loss: 327.213318
# Epoch 427/499	(J=435)
#
# 	AE Loss: 23.241720, Monifold Loss: 243.132645, ColAE Loss: 327.157532
# Epoch 428/499	(J=435)
#
# 	AE Loss: 23.232470, Monifold Loss: 243.095993, ColAE Loss: 327.102478
# Epoch 429/499	(J=435)
#
# 	AE Loss: 23.223207, Monifold Loss: 243.059723, ColAE Loss: 327.047852
# Epoch 430/499	(J=435)
#
# 	AE Loss: 23.214022, Monifold Loss: 243.024017, ColAE Loss: 326.994049
# Epoch 431/499	(J=435)
#
# 	AE Loss: 23.205013, Monifold Loss: 242.988770, ColAE Loss: 326.940979
# Epoch 432/499	(J=435)
#
# 	AE Loss: 23.196070, Monifold Loss: 242.954300, ColAE Loss: 326.888947
# Epoch 433/499	(J=435)
#
# 	AE Loss: 23.187403, Monifold Loss: 242.920227, ColAE Loss: 326.837677
# Epoch 434/499	(J=435)
#
# 	AE Loss: 23.178944, Monifold Loss: 242.886459, ColAE Loss: 326.787018
# Epoch 435/499	(J=435)
#
# 	AE Loss: 23.170532, Monifold Loss: 242.853287, ColAE Loss: 326.737152
# Epoch 436/499	(J=435)
#
# 	AE Loss: 23.162161, Monifold Loss: 242.820709, ColAE Loss: 326.688049
# Epoch 437/499	(J=435)
#
# 	AE Loss: 23.154106, Monifold Loss: 242.788528, ColAE Loss: 326.639771
# Epoch 438/499	(J=435)
#
# 	AE Loss: 23.146080, Monifold Loss: 242.756790, ColAE Loss: 326.592072
# Epoch 439/499	(J=435)
#
# 	AE Loss: 23.138256, Monifold Loss: 242.725708, ColAE Loss: 326.545380
# Epoch 440/499	(J=435)
#
# 	AE Loss: 23.130503, Monifold Loss: 242.695175, ColAE Loss: 326.499451
# Epoch 441/499	(J=435)
#
# 	AE Loss: 23.122690, Monifold Loss: 242.665039, ColAE Loss: 326.453979
# Epoch 442/499	(J=435)
#
# 	AE Loss: 23.115242, Monifold Loss: 242.635391, ColAE Loss: 326.409485
# Epoch 443/499	(J=435)
#
# 	AE Loss: 23.107798, Monifold Loss: 242.606430, ColAE Loss: 326.365814
# Epoch 444/499	(J=435)
#
# 	AE Loss: 23.100653, Monifold Loss: 242.577774, ColAE Loss: 326.322876
# Epoch 445/499	(J=435)
#
# 	AE Loss: 23.093420, Monifold Loss: 242.549622, ColAE Loss: 326.280426
# Epoch 446/499	(J=435)
#
# 	AE Loss: 23.086479, Monifold Loss: 242.522125, ColAE Loss: 326.239136
# Epoch 447/499	(J=435)
#
# 	AE Loss: 23.079685, Monifold Loss: 242.495193, ColAE Loss: 326.198669
# Epoch 448/499	(J=435)
#
# 	AE Loss: 23.073004, Monifold Loss: 242.468765, ColAE Loss: 326.158966
# Epoch 449/499	(J=435)
#
# 	AE Loss: 23.066532, Monifold Loss: 242.442688, ColAE Loss: 326.119873
# Epoch 450/499	(J=435)
#
# 	AE Loss: 23.060038, Monifold Loss: 242.417084, ColAE Loss: 326.081390
# Epoch 451/499	(J=435)
#
# 	AE Loss: 23.053707, Monifold Loss: 242.392380, ColAE Loss: 326.044189
# Epoch 452/499	(J=435)
#
# 	AE Loss: 23.047590, Monifold Loss: 242.367905, ColAE Loss: 326.007446
# Epoch 453/499	(J=435)
#
# 	AE Loss: 23.041586, Monifold Loss: 242.344208, ColAE Loss: 325.971863
# Epoch 454/499	(J=435)
#
# 	AE Loss: 23.035654, Monifold Loss: 242.321014, ColAE Loss: 325.936920
# Epoch 455/499	(J=435)
#
# 	AE Loss: 23.029867, Monifold Loss: 242.298080, ColAE Loss: 325.902466
# Epoch 456/499	(J=435)
#
# 	AE Loss: 23.024164, Monifold Loss: 242.275909, ColAE Loss: 325.869049
# Epoch 457/499	(J=435)
#
# 	AE Loss: 23.018776, Monifold Loss: 242.254318, ColAE Loss: 325.836670
# Epoch 458/499	(J=435)
#
# 	AE Loss: 23.013565, Monifold Loss: 242.233109, ColAE Loss: 325.804932
# Epoch 459/499	(J=435)
#
# 	AE Loss: 23.008341, Monifold Loss: 242.212540, ColAE Loss: 325.774017
# Epoch 460/499	(J=435)
#
# 	AE Loss: 23.003359, Monifold Loss: 242.192337, ColAE Loss: 325.743774
# Epoch 461/499	(J=435)
#
# 	AE Loss: 22.998486, Monifold Loss: 242.172852, ColAE Loss: 325.714539
# Epoch 462/499	(J=435)
#
# 	AE Loss: 22.993704, Monifold Loss: 242.153931, ColAE Loss: 325.686127
# Epoch 463/499	(J=435)
#
# 	AE Loss: 22.989128, Monifold Loss: 242.135437, ColAE Loss: 325.658447
# Epoch 464/499	(J=435)
#
# 	AE Loss: 22.984697, Monifold Loss: 242.117523, ColAE Loss: 325.631622
# Epoch 465/499	(J=435)
#
# 	AE Loss: 22.980328, Monifold Loss: 242.100113, ColAE Loss: 325.605469
# Epoch 466/499	(J=435)
#
# 	AE Loss: 22.976021, Monifold Loss: 242.083389, ColAE Loss: 325.580261
# Epoch 467/499	(J=435)
#
# 	AE Loss: 22.971823, Monifold Loss: 242.066956, ColAE Loss: 325.555511
# Epoch 468/499	(J=435)
#
# 	AE Loss: 22.967867, Monifold Loss: 242.051193, ColAE Loss: 325.531860
# Epoch 469/499	(J=435)
#
# 	AE Loss: 22.964062, Monifold Loss: 242.036026, ColAE Loss: 325.509094
# Epoch 470/499	(J=435)
#
# 	AE Loss: 22.960295, Monifold Loss: 242.021317, ColAE Loss: 325.486938
# Epoch 471/499	(J=435)
#
# 	AE Loss: 22.956675, Monifold Loss: 242.007111, ColAE Loss: 325.465546
# Epoch 472/499	(J=435)
#
# 	AE Loss: 22.953262, Monifold Loss: 241.993469, ColAE Loss: 325.445068
# Epoch 473/499	(J=435)
#
# 	AE Loss: 22.949898, Monifold Loss: 241.980438, ColAE Loss: 325.425446
# Epoch 474/499	(J=435)
#
# 	AE Loss: 22.946758, Monifold Loss: 241.967926, ColAE Loss: 325.406647
# Epoch 475/499	(J=435)
#
# 	AE Loss: 22.943668, Monifold Loss: 241.955872, ColAE Loss: 325.388489
# Epoch 476/499	(J=435)
#
# 	AE Loss: 22.940725, Monifold Loss: 241.944489, ColAE Loss: 325.371338
# Epoch 477/499	(J=435)
#
# 	AE Loss: 22.937963, Monifold Loss: 241.933578, ColAE Loss: 325.354919
# Epoch 478/499	(J=435)
#
# 	AE Loss: 22.935364, Monifold Loss: 241.923218, ColAE Loss: 325.339386
# Epoch 479/499	(J=435)
#
# 	AE Loss: 22.932947, Monifold Loss: 241.913406, ColAE Loss: 325.324707
# Epoch 480/499	(J=435)
#
# 	AE Loss: 22.930656, Monifold Loss: 241.904144, ColAE Loss: 325.310852
# Epoch 481/499	(J=435)
#
# 	AE Loss: 22.928425, Monifold Loss: 241.895462, ColAE Loss: 325.297760
# Epoch 482/499	(J=435)
#
# 	AE Loss: 22.926413, Monifold Loss: 241.887314, ColAE Loss: 325.285553
# Epoch 483/499	(J=435)
#
# 	AE Loss: 22.924421, Monifold Loss: 241.879562, ColAE Loss: 325.273865
# Epoch 484/499	(J=435)
#
# 	AE Loss: 22.922686, Monifold Loss: 241.872482, ColAE Loss: 325.263306
# Epoch 485/499	(J=435)
#
# 	AE Loss: 22.920986, Monifold Loss: 241.866104, ColAE Loss: 325.253632
# Epoch 486/499	(J=435)
#
# 	AE Loss: 22.919552, Monifold Loss: 241.860046, ColAE Loss: 325.244629
# Epoch 487/499	(J=435)
#
# 	AE Loss: 22.918207, Monifold Loss: 241.854553, ColAE Loss: 325.236389
# Epoch 488/499	(J=435)
#
# 	AE Loss: 22.916954, Monifold Loss: 241.849503, ColAE Loss: 325.228851
# Epoch 489/499	(J=435)
#
# 	AE Loss: 22.915880, Monifold Loss: 241.845200, ColAE Loss: 325.222382
# Epoch 490/499	(J=435)
#
# 	AE Loss: 22.914881, Monifold Loss: 241.841385, ColAE Loss: 325.216614
# Epoch 491/499	(J=435)
#
# 	AE Loss: 22.914085, Monifold Loss: 241.838150, ColAE Loss: 325.211792
# Epoch 492/499	(J=435)
#
# 	AE Loss: 22.913370, Monifold Loss: 241.835388, ColAE Loss: 325.207611
# Epoch 493/499	(J=435)
#
# 	AE Loss: 22.912786, Monifold Loss: 241.833206, ColAE Loss: 325.204285
# Epoch 494/499	(J=435)
#
# 	AE Loss: 22.912348, Monifold Loss: 241.831589, ColAE Loss: 325.201843
# Epoch 495/499	(J=435)
#
# 	AE Loss: 22.912056, Monifold Loss: 241.830460, ColAE Loss: 325.200134
# Epoch 496/499	(J=435)
#
# 	AE Loss: 22.911898, Monifold Loss: 241.829910, ColAE Loss: 325.199280
# Epoch 497/499	(J=435)
#
# 	AE Loss: 22.911747, Monifold Loss: 241.829407, ColAE Loss: 325.198486
# Epoch 498/499	(J=435)
#
# 	AE Loss: 22.911612, Monifold Loss: 241.828842, ColAE Loss: 325.197662
# Epoch 499/499	(J=435)
#
# 	AE Loss: 22.911476, Monifold Loss: 241.828247, ColAE Loss: 325.196777
# Running time of ColAE is 51774.17552113533

# %%
# %cd ~/BachelorResearch/ColAE
img_save_path = data_name
# Out:
# /home/zennakamura/BachelorResearch/ColAE

# %%
#with open(os.path.join(img_save_path, 'info_dadaptation.txt'),'a') as f_dadaptation:
    #for i in range(J):
        #f_dadaptation.write(f'{i}-th Params')
        #f_dadaptation.write(f'{optimizer[i].param_groups}')
        #f_dadaptation.write('\n')

#
with open(os.path.join(img_save_path, 'info.txt'),'a') as f:
    f.write(f'Number of Epoch (J) = {J}, L={L}, K={K}, eta={eta}\n')
    for i in range(epochs):
        f.write(f'Epoch {i}: AE Loss: {plot_AE_loss[i]}, Monifold Loss: {plot_monifold_loss[i]}')
        f.write('\n')
    f.write(f'Running time: {time_diff}')

# %%
# Auto-Encoder plot
fig, ax = plt.subplots()
t = np.linspace(0,epochs,epochs)
ax.set_xlabel('Epoch')
ax.set_ylabel('AE loss')
ax.grid()
ax.plot(t, plot_AE_loss)
fig.tight_layout()
plt.savefig(os.path.join(img_save_path, f'AE_loss.pdf'))
plt.show()

# %%
# Monifolod loss plot
fig, ax = plt.subplots()
t = np.linspace(0,epochs,epochs)
ax.set_xlabel('Epoch')
ax.set_ylabel('Monifolod loss')
ax.grid()
ax.plot(t, plot_monifold_loss)
fig.tight_layout()
plt.savefig(os.path.join(img_save_path, f'monifold_loss.pdf'))
plt.show()

# %%
# from IPython.display import display
# from torchviz import make_dot

# g = make_dot(loss, params={'input': input})

# 自動微分monifoldの部分もできているはず...
print(f'y_ik[0]: {mu_y[0].grad}')
print(f'y_ik[0]: {y_ik[0].grad}')
print(f'AE_loss_: {AE_loss_.grad}')
print(f'AE_loss: {AE_loss.grad}')
print(f'monifold_loss_: {monifold_loss_.grad}')
print(f'monifold_loss: {monifold_loss.grad}')
print(f'loss: {loss.grad}')
# Out:
# y_ik[0]: tensor([-0.0208, -0.0932, -0.0169, -0.0492, -0.0115,  0.0052, -0.0406,  0.0276,
#          0.0241,  0.0008,  0.0028,  0.0130,  0.0198, -0.0162, -0.0075, -0.0073,
#          0.0006, -0.0217,  0.0074, -0.0397,  0.0028, -0.0026,  0.0346, -0.0340,
#          0.0278, -0.0490,  0.0466, -0.0434,  0.0361,  0.0365], device='cuda:0')
# y_ik[0]: tensor([ 0.0208,  0.0932,  0.0169,  0.0492,  0.0115, -0.0052,  0.0406, -0.0276,
#         -0.0241, -0.0008, -0.0028, -0.0130, -0.0198,  0.0162,  0.0075,  0.0073,
#         -0.0006,  0.0217, -0.0074,  0.0397, -0.0028,  0.0026, -0.0346,  0.0340,
#         -0.0278,  0.0490, -0.0466,  0.0434, -0.0361, -0.0365], device='cuda:0')
# AE_loss_: 1.0
# AE_loss: 1.0
# monifold_loss_: 1.25
# monifold_loss: 1.25
# loss: 1.0

# %%
i = 0 # i番目のSuperpixel
print(f'imgs: {len(imgs)}')
print(f'imgs[{i}]: {len(imgs[i])}x{len(imgs[i][i])}')
# X の形状を表示
print(f'X.shape（{J}個のベクトル）: {X.shape}')
print(f'X[{i}].shape  : {X[i].shape}')

# Y の形状を表示
print(f'Y.shape（{J}個のベクトル）: {len(Y)}')
i = 0 # i番目のSuperpixel
#print(f'{i}番目のsuperpixelのサンプル数: {N[i]}')
#print(f'{i}番目のsuperpixelの潜在表現: {Y[i]}')
print(f'Y[{i}].shape: {np.array(Y[i]).shape}')
# Out:
# imgs: 181
# imgs[0]: 501x501
# X.shape（435個のベクトル）: (435,)
# X[0].shape  : (122, 181)
# Y.shape（435個のベクトル）: 435
# Y[0].shape: (122, 30)

# %%
i=0
print(f'pixel: {pixel.shape}')
print(f'pixel[{i}]: {pixel[i].shape}')
#print(f'pixel: {pixel[i]}')
# Out:
# pixel: (435,)
# pixel[0]: (122, 2)

# %%
# セグメンテーション毎のベクトル X_i 作成 (J, N_j, B)
class_data_ = [[] for _ in range(J)]

imgs_DR_output_ = [[[[0] for _ in range(height)] for _ in range(width)] for _ in range(L)]
print(f'imgs_DR_output_: {len(imgs_DR_output_)}')
print(f'imgs_DR_output_[{0}]: {len(imgs_DR_output_[0])}x{len(imgs_DR_output_[0][0])}')

for i in range(J):
    #for y in range(height):
        #for x in range(width):
    for j in range(pixel[i].shape[0]):
        y, x = pixel[i][j]
        #print(f'{i}:({y},{x})', end=' ')
        for l in range(L):
            imgs_DR_output_[l][y][x] = Y[i][j][l]

imgs_DR_output = np.array(imgs_DR_output_)
print(f'imgs_DR_output[0]: {imgs_DR_output[0]}')
# Out:
# imgs_DR_output_: 30
# imgs_DR_output_[0]: 501x501
# imgs_DR_output[0]: [[-0.17265595 -0.18995497 -0.23144552 ...  0.6431156   0.54714805
#    0.47825247]
#  [-0.00178     0.0051678   0.05907157 ...  0.6070421   0.53935474
#    0.49052593]
#  [-0.01124572 -0.00378365  0.03311733 ...  0.5850597   0.568301
#    0.5310908 ]
#  ...
#  [-0.5448185  -0.57042295 -0.5620813  ...  0.09360431  0.08945087
#    0.04732426]
#  [-0.5746228  -0.6112342  -0.590606   ...  0.0926943   0.09697298
#    0.04282226]
#  [-0.61941695 -0.65880436 -0.6204348  ...  0.10030431  0.08885007
#    0.03728878]]

# %% [markdown]
# ### 次元削減した画像の表示

# %% [markdown]
# ##### 次元削減画像の保存

# %%
# 次元削減後の画像の値を0~255
max = [[0] for _ in range(L)]
min = [[0] for _ in range(L)]

for l in range(L):
    max[l] = np.max(np.max(imgs_DR_output[l]))
    print(f'max_{l}: {max[l]},', end=' ')
    min[l] = np.min(np.min(imgs_DR_output[l]))
    print(f'min_{l}: {np.min(np.min(min[l]))}, ', end=' /')
print()
# Out:
# max_0: 5.042166233062744, min_0: -11.779017448425293,  /max_1: 1.656258225440979, min_1: -10.11563491821289,  /max_2: 4.70092248916626, min_2: -3.4451286792755127,  /max_3: 6.808919906616211, min_3: -3.8103585243225098,  /max_4: 3.4889540672302246, min_4: -11.294007301330566,  /max_5: 14.72122573852539, min_5: -6.423871994018555,  /max_6: 1.3857070207595825, min_6: -11.703985214233398,  /max_7: 6.77724027633667, min_7: -2.456362724304199,  /max_8: 12.677682876586914, min_8: -6.761601448059082,  /max_9: 4.6895246505737305, min_9: -4.564631462097168,  /max_10: 11.811771392822266, min_10: -14.400117874145508,  /max_11: 3.597606897354126, min_11: -3.0832860469818115,  /max_12: 6.871549606323242, min_12: -30.87105941772461,  /max_13: 15.89109992980957, min_13: -3.7462613582611084,  /max_14: 8.478121757507324, min_14: -1.6163318157196045,  /max_15: 15.613752365112305, min_15: -8.185876846313477,  /max_16: 6.551565170288086, min_16: -6.926929473876953,  /max_17: 4.199021339416504, min_17: -3.314337968826294,  /max_18: 11.837374687194824, min_18: -12.600035667419434,  /max_19: 8.691176414489746, min_19: -7.449937343597412,  /max_20: 19.544755935668945, min_20: -2.060610771179199,  /max_21: 13.757635116577148, min_21: -18.783113479614258,  /max_22: 17.238237380981445, min_22: -1.721845269203186,  /max_23: 8.808161735534668, min_23: -11.595314025878906,  /max_24: 9.093193054199219, min_24: -6.303775310516357,  /max_25: 2.3788678646087646, min_25: -5.193117141723633,  /max_26: 22.42910385131836, min_26: -7.0289764404296875,  /max_27: 10.602706909179688, min_27: -4.769278526306152,  /max_28: 11.475643157958984, min_28: -16.90801429748535,  /max_29: 8.093352317810059, min_29: -3.1665430068969727,  /

# %%
imgs_DR_ = [[[[0] for _ in range(height)] for _ in range(width)] for _ in range(L)]
imgs_DR = [[[[0] for _ in range(height)] for _ in range(width)] for _ in range(L)]
max_ = [[0] for _ in range(L)]
min_ = [[0] for _ in range(L)]

for l in range(L):
    imgs_DR_[l] = np.round((imgs_DR_output[l] - min[l])/(max[l]-min[l]) * 255) # (valud-min)x255/(max-min)により0~255の値に変換

    imgs_DR[l] = np.array(imgs_DR_[l], dtype='int32')

    max_[l] = np.max(np.max(imgs_DR_[l]))
    print(f'max_{l}: {np.max(np.max(max_[l]))},', end=' ')
    min_[l] = np.min(np.min(imgs_DR_[l]))
    print(f'min_{l}: {np.min(np.min(min_[l]))},', end=' /')
print()
# Out:
# max_0: 255.0, min_0: 0.0, /max_1: 255.0, min_1: 0.0, /max_2: 255.0, min_2: 0.0, /max_3: 255.0, min_3: 0.0, /max_4: 255.0, min_4: 0.0, /max_5: 255.0, min_5: 0.0, /max_6: 255.0, min_6: 0.0, /max_7: 255.0, min_7: 0.0, /max_8: 255.0, min_8: 0.0, /max_9: 255.0, min_9: 0.0, /max_10: 255.0, min_10: 0.0, /max_11: 255.0, min_11: 0.0, /max_12: 255.0, min_12: 0.0, /max_13: 255.0, min_13: 0.0, /max_14: 255.0, min_14: 0.0, /max_15: 255.0, min_15: 0.0, /max_16: 255.0, min_16: 0.0, /max_17: 255.0, min_17: 0.0, /max_18: 255.0, min_18: 0.0, /max_19: 255.0, min_19: 0.0, /max_20: 255.0, min_20: 0.0, /max_21: 255.0, min_21: 0.0, /max_22: 255.0, min_22: 0.0, /max_23: 255.0, min_23: 0.0, /max_24: 255.0, min_24: 0.0, /max_25: 255.0, min_25: 0.0, /max_26: 255.0, min_26: 0.0, /max_27: 255.0, min_27: 0.0, /max_28: 255.0, min_28: 0.0, /max_29: 255.0, min_29: 0.0, /

# %%
print(imgs_DR_output[0])
print(imgs_DR_[0])
#print(min[0])
# Out:
# [[-0.17265595 -0.18995497 -0.23144552 ...  0.6431156   0.54714805
#    0.47825247]
#  [-0.00178     0.0051678   0.05907157 ...  0.6070421   0.53935474
#    0.49052593]
#  [-0.01124572 -0.00378365  0.03311733 ...  0.5850597   0.568301
#    0.5310908 ]
#  ...
#  [-0.5448185  -0.57042295 -0.5620813  ...  0.09360431  0.08945087
#    0.04732426]
#  [-0.5746228  -0.6112342  -0.590606   ...  0.0926943   0.09697298
#    0.04282226]
#  [-0.61941695 -0.65880436 -0.6204348  ...  0.10030431  0.08885007
#    0.03728878]]
# [[176. 176. 175. ... 188. 187. 186.]
#  [179. 179. 179. ... 188. 187. 186.]
#  [178. 179. 179. ... 187. 187. 187.]
#  ...
#  [170. 170. 170. ... 180. 180. 179.]
#  [170. 169. 170. ... 180. 180. 179.]
#  [169. 169. 169. ... 180. 180. 179.]]

# %%
print(imgs_DR[0])
# Out:
# [[176 176 175 ... 188 187 186]
#  [179 179 179 ... 188 187 186]
#  [178 179 179 ... 187 187 187]
#  ...
#  [170 170 170 ... 180 180 179]
#  [170 169 170 ... 180 180 179]
#  [169 169 169 ... 180 180 179]]

# %%
# %cd ~/BachelorResearch/ColAE
img_save_path = data_name

if not os.path.exists(img_save_path):
    print(f'{img_save_path} is not exists')
    os.makedirs(img_save_path, exist_ok=True)
# Out:
# /home/zennakamura/BachelorResearch/ColAE
# /home/zennakamura/anaconda3/envs/torch/lib/python3.11/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /home/zennakamura/anaconda3/envs/torch/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from PIL import Image

if not os.path.exists(img_save_path):
    print('not exsts')
    os.makedirs(img_save_path, exist_ok=True)

for l in range(L):
    #image_array = np.array(imgs_DR_[l], dtype='int32')
    image = Image.fromarray(imgs_DR[l])
    if l==0:
        plt.imshow(image)
    #img_save_path = f'~/BachelorResearch/ColAE/Schrodinger/DR_img_{l}.tif'
    if os.path.exists(os.path.join(img_save_path, f'DR_img_{l}.tif')):
        print(f'{l},', end=' ')
        image.save(os.path.join(img_save_path, f'DR_img_{l}.tif'))
    else:
        with open(os.path.join(img_save_path, f'DR_img_{l}.tif'), 'x') as f:
            image.save(os.path.join(img_save_path, f'DR_img_{l}.tif'))

# %%
#l = 0
#img_save_path = f'~/BachelorResearch/ColAE/Schrodinger/DR_img_{l}.tif'
#if os.path.exists(img_save_path):
    #print('Yes')
#data_ = cv2.imread(img_save_path, cv2.IMREAD_GRAYSCALE)

#print(data_[0])

# %%
#data_ = data_.astype('float32')/255.
#print(data_)

# %%
#plt.imshow(data_, cmap='gray')

# %%
print(imgs_DR_[0])
# Out:
# [[176. 176. 175. ... 188. 187. 186.]
#  [179. 179. 179. ... 188. 187. 186.]
#  [178. 179. 179. ... 187. 187. 187.]
#  ...
#  [170. 170. 170. ... 180. 180. 179.]
#  [170. 169. 170. ... 180. 180. 179.]
#  [169. 169. 169. ... 180. 180. 179.]]

# %%
plt.imshow(imgs_DR_[0], cmap='gray')

# %%
plt.imshow(imgs_DR_output[0], cmap='gray')

# %%
plt.imshow(imgs_DR_output[1], cmap='gray')

# %%
plt.imshow(imgs_DR_output[2], cmap='gray')

# %%
plt.imshow(imgs_DR_output[3], cmap='gray')

# %%
plt.imshow(imgs_DR_output[4], cmap='gray')

# %%
plt.imshow(imgs_DR_output[5], cmap='gray')

# %%
plt.imshow(imgs_DR_output[6], cmap='gray')

# %%
plt.imshow(imgs_DR_output[7], cmap='gray')

# %% [markdown]
# ## Segmentaion
#
# 潜在表現（コンパクト表現）をSVMに入力し、カテゴリを決定する
