# %% [markdown]
# # Collaborative Superpixelwise Autoencoderの実装
#
# **[書誌情報]**
# - タイトル
#     - A Collaborative Superpixelwise Autoencoder for Unsupervised Dimension Deduction in Hyperspectral Images
# - 著者
#     - Chao Yao, Lingfeng Zheng, Longchao Feng, Fan Yang, Zehua Guo, Miao Ma
# - 出版
#     - Received: 21 July 2023 / Revised: 23 August 2023 / Accepted: 24 August 2023 / Published: 27 August 2023
# - DOI: https://doi.org/10.3390/rs15174211
#
# **[Abstract]**
# - [論文紹介スライド](https://drive.google.com/file/d/1nj9pMiVVg5Q-G_UObhXD0QsFzxGZKAlV/view?usp=sharing)
# - Superpixel-based approaches
#     - サンプルをグループに分け、小さなグループにDR(Dimension Reduction)技術を適応
#     - 良い点
#         - HSIデータの**スペクトル空間情報**を柔軟に扱うことができる
#     - 課題
#         - 同じクラスからのサンプルが異なるSuperpixelに存在する可能性があるという事実を無視することにより、クラス内格差を増加させ、結果的に性能を低下させることがわかった
# - Collaborative superpixelwise Auto-Encoder (**ColAE**)
#     - クラス内格差を低減するため、たとえ異なるsuperpixelに位置するとしても、同じクラスからのサンプルが符号空間（code空間）において同様の表現を持つように制限する**多様体損失**を導入する
#
# **[実装の概要]**
# - HSIデータの読み込み
# - ColAEの実装
# 1. Superpixel segmentation with ERS
#
#  1.1. PCA
#
#  1.2. ERS -> SLIC
#
# 2. Collaborative AEs
#
#  2.1. LLE
#
#  2.2. パラメータを $\Theta^{(0)}$ に初期化
#
#  2.3. AEの損失関数と多様体損失関数の２つの損失関数を計算し、即時のoptimizerを用いて $g^(t)$ の勾配を計算し、$\Theta^{(t+1)} = \Theta^(t) + \alpha g^(t) $ でパラメータを更新
#
#  2.4. $\Theta^(t)$ によって符号空間を計算し、 $Y \in \mathbb{R}^{L \times W \times H}$ を再形成する

# %% [markdown]
# #### Pyhton version -----

# %%
# !sudo apt install python3.7
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.7 1
# !sudo update-alternatives --config python3

# %% [markdown]
# #### ----------

# %% [markdown]
# ## HSIデータの読み込み
#
# [HISUI](https://www.jspacesystems.or.jp/project/observation/hisui/)のデータを[Tellus](https://www.tellusxdp.com/ja/catalog/data/hisui.html)からダウンロードして使用
#
# [使用したデータのダウンロード先リンク](https://www.tellusxdp.com/traveler/viewer/?q=%257B%2522center%2522%253A%255B139.67269389063912%252C35.62839714641322%255D%252C%2522zoom%2522%253A10.828120584428342%252C%2522searchMapState%2522%253A%257B%2522nameState%2522%253A%257B%2522name%2522%253A%2522%2522%252C%2522mode%2522%253Anull%257D%252C%2522observationDateRange%2522%253A%257B%2522start%2522%253Anull%252C%2522end%2522%253Anull%252C%2522active%2522%253Afalse%257D%252C%2522publishedDateRange%2522%253A%257B%2522start%2522%253Anull%252C%2522end%2522%253Anull%252C%2522active%2522%253Afalse%257D%252C%2522aoiState%2522%253A%257B%2522geometry%2522%253A%257B%2522type%2522%253A%2522Polygon%2522%252C%2522coordinates%2522%253A%255B%255B%255B127.16499790831209%252C5.308236535699957%255D%252C%255B168.8696729544158%252C5.308236535699957%255D%252C%255B168.8696729544158%252C44.85495239409777%255D%252C%255B127.16499790831209%252C44.85495239409777%255D%252C%255B127.16499790831209%252C5.308236535699957%255D%255D%255D%257D%252C%2522mode%2522%253A%2522intersect%2522%257D%252C%2522condition%2522%253A%257B%2522dataset%2522%253A%255B%252268f7270f-414f-4587-aaee-01389678d425%2522%252C%2522f1979af1-7585-4251-8225-965d61b4373a%2522%255D%252C%2522properties%2522%253A%257B%257D%252C%2522datasetsType%2522%253A%2522public%2522%257D%252C%2522order%2522%253A%257B%2522field%2522%253A%2522properties.end_datetime%2522%252C%2522direction%2522%253A%2522desc%2522%257D%252C%2522onlyDownloadableFile%2522%253A%257B%2522active%2522%253Afalse%252C%2522value%2522%253Afalse%257D%252C%2522scene%2522%253A%2522detail%2522%252C%2522consoleOpened%2522%253Atrue%252C%2522selectedData%2522%253A%257B%2522dataset%2522%253A%252268f7270f-414f-4587-aaee-01389678d425%2522%252C%2522data%2522%253A%2522bcbda156-8ee9-49db-947b-782f221496b0%2522%257D%257D%257D) (ログインが必要)

# %% [markdown]
# ### データの読み込み

# %%
import numpy as np
import os
import glob
import cv2
from osgeo import gdal
import matplotlib.pyplot as plt
import torch
import time

from livelossplot import PlotLosses

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f'device: {device}')

# 波長順にsort
import re
def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

# ファイルの読み込み
data_name = 'Tokyo'
files = sorted(glob.glob('../Dataset/HISUI/'+data_name+'/*.tif'), key=natural_keys)
print(f'len: {len(files)}')

datas = []
for i, file in enumerate(files):
    # 画像読み込み
    data = cv2.imread(file, cv2.IMREAD_GRAYSCALE)

    data_expanded = np.expand_dims(data, axis=0)
    datas.append(data_expanded)
    
imgs = np.concatenate(datas, axis=0)
imgs = imgs.astype(np.float32)/255. 
#imgs = np.array(imgs.ReadAsArray(), np.float32) # [0~1]にスケーリング正規化かつfloat64->float32へ変換
band_size = imgs.shape[0] # band number
print(f'dtype: {imgs.dtype}, shape: {imgs.shape}, min: {np.min(imgs)}, max: {np.max(imgs)}')
plt.imshow(imgs[0], cmap='gray')
# Out:
# device: cuda:0
# len: 180
# dtype: float32, shape: (180, 501, 501), min: 0.0, max: 1.0

# %%
# file_path = '/content/drive/MyDrive/Intern/Intern_S2023/ColAE/HSI_data_inTokyo'
# format = 'tif'
# print(file_path+'/*.'+format)

# %%
# im = cv2.imread('/content/drive/MyDrive/Intern/Intern_S2023/ColAE/imgs_ers_input.jpg')
# im = im.transpose(2, 0, 1)
# print(len(im))
# print(f'{len(im[0])}x{len(im[0][0])}')

# %%
# print(imgs.dtype)

# %%
# #--nChannel
# %cd

# %%
# %cd '/content/drive/MyDrive/Intern/Intern_S2023/ColAE'
# #!git clone https://github.com/kanezaki/pytorch-unsupervised-segmentation.git
# %cd 'pytorch-unsupervised-segmentation'
# !ls

# %%
# band_num = len(imgs)

# %%
# print(type(band_num))

# %%
# !python demo.py --input file_path --nChannel 180 --format tif --mode origin

# %% [markdown]
# ## 1. Superpixel segmentation with ERS

# %% [markdown]
# ### 1.1 Principal Componet Analysis (PCA)

# %%
# 画像をバンドごとに平坦化
# 波長 82 band
imgs_pca_input = imgs.reshape(band_size, -1).transpose()

print(imgs_pca_input.shape)
# Out:
# (251001, 180)

# %%
# 画像180x1794x1891（band, h, w）にPCAを適用
from sklearn.decomposition import PCA

# chanel: 82　->　3（主成分）
pca = PCA(3)
imgs_pca_output = pca.fit_transform(imgs_pca_input)

imgs_pca_output.shape
# Out:
# (251001, 3)

# %% [markdown]
# #### 表示

# %%
# plt.style.use('seaborn-whitegrid')
# fig = plt.figure(figsize = (10,6))
# ax = fig.add_subplot(1,1,1,projection='3d')
# ax.set_xlabel('PC_1')
# ax.set_ylabel('PC_2')
# ax.set_zlabel('PC_3')
# c_map = plt.cm.get_cmap('jet', 10)
# mappable = ax.scatter(imgs_pca_output[:, 0], imgs_pca_output[:, 1], imgs_pca_output[:, 2], s = 15, cmap = c_map, marker='.')
# fig.colorbar(mappable, ax=ax)
# plt.show()

# %% [markdown]
# ### 1.2 Entropy Rate Superpixel Segmentation (ERS)
#
# ERSを用いて、Superpixel Segmentaionを作成
#
# GitHub: https://github.com/mingyuliutw/EntropyRateSuperpixel
#
# [ERSを採用する理由]
# - HSI分類タスクにおいての有望な性能が示されている
#
#  1. Jiang+ (2018): [A superpixelwise PCA approach for unsupervised feature extraction of hyperspectral imagery](https://doi.org/10.1109/TGRS.2018.2828029)
#
#  → 前処理プロセスとして用いるため計算量を少なくする必要がある。（具体的に、他の手法と比較してどれだけ計算量が少なく、かつどれだけの性能なのか調べる必要がある。）
#  2. Zhang+ (2022): [Spectral-spatial and superpixelwise PCA for unspervised feature extraction of hyperspectral imaagery](https://doi.org/10.1109/TGRS.2021.3057701)
#
#
# - 適用的領域生成とテクスチャ保存における固有の能力がある
#
# \\
# また今後として、マルチスケールスーパーピクセルに拡張でき、精度向上が期待できる。

# %%
# # Githubからclone
# %cd /content/drive/MyDrive/Intern/Intern_S2023/ColAE
# !pwd
# !ls
# #!git clone https://github.com/mingyuliutw/EntropyRateSuperpixel.git
# %cd '/content/drive/MyDrive/Intern/Intern_S2023/ColAE/EntropyRateSuperpixel/'

# %%
# # PCAによって180から3chanelにした擬似カラー画像
# imgs_ers_input = imgs_pca_output.reshape(imgs.shape[1], imgs.shape[2], -1)
# print(imgs_ers_input.shape)
# plt.imshow(imgs_ers_input)

# # Matlab に読み込むように保存
# imgs_ers_input_path = '/content/drive/MyDrive/Intern/Intern_S2023/ColAE/imgs_ers_input.jpg'

# # BGR to RGB
# imgs_ers_input_rgb = imgs_ers_input[:, :, [2, 1, 0]]
# cv2.imwrite(imgs_ers_input_path, imgs_ers_input_rgb, [cv2.IMWRITE_JPEG_QUALITY, 100])

# %%
# imgs_ers_input_path = '/content/drive/MyDrive/Intern/Intern_S2023/ColAE/imgs_ers_input.jpg'
# tmp = cv2.imread(imgs_ers_input_path)
# # BGR to RGB
# tmp_rgb = tmp[:, :, [2, 1, 0]]
# plt.imshow(tmp_rgb)

# %% [markdown]
# #### ERSのGitHubコードがMATLABで使えそうなので、MATLABで作成したSuperpixel Segementaion by using ERSを読み込む

# %%
# !ls

# %% [markdown]
# Python3のバージョンによる以下のようなエラーが発生するための解決する方法の提供先
#
# ModuleNotFoundError: No module named 'erspy'
#
# GitHub: https://github.com/aniku777tw/ERS-EntropyRateSuperpixel

# %%
# %cd /content/drive/MyDrive/Intern/Intern_S2023/ColAE
# !pwd
# !ls
# #!git clone https://github.com/aniku777tw/ERS-EntropyRateSuperpixel.git
# %cd '/content/drive/MyDrive/Intern/Intern_S2023/ColAE/ERS-EntropyRateSuperpixel'

# %%
# !python --version

# %%
# %cd ERS_Python
# !ls

# %%
# !python compile_cpp.py build

# %%
# %cd ..
# !ls

# %%
# !python demoERS.py

# %%
# from ERSModule import *
# import cv2
# import numpy as np

# def colormap(input,colors):
# 	height = input.shape[0]
# 	width  = input.shape[1]
# 	output = np.zeros([height,width,3],np.uint8)
# 	for y in range(0,height):
# 		for x in range(0,width):
# 			id = int(input[y,x])
# 			for k in range(0,3):
# 				output[y,x,k] = colors[id,k]
# 	return output

# nC = 100

# # BGR to RGB
# imgs_ers_input_rgb = imgs_ers_input[:, :, [2, 1, 0]]
# #grayImg = cv2.cvtColor(imgs_ers_input_rgb,cv2.COLOR_BGR2GRAY)
# # print grayImg.shape
# seg = ERS()
# segmentation = seg.ComputeSegmentation(np.uint8(imgs_ers_input_rgb), nC)[0]

# colors = np.uint8(np.random.rand(nC,3)*255)
# output = colormap(segmentation,colors)
# cv2.imshow("img", imgs_ers_input_rgb)
# cv2.imshow("segmentation",output)
# cv2.waitKey()
# cv2.destroyAllWindows()

# %% [markdown]
# ### 1.2 Simple Linear Iterative Clustering (SLIC) （ERSの代わり）
#
# SLICを用いて、Superpixel Segmentaionを実施
#
# Stutz+ (2016)が推奨しているSuperpixel Segmentaion手法の１つ
#
# scikit-imageやOpenCVで実装が公開されている
#
# [利用例]
# - アノテーションの効率化

# %%
# PCAによって180から3chanelにした擬似カラー画像
imgs_slic_input = imgs_pca_output.reshape(imgs.shape[1], imgs.shape[2], -1)

# BGR to RGB
#imgs_slic_input_rgb = imgs_slic_input[:, :, [2, 1, 0]]
imgs_slic_input_rgb = imgs_slic_input

print(imgs_slic_input_rgb.shape)
plt.imshow(imgs_slic_input_rgb)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (501, 501, 3)

# %%
# Superpixel Segmentaion のパラメータ
height, width, channels = imgs_slic_input.shape[:3]
region_size = 23
ruler = 5
min_element_size = 18
num_iterations = 10  # 反復回数

# 64ビットから32ビットへの変換
imgs_slic_input_32f = np.float32(imgs_slic_input_rgb)
imgs_slic_input_hsv = cv2.cvtColor(imgs_slic_input_32f, cv2.COLOR_BGR2HSV)

slic = cv2.ximgproc.createSuperpixelSLIC(imgs_slic_input_hsv, cv2.ximgproc.SLIC, region_size, float(ruler))

# 画像のスーパーピクセルセグメンテーションを計算
# 入力画像は,HSVまたはL*a*b*
slic.iterate(num_iterations)
slic.enforceLabelConnectivity(min_element_size);

labels = slic.getLabels()

# スーパーピクセルセグメンテーションの境界を取得
contour_mask = slic.getLabelContourMask(False)
imgs_slic_output = imgs_slic_input_rgb.copy()
imgs_slic_output[0 < contour_mask] = (255, 255, 0)

# セグメンテーション数の取得
# ColAE論文中の J (nseg) にあたる（Jが100前後の時が性能が良い）
# 論文中のDataset（Indian: 145x145, UoPavia: 610x340, Salinas: 512x217）
## と比較して今回のデータは　1640x998　と3倍ほど大きいので J も少し大きい値でもいいか？
J = slic.getNumberOfSuperpixels()

lbavgimg = np.zeros((height, width, channels), dtype=np.uint8)
meanimg = np.zeros((J, channels+1), dtype=np.float32)

# 画像表示
print(f'J (nSeg) = {J}')
plt.imshow(imgs_slic_output)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# J (nSeg) = 495

# %% [markdown]
# ## 2. Collaborative AEs

# %% [markdown]
# ### セグメンテーションごとにベクトルを作成
#
# $$
# X = ({X^1, X^2, ..., X^J})
# $$
#
# , where
# $$
# X^i = ({X_1}^i, {X_2}^i, ..., {X_{N_i}}^i)
# $$
# $$X^i \in \mathbb{R}^{B \times {N_i}}$$
#
# $N_i$ : i番目のSuperpixelのサンプル数

# %%
print(f'size: {labels.shape}')
print(f'画像pixelごとのseglabel: {labels}')
# Out:
# size: (501, 501)
# 画像pixelごとのseglabel: [[  0   0   0 ...  18  18  18]
#  [  0   0   0 ...  18  18  21]
#  [  0   0   0 ...  21  21  21]
#  ...
#  [483 483 483 ... 482 482 482]
#  [483 483 483 ... 482 482 482]
#  [483 483 483 ... 482 482 482]]

# %%
band_num, height, width = imgs.shape[:3]

# ベクトル N_j x 波長180

# セグメンテーション毎のベクトル X_i 作成 (J, N_j, B)
class_data = [[] for _ in range(J)]
save_pixel_index = [[] for _ in range(J)]

# ピクセルごとにクラスごとのデータを追加
for y in range(height):
    for x in range(width):
        class_idx = labels[y, x]  # クラスを取得
        pixel_data = imgs[:, y, x]  # 長さがBの一次元配列を生成（仮のデータ）
        class_data[class_idx].append(pixel_data)
        save_pixel_index[class_idx].append([y, x])

# クラスごとのデータを NumPy 配列に変換
X = np.array([np.array(class_data[j]) for j in range(J)], dtype=object)
pixel = np.array([np.array(save_pixel_index[j]) for j in range(J)], dtype=object)

# セグメンテーション毎（クラスごと）のpixel数 N_j
N = [0]*J
for index, x_i in enumerate(X):
    N[index] = X[index].shape[0]
    #print(f'X[{i}].shape: {X[i].shape[0]}', end=' ')

# X の形状を表示
print(f'X.shape（J個のベクトル）: {X.shape}')
i = 0 # i番目のSuperpixel
print(f'{i}番目のsuperpixelのサンプル数: {N[i]}')
print(f'{i}番目のsuperpixelのサンプル: {X[i]}')
print(f'X[i].shape: {X[i].shape}')

N = np.array(N)
#N = torch.Tensor(N).to(device)# to torch.Tensor
#N = torch.from_numpy(N).to(dtype=torch.float32, device=device) # .to(device).to(torch.float32)
#N.requires_grad = True

# # == 過学習を防ぐためにSuperpixelの順番を shuffle ==
# # ======= 必要か?, 空間情報どうなる？ =======
# np.random.shuffle(X)
# for index, x_i in enumerate(X):
#     # 各Superpixel内の順番も shuffle
#     np.random.shuffle(X[i])

#     N[index] = X[i].shape[0]
# # =======================================

# # X の形状を表示
# print('\n==== シャッフル後 ====')
# print(f'X.shape（J個のベクトル）: {X.shape}')
# i = 0 # i番目のSuperpixel
# print(f'{i}番目のsuperpixelのサンプル数: {N[i]}')
# print(f'{i}番目のsuperpixelのサンプル: {X[i]}')

# print(f'X[i].shape: {X[i].shape}')
# Out:
# X.shape（J個のベクトル）: (495,)
# 0番目のsuperpixelのサンプル数: 235
# 0番目のsuperpixelのサンプル: [[0.50980395 0.6509804  0.48235294 ... 0.5764706  0.5921569  0.69411767]
#  [0.58431375 0.6862745  0.54509807 ... 0.5647059  0.6039216  0.65882355]
#  [0.7058824  0.7294118  0.65882355 ... 0.5176471  0.5529412  0.6313726 ]
#  ...
#  [0.45490196 0.5294118  0.41960785 ... 0.38431373 0.44705883 0.5372549 ]
#  [0.5019608  0.48235294 0.49411765 ... 0.36078432 0.36862746 0.4862745 ]
#  [0.4627451  0.5921569  0.44313726 ... 0.44705883 0.4392157  0.5294118 ]]
# X[i].shape: (235, 180)

# %%
for i in range(J):
    print(f'{i}:{N[i]}', end=' ')
print()
# Out:
# 0:235 1:196 2:1717 3:718 4:1271 5:490 6:256 7:346 8:728 9:437 10:969 11:339 12:1565 13:2040 14:1036 15:397 16:456 17:109 18:529 19:303 20:748 21:795 22:698 23:322 24:909 25:807 26:157 27:225 28:642 29:283 30:290 31:327 32:199 33:549 34:226 35:458 36:215 37:430 38:166 39:128 40:1328 41:646 42:158 43:167 44:309 45:453 46:1568 47:925 48:672 49:98 50:481 51:280 52:97 53:213 54:131 55:1206 56:133 57:898 58:311 59:282 60:269 61:157 62:457 63:254 64:421 65:273 66:1069 67:738 68:913 69:354 70:1379 71:1413 72:374 73:324 74:316 75:1267 76:215 77:656 78:194 79:142 80:138 81:433 82:783 83:1384 84:322 85:252 86:618 87:546 88:356 89:179 90:451 91:606 92:376 93:1804 94:166 95:383 96:356 97:177 98:168 99:226 100:959 101:504 102:512 103:372 104:709 105:876 106:295 107:1135 108:200 109:454 110:878 111:291 112:166 113:295 114:383 115:1129 116:399 117:428 118:559 119:1238 120:148 121:579 122:741 123:280 124:436 125:543 126:154 127:359 128:258 129:898 130:779 131:558 132:324 133:117 134:557 135:208 136:164 137:851 138:104 139:228 140:909 141:719 142:463 143:567 144:830 145:462 146:336 147:190 148:436 149:657 150:952 151:546 152:93 153:666 154:552 155:267 156:1193 157:436 158:205 159:487 160:291 161:163 162:172 163:179 164:158 165:1305 166:691 167:1339 168:331 169:688 170:137 171:443 172:1245 173:570 174:601 175:290 176:198 177:251 178:262 179:166 180:159 181:178 182:543 183:1168 184:1674 185:710 186:95 187:496 188:386 189:521 190:1158 191:499 192:1431 193:950 194:241 195:1078 196:391 197:708 198:879 199:596 200:115 201:560 202:1275 203:1349 204:526 205:196 206:514 207:134 208:198 209:294 210:134 211:303 212:281 213:577 214:169 215:1639 216:1123 217:584 218:336 219:771 220:350 221:328 222:238 223:411 224:142 225:1228 226:1116 227:197 228:764 229:188 230:114 231:399 232:797 233:202 234:921 235:253 236:379 237:995 238:548 239:822 240:102 241:429 242:109 243:605 244:248 245:161 246:402 247:350 248:147 249:376 250:505 251:908 252:1367 253:1139 254:443 255:420 256:260 257:877 258:1732 259:252 260:540 261:1996 262:162 263:270 264:154 265:1958 266:122 267:179 268:957 269:405 270:1263 271:338 272:193 273:721 274:533 275:353 276:782 277:398 278:224 279:1037 280:397 281:310 282:287 283:1005 284:793 285:150 286:533 287:1308 288:185 289:303 290:865 291:222 292:132 293:105 294:1009 295:479 296:140 297:126 298:510 299:454 300:112 301:118 302:158 303:569 304:422 305:205 306:500 307:474 308:401 309:1314 310:413 311:922 312:992 313:294 314:822 315:386 316:167 317:125 318:155 319:356 320:837 321:415 322:337 323:126 324:214 325:251 326:113 327:656 328:1027 329:359 330:1093 331:262 332:681 333:237 334:198 335:1181 336:777 337:284 338:965 339:390 340:489 341:1614 342:122 343:372 344:391 345:581 346:111 347:309 348:450 349:117 350:184 351:144 352:312 353:381 354:432 355:184 356:1518 357:966 358:537 359:380 360:488 361:722 362:196 363:405 364:536 365:161 366:113 367:229 368:274 369:397 370:1126 371:140 372:990 373:123 374:1369 375:288 376:185 377:177 378:575 379:249 380:390 381:153 382:1279 383:340 384:462 385:990 386:756 387:666 388:119 389:294 390:303 391:430 392:115 393:296 394:455 395:1105 396:1003 397:410 398:285 399:751 400:506 401:816 402:526 403:306 404:463 405:266 406:140 407:181 408:1098 409:517 410:1331 411:458 412:426 413:183 414:276 415:183 416:1460 417:649 418:548 419:272 420:298 421:750 422:171 423:165 424:1010 425:133 426:1018 427:516 428:521 429:904 430:560 431:151 432:365 433:277 434:319 435:521 436:750 437:718 438:375 439:194 440:532 441:91 442:295 443:167 444:394 445:284 446:304 447:437 448:384 449:528 450:238 451:246 452:242 453:1283 454:317 455:718 456:320 457:234 458:754 459:265 460:358 461:197 462:658 463:589 464:219 465:556 466:637 467:324 468:416 469:137 470:120 471:213 472:677 473:202 474:869 475:209 476:798 477:110 478:320 479:274 480:167 481:411 482:248 483:330 484:119 485:313 486:123 487:134 488:344 489:488 490:245 491:144 492:196 493:365 494:339

# %% [markdown]
# ### Locally Linear Embedding (LLE)
#
# 各Superpixel内の平均ベクトルの基本的な多様体構造を捕らえる
#
#
# 多様体学習についての参考 Web (https://www.hellocybernetics.tech/entry/2017/07/06/133450)
#
# 多様体学習の主な手法
# - LLE
#     - 長所
#         - 大域的な位置関係を保持できる
#     - 短所
#         - 多様体が複数ある場合、互いの位置関係をうまく保存できない。
#         - 圧縮後のデータ位置を再構成する計算量がデータ数の2乗に比例するため、大規模なデータに適用しづらい。
#     - Other LLE
#         - Hessian LLE
#         - Modified LLE
#         - Local Tangent Space Alignment (LTSA)
# - 多次元尺度法 (multi-dimensional scaling, MDS)
# - Isomap
# - t-SEN (t-distributed Stochastic Neighbor Embedding)
# - UMAP (Uniform Manifold Approximation and Projection)

# %% [markdown]
# #### 各Superpixel内の平均ベクトルを作成

# %%
# i番目のSuperpixelの平均ベクトル x J
#mu = [0]*J
mu = [[] for _ in range(J)]
for i in range(J):
    mu[i] = np.mean(X[i], axis=0)

mu = np.array(mu)
print(f'平均ベクトル: {mu.shape}')
# Out:
# 平均ベクトル: (495, 180)

# %% [markdown]
# #### 多様体損失
#
# 多様体構造を作るための入力として各Superpixelの平均ベクトル(mean vectors)を用いる
#
# 以下の式を最小化
#
# $$
# \matrix L(\matrix{Y}) = \sum_{i}
# {\|
#  \sum_{j} \frac{1}{N_{j}} \mathbf{y_{\textit{j}}^{\textit{i}}}
#   - \sum_{k} \mathbf{w_{\textit{ik}}} \sum_{j} \frac{1}{N_{k}} \mathbf{y_{\textit{j}}^{\textit{k}}}
#  \|}^{2}
# $$

# %%
# from sklearn.manifold import LocallyLinearEmbedding

# # 潜在空間のサイズ
# L = 30
# K = 5
# method = 'standard' # 通常のLLE

# embedding = LocallyLinearEmbedding(n_neighbors=K, n_components=L, method=method)

# M = embedding.fit_transform(mu[:J])

# # LLEの再構成誤差（多様体損失）
# monifold_loss = embedding.reconstruction_error_

# print(f'M shape: {M.shape}')
# print(f'monifold_loss: {monifold_loss}')
# print(f'M: {M}')

# %%
# LLEの実装しているコード
# %cd ~/BachelorResearch/ColAE/
# !git clone https://github.com/bghojogh/Generative-LLE.git
# %cd Generative-LLE
# Out:
# /home/zennakamura/BachelorResearch/ColAE
# fatal: destination path 'Generative-LLE' already exists and is not an empty directory.
# /home/zennakamura/BachelorResearch/ColAE/Generative-LLE
# /home/zennakamura/anaconda3/envs/torch/lib/python3.11/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /home/zennakamura/anaconda3/envs/torch/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# LLE
from functions import my_LLE

# 潜在空間のサイズ
L = 30
# K-最近傍の数 (固定比率 R=0.2 のとき)
K = J * 0.2
K = int(K)
print(f'K={K}')

# My_LLEの入力のため転置
mu_transpose = mu.transpose()

embedding = my_LLE.My_LLE(X=mu_transpose, n_neighbors=K, n_components=L,
                          path_save='~/BachelorResearch/ColAE/LLE')
# Out:
# K=99

# %%
X_transformed = embedding.fit_transform(calculate_again=True)
print(f'X shape: {mu_transpose.shape}')
print(f'Y shape: {X_transformed.shape}')

# 式（2）に従った各平均ベクトルの重み
W = embedding.W_linearEmbedding
print(f'W.shape: {W.shape}')
W = torch.from_numpy(W).to(dtype=torch.float32, device=device)
W.requires_grad = True

# K-最近傍のインデックス
neighbor_indices = embedding.neighbor_indices
print(f'neighbor_indices.shape: {neighbor_indices.shape}')
# Out:
# X shape: (180, 495)
# Y shape: (30, 495)
# W.shape: (495, 495)
# neighbor_indices.shape: (495, 99)

# %% [markdown]
# ### Auto-Encoder (AE)
#
# 各SuperpixelごとにAutoencoderを実装
#
# 余裕があれば、Variational Autoencoder（変分AE）にする、他も試してみる

# %%
# 入力サイズ BxN_i
i = 0 # i番目のSuperpixel
print(f'Input size ({band_num}x{N[i]}): {band_num*N[i]}')
# 潜在空間のサイズ
L = 30
print(f'Latent space size ({L}x{N[i]}): {L*N[i]}')
# Out:
# Input size (180x235): 42300
# Latent space size (30x235): 7050

# %% [markdown]
# #### Auto-Encoderの定義

# %%
import torch.nn as nn

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f'device: {device}')

class Encoder(nn.Module):
    def __init__(self, input_size, latent_size):
        super(Encoder, self).__init__()
        self.L = latent_size # 潜在空間の次元数 LxN_i
        self.fc1 = nn.Linear(input_size, input_size//2)
        self.fc2 = nn.Linear(input_size//2, self.L) # L = (band_num//3)//2
        # 重みを初期化
        nn.init.xavier_normal_(self.fc1.weight)
        nn.init.xavier_normal_(self.fc2.weight)
        nn.init.zeros_(self.fc1.bias)
        nn.init.zeros_(self.fc2.bias)

    def forward(self, x):
        x = x.float()
        #x = torch.tensor(x)
        x = torch.tanh(self.fc1(x))
        x = self.fc2(x)
        return x

class Decoder(nn.Module):
    def __init__(self, input_size, latent_size):
        super(Decoder, self).__init__()
        self.L = latent_size # 潜在空間の次元数 LxN_i
        self.fc1 = nn.Linear(self.L, input_size//2)
        self.fc2 = nn.Linear(input_size//2, input_size) # band_num = ((L*2)*3)
        # 重みを初期化
        nn.init.xavier_normal_(self.fc1.weight)
        nn.init.xavier_normal_(self.fc2.weight)
        nn.init.zeros_(self.fc1.bias)
        nn.init.zeros_(self.fc2.bias)

    def forward(self, x):
        x = x.float()
        #x = torch.tensor(x)
        x = torch.tanh(self.fc1(x))
        x = self.fc2(x)
        return x

class AutoEncoder(nn.Module):
    def __init__(self, input_size, latent_size):
        super().__init__()
        self.L = L
        self.enc = Encoder(input_size, latent_size).to(device)
        self.dec = Decoder(input_size, latent_size).to(device)

    def forward(self, x):
        #x = torch.tensor(x)
        encoded = self.enc(x) # Encode
        decoded = self.dec(encoded) # Decode
        return encoded, decoded
# Out:
# device: cuda:0

# %% [markdown]
# #### Auto-Encoderの学習
#
# 再構成誤差と多様体損失の２つの損失関数を用いて学習
#
# $$\mathbf{R}(\mathbf{\ominus}) =
# \sum_{i}\sum_{j} {\|{\mathbf{x_{\textit{j}}^{\textit{i}}}} - \mathbf{\hat{x}_{\textit{j}}^{\textit{i}}}\|}^{2} + \eta \sum_{i}
# {\|
#  \sum_{j} \frac{1}{N_{i}} \mathbf{y_{\textit{j}}^{\textit{i}}}
#   - \sum_{k} \mathbf{\textit{w}_{\textit{ik}}} \sum_{j} \frac{1}{N_{k}} \mathbf{y_{\textit{j}}^{\textit{k}}}
#  \|}^{2}
#  $$

# %% [markdown]
# #### 損失関数, 最適化手法の定義

# %%
# MSE Loss funcion (再構成誤差)
AE_loss_function = torch.nn.MSELoss()
monifold_loss_function = torch.nn.MSELoss()

# 乱数のシードを固定して再現性を確保
torch.manual_seed(0)

# %% [markdown]
# #### D-Adaptation
#
# DOI: https://arxiv.org/abs/2301.07733
# Github: https://github.com/facebookresearch/dadaptation

# %%
#import dadaptation

# %%
model = [[] for _ in range(J)]
optimizer = [[] for _ in range(J)]
scheduler = [[] for _ in range(J)]

epochs = 500 # epoch数

for i in range(J):
    # i番目のModel
    model[i] = AutoEncoder(band_num, L).to(device)

    # i番目のOptimizer
    optimizer[i] = torch.optim.Adam(model[i].parameters(), lr=1e-3, weight_decay=1e-5)
    #optimizer[i] = dadaptation.dadapt_adam.DAdaptAdam(model[i].parameters(), lr=1.0, decouple=False, weight_decay=1e-5)
    scheduler[i] = torch.optim.lr_scheduler.LinearLR(optimizer[i], start_factor=0.5, end_factor=1e-3, total_iters=(epochs-5))

# %% [markdown]
# #### 学習

# %%
save_path = '~/BachelorResearch/ColAE/'+data_name
# %cd {save_path}
weight_path = f'weight'

if not os.path.exists(weight_path):
    print(f'{weight_path} is not exists')
    os.makedirs(weight_path, exist_ok=True)
# Out:
# /home/zennakamura/BachelorResearch/ColAE/Tokyo
# /home/zennakamura/anaconda3/envs/torch/lib/python3.11/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /home/zennakamura/anaconda3/envs/torch/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
#from sklearn.manifold import LocallyLinearEmbedding

L = 30 # 符号空間（code space）の次元数
#eta =  0.75 # 損失のバランス係数
eta =  1.25 # 損失のバランス係数

# i-th Superpixelの符号空間の平均ベクトル x J
mu_y_ = [[] for _ in range(J)]
mu_y = [[] for _ in range(J)]

# K-近傍
y_ik_ = [[0] for _ in range(J)]
y_ik = [[0] for _ in range(J)]

start_ColAE = time.time() #
#liveloss = PlotLosses() # livelossplot
plot_AE_loss = []
plot_monifold_loss = []

# 学習
for epoch in range(epochs):
    print(f'Epoch {epoch}/{epochs-1}\t(J={J})')
    print('\t', end='')
    #logs = {} # livelossplot

    AE_loss = 0.0 # AEの損失
    monifold_loss = 0.0 # 多様体損失(LLE)
    loss = 0.0 # ColAEの損失

    # 潜在空間(Latent Space)ベクトル
    Y_ = [[] for _ in range(J)]
    Y = [[] for _ in range(J)]

    for i in range(J):
# ========== train ===========
        # modelのパラメータの読み込み
        #weight_path = f'~/BachelorResearch/ColAE/weight/ColAE_weight_{i}.pth'
        if os.path.exists(os.path.join(weight_path, f'ColAE_weight_{i}.pth')):
            model[i].load_state_dict(torch.load(os.path.join(weight_path, f'ColAE_weight_{i}.pth')))

        model[i].train() # モデルを訓練モードに設定

        for j, input in enumerate(X[i]): # BxN_i から 長さBのベクトルごとに

            # Encoder input
            input = torch.from_numpy(input).to(dtype=torch.float32, device=device)
            input.requires_grad = True

            # Encoder output (Latent Space) and Decoder output
            latent, reconstructed = model[i](input)

            # L(latentの次元) x N_i
            latent = np.array(latent.detach().cpu())
            Y_[i].append(latent)

            #  ======= 損失計算 =======
            # Loss function for the i-th AE (式9, 10)
            AE_loss_ = AE_loss_function(reconstructed, input)
            AE_loss_.retain_grad()
            AE_loss += AE_loss_
            AE_loss.retain_grad()
            # ======================

        #print(f'AE_{i} Train Loss: {AE_loss_:.5f},', end=' ')
        #print(f'{i},', end='')
        # i番目のSuperpixelの潜在空間ベクトル
        Y[i] = np.array(Y_[i])

    print()

    # ======= 損失計算 =======
    # 再構成誤差, 多様体損失 (式8)
    # i-th Superpixelの符号空間の平均ベクトル x J
    for i in range(J):
        mu_y_[i] = np.mean(Y[i], axis=0)
        mu_y_[i] = np.array(mu_y_[i])
        mu_y[i] = torch.from_numpy(mu_y_[i]).to(dtype=torch.float32, device=device)
        mu_y[i].requires_grad = True

    for i in range(J):
        for k in neighbor_indices[i].astype('int32'):
            # y_i のK-最近傍の線型結合
            y_ik_[i] = np.array(y_ik_[i])
            y_ik[i] = torch.from_numpy(y_ik_[i]).to(dtype=torch.float32, device=device)
            y_ik[i].requires_grad = True
            y_ik[i] = y_ik[i] + W[i][k] * mu_y[k]
            y_ik[i].retain_grad()

        monifold_loss_ = monifold_loss_function(mu_y[i], y_ik[i])
        monifold_loss_.retain_grad()
        # LLEの再構成誤差（多様体損失）
        monifold_loss +=  monifold_loss_
        monifold_loss.retain_grad()

    # ColAEの損失(式11)
    loss = AE_loss + eta*monifold_loss
    loss.retain_grad()
    # ======================

    for i in range(J):
        # 全Superpixelの多様体構造を保つようにパラメータ更新
        optimizer[i].zero_grad()
    loss.backward() # 誤差逆伝播法に基づいて各パラメータの勾配を計算
    #monifold_loss.backward()
    for i in range(J):
        optimizer[i].step() # 勾配の値に基づいて選択した最適化手法によりパラメータ W, b を更新
        scheduler[i].step()

        # modelのパラメータの保存（epochごとに使う）
        #weight_path = f'~/BachelorResearch/ColAE/weight/ColAE_weight_{i}.pth'
        torch.save(model[i].state_dict(), os.path.join(weight_path, f'ColAE_weight_{i}.pth'))
    print(f'\tAE Loss: {AE_loss:.6f}, Monifold Loss: {monifold_loss:.6f}, ColAE Loss: {loss:.6f}')
    #logs['AE_loss'] = AE_loss.to('cpu').detach().numpy()
    #logs['Monifold_loss'] = monifold_loss.to('cpu').detach().numpy()
    #liveloss.update(logs)
    #liveloss.send()
    plot_AE_loss.append(AE_loss.to('cpu').detach().numpy())
    plot_monifold_loss.append(monifold_loss.to('cpu').detach().numpy())

end_ColAE = time.time() #
time_diff = end_ColAE-start_ColAE
print(f'Running time of ColAE is {time_diff}')
# ========== train ===========
# Out:
# Epoch 0/499	(J=495)
#
# 	AE Loss: 1016.148682, Monifold Loss: 1146.756470, ColAE Loss: 2449.594238
# Epoch 1/499	(J=495)
#
# 	AE Loss: 2142.028564, Monifold Loss: 1154.091919, ColAE Loss: 3584.643555
# Epoch 2/499	(J=495)
#
# 	AE Loss: 896.154358, Monifold Loss: 1149.249512, ColAE Loss: 2332.716309
# Epoch 3/499	(J=495)
#
# 	AE Loss: 1141.706055, Monifold Loss: 1146.583618, ColAE Loss: 2574.935547
# Epoch 4/499	(J=495)
#
# 	AE Loss: 1236.596924, Monifold Loss: 1146.220093, ColAE Loss: 2669.372070
# Epoch 5/499	(J=495)
#
# 	AE Loss: 921.175781, Monifold Loss: 1146.621216, ColAE Loss: 2354.452148
# Epoch 6/499	(J=495)
#
# 	AE Loss: 696.854614, Monifold Loss: 1147.445923, ColAE Loss: 2131.162109
# Epoch 7/499	(J=495)
#
# 	AE Loss: 708.598450, Monifold Loss: 1148.351074, ColAE Loss: 2144.037354
# Epoch 8/499	(J=495)
#
# 	AE Loss: 776.768677, Monifold Loss: 1148.962158, ColAE Loss: 2212.971191
# Epoch 9/499	(J=495)
#
# 	AE Loss: 749.652344, Monifold Loss: 1149.084595, ColAE Loss: 2186.008057
# Epoch 10/499	(J=495)
#
# 	AE Loss: 655.592224, Monifold Loss: 1148.764771, ColAE Loss: 2091.548096
# Epoch 11/499	(J=495)
#
# 	AE Loss: 583.097229, Monifold Loss: 1148.205078, ColAE Loss: 2018.353516
# Epoch 12/499	(J=495)
#
# 	AE Loss: 560.532043, Monifold Loss: 1147.718750, ColAE Loss: 1995.180420
# Epoch 13/499	(J=495)
#
# 	AE Loss: 558.135803, Monifold Loss: 1147.600708, ColAE Loss: 1992.636719
# Epoch 14/499	(J=495)
#
# 	AE Loss: 546.376221, Monifold Loss: 1147.981445, ColAE Loss: 1981.353027
# Epoch 15/499	(J=495)
#
# 	AE Loss: 522.969910, Monifold Loss: 1148.785767, ColAE Loss: 1958.952148
# Epoch 16/499	(J=495)
#
# 	AE Loss: 497.438690, Monifold Loss: 1149.767334, ColAE Loss: 1934.647949
# Epoch 17/499	(J=495)
#
# 	AE Loss: 475.039337, Monifold Loss: 1150.630127, ColAE Loss: 1913.326904
# Epoch 18/499	(J=495)
#
# 	AE Loss: 456.945007, Monifold Loss: 1151.171509, ColAE Loss: 1895.909424
# Epoch 19/499	(J=495)
#
# 	AE Loss: 443.048950, Monifold Loss: 1151.363525, ColAE Loss: 1882.253296
# Epoch 20/499	(J=495)
#
# 	AE Loss: 431.650696, Monifold Loss: 1151.322998, ColAE Loss: 1870.804443
# Epoch 21/499	(J=495)
#
# 	AE Loss: 420.861908, Monifold Loss: 1151.220825, ColAE Loss: 1859.887939
# Epoch 22/499	(J=495)
#
# 	AE Loss: 409.929718, Monifold Loss: 1151.189697, ColAE Loss: 1848.916748
# Epoch 23/499	(J=495)
#
# 	AE Loss: 398.688995, Monifold Loss: 1151.267578, ColAE Loss: 1837.773438
# Epoch 24/499	(J=495)
#
# 	AE Loss: 387.428680, Monifold Loss: 1151.404175, ColAE Loss: 1826.683960
# Epoch 25/499	(J=495)
#
# 	AE Loss: 377.058655, Monifold Loss: 1151.519531, ColAE Loss: 1816.458008
# Epoch 26/499	(J=495)
#
# 	AE Loss: 368.762054, Monifold Loss: 1151.566528, ColAE Loss: 1808.220215
# Epoch 27/499	(J=495)
#
# 	AE Loss: 362.678528, Monifold Loss: 1151.541138, ColAE Loss: 1802.104980
# Epoch 28/499	(J=495)
#
# 	AE Loss: 357.199707, Monifold Loss: 1151.467529, ColAE Loss: 1796.534180
# Epoch 29/499	(J=495)
#
# 	AE Loss: 350.486847, Monifold Loss: 1151.363281, ColAE Loss: 1789.690918
# Epoch 30/499	(J=495)
#
# 	AE Loss: 342.825043, Monifold Loss: 1151.239136, ColAE Loss: 1781.874023
# Epoch 31/499	(J=495)
#
# 	AE Loss: 336.139374, Monifold Loss: 1151.108276, ColAE Loss: 1775.024780
# Epoch 32/499	(J=495)
#
# 	AE Loss: 331.360260, Monifold Loss: 1150.991699, ColAE Loss: 1770.099854
# Epoch 33/499	(J=495)
#
# 	AE Loss: 327.419830, Monifold Loss: 1150.905396, ColAE Loss: 1766.051514
# Epoch 34/499	(J=495)
#
# 	AE Loss: 323.155090, Monifold Loss: 1150.841919, ColAE Loss: 1761.707520
# Epoch 35/499	(J=495)
#
# 	AE Loss: 318.688660, Monifold Loss: 1150.776855, ColAE Loss: 1757.159668
# Epoch 36/499	(J=495)
#
# 	AE Loss: 314.543152, Monifold Loss: 1150.670776, ColAE Loss: 1752.881592
# Epoch 37/499	(J=495)
#
# 	AE Loss: 310.945770, Monifold Loss: 1150.493652, ColAE Loss: 1749.062866
# Epoch 38/499	(J=495)
#
# 	AE Loss: 307.817596, Monifold Loss: 1150.240479, ColAE Loss: 1745.618164
# Epoch 39/499	(J=495)
#
# 	AE Loss: 304.879608, Monifold Loss: 1149.935059, ColAE Loss: 1742.298462
# Epoch 40/499	(J=495)
#
# 	AE Loss: 302.011078, Monifold Loss: 1149.613159, ColAE Loss: 1739.027588
# Epoch 41/499	(J=495)
#
# 	AE Loss: 299.261200, Monifold Loss: 1149.302612, ColAE Loss: 1735.889526
# Epoch 42/499	(J=495)
#
# 	AE Loss: 296.734985, Monifold Loss: 1149.009644, ColAE Loss: 1732.997070
# Epoch 43/499	(J=495)
#
# 	AE Loss: 294.513947, Monifold Loss: 1148.725952, ColAE Loss: 1730.421387
# Epoch 44/499	(J=495)
#
# 	AE Loss: 292.446777, Monifold Loss: 1148.450439, ColAE Loss: 1728.009766
# Epoch 45/499	(J=495)
#
# 	AE Loss: 290.343964, Monifold Loss: 1148.198730, ColAE Loss: 1725.592407
# Epoch 46/499	(J=495)
#
# 	AE Loss: 288.275055, Monifold Loss: 1147.978516, ColAE Loss: 1723.248169
# Epoch 47/499	(J=495)
#
# 	AE Loss: 286.435791, Monifold Loss: 1147.778809, ColAE Loss: 1721.159302
# Epoch 48/499	(J=495)
#
# 	AE Loss: 284.813416, Monifold Loss: 1147.569580, ColAE Loss: 1719.275391
# Epoch 49/499	(J=495)
#
# 	AE Loss: 283.206604, Monifold Loss: 1147.320312, ColAE Loss: 1717.356934
# Epoch 50/499	(J=495)
#
# 	AE Loss: 281.573578, Monifold Loss: 1147.017578, ColAE Loss: 1715.345581
# Epoch 51/499	(J=495)
#
# 	AE Loss: 280.059204, Monifold Loss: 1146.660767, ColAE Loss: 1713.385132
# Epoch 52/499	(J=495)
#
# 	AE Loss: 278.683044, Monifold Loss: 1146.276855, ColAE Loss: 1711.529053
# Epoch 53/499	(J=495)
#
# 	AE Loss: 277.345276, Monifold Loss: 1145.896606, ColAE Loss: 1709.716064
# Epoch 54/499	(J=495)
#
# 	AE Loss: 276.001587, Monifold Loss: 1145.522461, ColAE Loss: 1707.904663
# Epoch 55/499	(J=495)
#
# 	AE Loss: 274.726868, Monifold Loss: 1145.173340, ColAE Loss: 1706.193604
# Epoch 56/499	(J=495)
#
# 	AE Loss: 273.548645, Monifold Loss: 1144.820801, ColAE Loss: 1704.574707
# Epoch 57/499	(J=495)
#
# 	AE Loss: 272.418121, Monifold Loss: 1144.421509, ColAE Loss: 1702.944946
# Epoch 58/499	(J=495)
#
# 	AE Loss: 271.301819, Monifold Loss: 1143.964722, ColAE Loss: 1701.257812
# Epoch 59/499	(J=495)
#
# 	AE Loss: 270.192383, Monifold Loss: 1143.454346, ColAE Loss: 1699.510254
# Epoch 60/499	(J=495)
#
# 	AE Loss: 269.112732, Monifold Loss: 1142.899292, ColAE Loss: 1697.736816
# Epoch 61/499	(J=495)
#
# 	AE Loss: 268.109283, Monifold Loss: 1142.302734, ColAE Loss: 1695.987671
# Epoch 62/499	(J=495)
#
# 	AE Loss: 267.165436, Monifold Loss: 1141.717896, ColAE Loss: 1694.312744
# Epoch 63/499	(J=495)
#
# 	AE Loss: 266.255310, Monifold Loss: 1141.086914, ColAE Loss: 1692.614014
# Epoch 64/499	(J=495)
#
# 	AE Loss: 265.326141, Monifold Loss: 1140.424072, ColAE Loss: 1690.856201
# Epoch 65/499	(J=495)
#
# 	AE Loss: 264.399109, Monifold Loss: 1139.786499, ColAE Loss: 1689.132324
# Epoch 66/499	(J=495)
#
# 	AE Loss: 263.524689, Monifold Loss: 1139.081909, ColAE Loss: 1687.377075
# Epoch 67/499	(J=495)
#
# 	AE Loss: 262.690521, Monifold Loss: 1138.358398, ColAE Loss: 1685.638550
# Epoch 68/499	(J=495)
#
# 	AE Loss: 261.877167, Monifold Loss: 1137.690796, ColAE Loss: 1683.990723
# Epoch 69/499	(J=495)
#
# 	AE Loss: 261.081818, Monifold Loss: 1136.928955, ColAE Loss: 1682.242920
# Epoch 70/499	(J=495)
#
# 	AE Loss: 260.295563, Monifold Loss: 1136.080322, ColAE Loss: 1680.395874
# Epoch 71/499	(J=495)
#
# 	AE Loss: 259.526703, Monifold Loss: 1135.249512, ColAE Loss: 1678.588623
# Epoch 72/499	(J=495)
#
# 	AE Loss: 258.778290, Monifold Loss: 1134.305786, ColAE Loss: 1676.660522
# Epoch 73/499	(J=495)
#
# 	AE Loss: 258.080994, Monifold Loss: 1133.362305, ColAE Loss: 1674.783936
# Epoch 74/499	(J=495)
#
# 	AE Loss: 257.378082, Monifold Loss: 1132.611816, ColAE Loss: 1673.142822
# Epoch 75/499	(J=495)
#
# 	AE Loss: 256.649597, Monifold Loss: 1131.814697, ColAE Loss: 1671.417969
# Epoch 76/499	(J=495)
#
# 	AE Loss: 255.937668, Monifold Loss: 1131.018921, ColAE Loss: 1669.711304
# Epoch 77/499	(J=495)
#
# 	AE Loss: 255.278091, Monifold Loss: 1130.255371, ColAE Loss: 1668.097290
# Epoch 78/499	(J=495)
#
# 	AE Loss: 254.629929, Monifold Loss: 1129.285400, ColAE Loss: 1666.236572
# Epoch 79/499	(J=495)
#
# 	AE Loss: 253.958130, Monifold Loss: 1128.353149, ColAE Loss: 1664.399536
# Epoch 80/499	(J=495)
#
# 	AE Loss: 253.293549, Monifold Loss: 1127.737183, ColAE Loss: 1662.965088
# Epoch 81/499	(J=495)
#
# 	AE Loss: 252.669662, Monifold Loss: 1126.940796, ColAE Loss: 1661.345703
# Epoch 82/499	(J=495)
#
# 	AE Loss: 252.045731, Monifold Loss: 1126.166016, ColAE Loss: 1659.753296
# Epoch 83/499	(J=495)
#
# 	AE Loss: 251.421448, Monifold Loss: 1125.424072, ColAE Loss: 1658.201416
# Epoch 84/499	(J=495)
#
# 	AE Loss: 250.802887, Monifold Loss: 1124.929565, ColAE Loss: 1656.964844
# Epoch 85/499	(J=495)
#
# 	AE Loss: 250.201172, Monifold Loss: 1124.241333, ColAE Loss: 1655.502808
# Epoch 86/499	(J=495)
#
# 	AE Loss: 249.583710, Monifold Loss: 1123.056396, ColAE Loss: 1653.404297
# Epoch 87/499	(J=495)
#
# 	AE Loss: 249.006653, Monifold Loss: 1122.121704, ColAE Loss: 1651.658691
# Epoch 88/499	(J=495)
#
# 	AE Loss: 248.399353, Monifold Loss: 1121.415771, ColAE Loss: 1650.169189
# Epoch 89/499	(J=495)
#
# 	AE Loss: 247.843643, Monifold Loss: 1120.532227, ColAE Loss: 1648.508911
# Epoch 90/499	(J=495)
#
# 	AE Loss: 247.241028, Monifold Loss: 1119.319336, ColAE Loss: 1646.390137
# Epoch 91/499	(J=495)
#
# 	AE Loss: 246.705063, Monifold Loss: 1117.837891, ColAE Loss: 1644.002441
# Epoch 92/499	(J=495)
#
# 	AE Loss: 246.140976, Monifold Loss: 1117.110718, ColAE Loss: 1642.529419
# Epoch 93/499	(J=495)
#
# 	AE Loss: 245.604813, Monifold Loss: 1116.059326, ColAE Loss: 1640.679077
# Epoch 94/499	(J=495)
#
# 	AE Loss: 245.033035, Monifold Loss: 1115.114380, ColAE Loss: 1638.926025
# Epoch 95/499	(J=495)
#
# 	AE Loss: 244.518173, Monifold Loss: 1113.611938, ColAE Loss: 1636.533081
# Epoch 96/499	(J=495)
#
# 	AE Loss: 243.987579, Monifold Loss: 1112.587036, ColAE Loss: 1634.721313
# Epoch 97/499	(J=495)
#
# 	AE Loss: 243.465302, Monifold Loss: 1111.766846, ColAE Loss: 1633.173828
# Epoch 98/499	(J=495)
#
# 	AE Loss: 242.952713, Monifold Loss: 1110.491943, ColAE Loss: 1631.067749
# Epoch 99/499	(J=495)
#
# 	AE Loss: 242.451111, Monifold Loss: 1109.103149, ColAE Loss: 1628.830078
# Epoch 100/499	(J=495)
#
# 	AE Loss: 241.938309, Monifold Loss: 1107.915405, ColAE Loss: 1626.832642
# Epoch 101/499	(J=495)
#
# 	AE Loss: 241.457169, Monifold Loss: 1107.053833, ColAE Loss: 1625.274414
# Epoch 102/499	(J=495)
#
# 	AE Loss: 240.956039, Monifold Loss: 1105.774048, ColAE Loss: 1623.173584
# Epoch 103/499	(J=495)
#
# 	AE Loss: 240.485657, Monifold Loss: 1104.159668, ColAE Loss: 1620.685303
# Epoch 104/499	(J=495)
#
# 	AE Loss: 239.996857, Monifold Loss: 1103.275391, ColAE Loss: 1619.091064
# Epoch 105/499	(J=495)
#
# 	AE Loss: 239.529358, Monifold Loss: 1102.116333, ColAE Loss: 1617.174805
# Epoch 106/499	(J=495)
#
# 	AE Loss: 239.053513, Monifold Loss: 1100.654663, ColAE Loss: 1614.871826
# Epoch 107/499	(J=495)
#
# 	AE Loss: 238.600143, Monifold Loss: 1099.450439, ColAE Loss: 1612.913086
# Epoch 108/499	(J=495)
#
# 	AE Loss: 238.140549, Monifold Loss: 1098.490845, ColAE Loss: 1611.254028
# Epoch 109/499	(J=495)
#
# 	AE Loss: 237.685745, Monifold Loss: 1097.295532, ColAE Loss: 1609.305176
# Epoch 110/499	(J=495)
#
# 	AE Loss: 237.238586, Monifold Loss: 1095.782837, ColAE Loss: 1606.967041
# Epoch 111/499	(J=495)
#
# 	AE Loss: 236.788422, Monifold Loss: 1094.794312, ColAE Loss: 1605.281372
# Epoch 112/499	(J=495)
#
# 	AE Loss: 236.355515, Monifold Loss: 1093.914917, ColAE Loss: 1603.749146
# Epoch 113/499	(J=495)
#
# 	AE Loss: 235.914627, Monifold Loss: 1092.516724, ColAE Loss: 1601.560547
# Epoch 114/499	(J=495)
#
# 	AE Loss: 235.480698, Monifold Loss: 1091.439331, ColAE Loss: 1599.779907
# Epoch 115/499	(J=495)
#
# 	AE Loss: 235.051636, Monifold Loss: 1090.493286, ColAE Loss: 1598.168213
# Epoch 116/499	(J=495)
#
# 	AE Loss: 234.619461, Monifold Loss: 1089.304321, ColAE Loss: 1596.249878
# Epoch 117/499	(J=495)
#
# 	AE Loss: 234.200119, Monifold Loss: 1088.209717, ColAE Loss: 1594.462280
# Epoch 118/499	(J=495)
#
# 	AE Loss: 233.778885, Monifold Loss: 1087.349854, ColAE Loss: 1592.966187
# Epoch 119/499	(J=495)
#
# 	AE Loss: 233.356003, Monifold Loss: 1086.251587, ColAE Loss: 1591.170410
# Epoch 120/499	(J=495)
#
# 	AE Loss: 232.945969, Monifold Loss: 1085.047119, ColAE Loss: 1589.254761
# Epoch 121/499	(J=495)
#
# 	AE Loss: 232.527573, Monifold Loss: 1084.332886, ColAE Loss: 1587.943726
# Epoch 122/499	(J=495)
#
# 	AE Loss: 232.113892, Monifold Loss: 1083.155396, ColAE Loss: 1586.058105
# Epoch 123/499	(J=495)
#
# 	AE Loss: 231.714600, Monifold Loss: 1082.041870, ColAE Loss: 1584.266968
# Epoch 124/499	(J=495)
#
# 	AE Loss: 231.304520, Monifold Loss: 1081.226807, ColAE Loss: 1582.838013
# Epoch 125/499	(J=495)
#
# 	AE Loss: 230.900009, Monifold Loss: 1080.217407, ColAE Loss: 1581.171753
# Epoch 126/499	(J=495)
#
# 	AE Loss: 230.502808, Monifold Loss: 1078.950928, ColAE Loss: 1579.191528
# Epoch 127/499	(J=495)
#
# 	AE Loss: 230.104187, Monifold Loss: 1078.333984, ColAE Loss: 1578.021729
# Epoch 128/499	(J=495)
#
# 	AE Loss: 229.704636, Monifold Loss: 1076.832275, ColAE Loss: 1575.744873
# Epoch 129/499	(J=495)
#
# 	AE Loss: 229.310699, Monifold Loss: 1076.079834, ColAE Loss: 1574.410522
# Epoch 130/499	(J=495)
#
# 	AE Loss: 228.923126, Monifold Loss: 1075.002075, ColAE Loss: 1572.675659
# Epoch 131/499	(J=495)
#
# 	AE Loss: 228.532623, Monifold Loss: 1073.735107, ColAE Loss: 1570.701538
# Epoch 132/499	(J=495)
#
# 	AE Loss: 228.142715, Monifold Loss: 1072.823486, ColAE Loss: 1569.171997
# Epoch 133/499	(J=495)
#
# 	AE Loss: 227.759491, Monifold Loss: 1071.483887, ColAE Loss: 1567.114380
# Epoch 134/499	(J=495)
#
# 	AE Loss: 227.381058, Monifold Loss: 1070.484131, ColAE Loss: 1565.486328
# Epoch 135/499	(J=495)
#
# 	AE Loss: 227.005844, Monifold Loss: 1069.183594, ColAE Loss: 1563.485352
# Epoch 136/499	(J=495)
#
# 	AE Loss: 226.636978, Monifold Loss: 1067.827271, ColAE Loss: 1561.421021
# Epoch 137/499	(J=495)
#
# 	AE Loss: 226.273926, Monifold Loss: 1066.939209, ColAE Loss: 1559.947998
# Epoch 138/499	(J=495)
#
# 	AE Loss: 225.903854, Monifold Loss: 1065.432251, ColAE Loss: 1557.694092
# Epoch 139/499	(J=495)
#
# 	AE Loss: 225.533676, Monifold Loss: 1064.468384, ColAE Loss: 1556.119141
# Epoch 140/499	(J=495)
#
# 	AE Loss: 225.178665, Monifold Loss: 1063.284302, ColAE Loss: 1554.284058
# Epoch 141/499	(J=495)
#
# 	AE Loss: 224.829880, Monifold Loss: 1061.967163, ColAE Loss: 1552.288818
# Epoch 142/499	(J=495)
#
# 	AE Loss: 224.481995, Monifold Loss: 1060.879150, ColAE Loss: 1550.580811
# Epoch 143/499	(J=495)
#
# 	AE Loss: 224.126999, Monifold Loss: 1059.543457, ColAE Loss: 1548.556274
# Epoch 144/499	(J=495)
#
# 	AE Loss: 223.763199, Monifold Loss: 1058.198853, ColAE Loss: 1546.511719
# Epoch 145/499	(J=495)
#
# 	AE Loss: 223.407166, Monifold Loss: 1057.283691, ColAE Loss: 1545.011719
# Epoch 146/499	(J=495)
#
# 	AE Loss: 223.058395, Monifold Loss: 1055.631836, ColAE Loss: 1542.598145
# Epoch 147/499	(J=495)
#
# 	AE Loss: 222.714661, Monifold Loss: 1054.739990, ColAE Loss: 1541.139648
# Epoch 148/499	(J=495)
#
# 	AE Loss: 222.375336, Monifold Loss: 1053.177368, ColAE Loss: 1538.847046
# Epoch 149/499	(J=495)
#
# 	AE Loss: 222.032181, Monifold Loss: 1051.917480, ColAE Loss: 1536.929077
# Epoch 150/499	(J=495)
#
# 	AE Loss: 221.694595, Monifold Loss: 1050.983521, ColAE Loss: 1535.423950
# Epoch 151/499	(J=495)
#
# 	AE Loss: 221.352905, Monifold Loss: 1049.175049, ColAE Loss: 1532.821655
# Epoch 152/499	(J=495)
#
# 	AE Loss: 221.022797, Monifold Loss: 1048.599243, ColAE Loss: 1531.771851
# Epoch 153/499	(J=495)
#
# 	AE Loss: 220.687515, Monifold Loss: 1046.944702, ColAE Loss: 1529.368408
# Epoch 154/499	(J=495)
#
# 	AE Loss: 220.357712, Monifold Loss: 1045.891113, ColAE Loss: 1527.721558
# Epoch 155/499	(J=495)
#
# 	AE Loss: 220.030289, Monifold Loss: 1045.112061, ColAE Loss: 1526.420410
# Epoch 156/499	(J=495)
#
# 	AE Loss: 219.700592, Monifold Loss: 1043.630981, ColAE Loss: 1524.239258
# Epoch 157/499	(J=495)
#
# 	AE Loss: 219.383148, Monifold Loss: 1042.838623, ColAE Loss: 1522.931519
# Epoch 158/499	(J=495)
#
# 	AE Loss: 219.059296, Monifold Loss: 1041.810547, ColAE Loss: 1521.322510
# Epoch 159/499	(J=495)
#
# 	AE Loss: 218.739990, Monifold Loss: 1041.265015, ColAE Loss: 1520.321289
# Epoch 160/499	(J=495)
#
# 	AE Loss: 218.420563, Monifold Loss: 1040.068970, ColAE Loss: 1518.506714
# Epoch 161/499	(J=495)
#
# 	AE Loss: 218.102173, Monifold Loss: 1039.207031, ColAE Loss: 1517.110962
# Epoch 162/499	(J=495)
#
# 	AE Loss: 217.788055, Monifold Loss: 1038.739990, ColAE Loss: 1516.213135
# Epoch 163/499	(J=495)
#
# 	AE Loss: 217.475266, Monifold Loss: 1037.623413, ColAE Loss: 1514.504517
# Epoch 164/499	(J=495)
#
# 	AE Loss: 217.166122, Monifold Loss: 1036.974121, ColAE Loss: 1513.383789
# Epoch 165/499	(J=495)
#
# 	AE Loss: 216.854019, Monifold Loss: 1036.080811, ColAE Loss: 1511.955078
# Epoch 166/499	(J=495)
#
# 	AE Loss: 216.550751, Monifold Loss: 1035.556030, ColAE Loss: 1510.995850
# Epoch 167/499	(J=495)
#
# 	AE Loss: 216.248306, Monifold Loss: 1034.532349, ColAE Loss: 1509.413696
# Epoch 168/499	(J=495)
#
# 	AE Loss: 215.949661, Monifold Loss: 1033.690918, ColAE Loss: 1508.063354
# Epoch 169/499	(J=495)
#
# 	AE Loss: 215.653244, Monifold Loss: 1033.079224, ColAE Loss: 1507.002197
# Epoch 170/499	(J=495)
#
# 	AE Loss: 215.344437, Monifold Loss: 1032.036377, ColAE Loss: 1505.389893
# Epoch 171/499	(J=495)
#
# 	AE Loss: 215.036041, Monifold Loss: 1031.208374, ColAE Loss: 1504.046509
# Epoch 172/499	(J=495)
#
# 	AE Loss: 214.736435, Monifold Loss: 1030.377319, ColAE Loss: 1502.708130
# Epoch 173/499	(J=495)
#
# 	AE Loss: 214.447632, Monifold Loss: 1029.376587, ColAE Loss: 1501.168335
# Epoch 174/499	(J=495)
#
# 	AE Loss: 214.159180, Monifold Loss: 1028.343994, ColAE Loss: 1499.589111
# Epoch 175/499	(J=495)
#
# 	AE Loss: 213.863831, Monifold Loss: 1027.428345, ColAE Loss: 1498.149170
# Epoch 176/499	(J=495)
#
# 	AE Loss: 213.574463, Monifold Loss: 1026.304565, ColAE Loss: 1496.455200
# Epoch 177/499	(J=495)
#
# 	AE Loss: 213.289398, Monifold Loss: 1025.220825, ColAE Loss: 1494.815430
# Epoch 178/499	(J=495)
#
# 	AE Loss: 212.998734, Monifold Loss: 1024.009521, ColAE Loss: 1493.010742
# Epoch 179/499	(J=495)
#
# 	AE Loss: 212.708359, Monifold Loss: 1023.093506, ColAE Loss: 1491.575317
# Epoch 180/499	(J=495)
#
# 	AE Loss: 212.423828, Monifold Loss: 1021.546570, ColAE Loss: 1489.357056
# Epoch 181/499	(J=495)
#
# 	AE Loss: 212.142288, Monifold Loss: 1020.596802, ColAE Loss: 1487.888306
# Epoch 182/499	(J=495)
#
# 	AE Loss: 211.864151, Monifold Loss: 1019.237122, ColAE Loss: 1485.910522
# Epoch 183/499	(J=495)
#
# 	AE Loss: 211.580383, Monifold Loss: 1018.002869, ColAE Loss: 1484.083984
# Epoch 184/499	(J=495)
#
# 	AE Loss: 211.300095, Monifold Loss: 1016.681641, ColAE Loss: 1482.152100
# Epoch 185/499	(J=495)
#
# 	AE Loss: 211.025085, Monifold Loss: 1015.335571, ColAE Loss: 1480.194580
# Epoch 186/499	(J=495)
#
# 	AE Loss: 210.746750, Monifold Loss: 1014.152466, ColAE Loss: 1478.437256
# Epoch 187/499	(J=495)
#
# 	AE Loss: 210.470291, Monifold Loss: 1012.521240, ColAE Loss: 1476.121948
# Epoch 188/499	(J=495)
#
# 	AE Loss: 210.196060, Monifold Loss: 1011.390686, ColAE Loss: 1474.434448
# Epoch 189/499	(J=495)
#
# 	AE Loss: 209.928421, Monifold Loss: 1009.909424, ColAE Loss: 1472.315186
# Epoch 190/499	(J=495)
#
# 	AE Loss: 209.659058, Monifold Loss: 1008.504578, ColAE Loss: 1470.289795
# Epoch 191/499	(J=495)
#
# 	AE Loss: 209.388443, Monifold Loss: 1007.097534, ColAE Loss: 1468.260376
# Epoch 192/499	(J=495)
#
# 	AE Loss: 209.126770, Monifold Loss: 1005.951965, ColAE Loss: 1466.566650
# Epoch 193/499	(J=495)
#
# 	AE Loss: 208.858261, Monifold Loss: 1004.372131, ColAE Loss: 1464.323486
# Epoch 194/499	(J=495)
#
# 	AE Loss: 208.589142, Monifold Loss: 1003.202087, ColAE Loss: 1462.591675
# Epoch 195/499	(J=495)
#
# 	AE Loss: 208.320404, Monifold Loss: 1001.931213, ColAE Loss: 1460.734497
# Epoch 196/499	(J=495)
#
# 	AE Loss: 208.055573, Monifold Loss: 1000.512146, ColAE Loss: 1458.695679
# Epoch 197/499	(J=495)
#
# 	AE Loss: 207.796936, Monifold Loss: 999.453918, ColAE Loss: 1457.114258
# Epoch 198/499	(J=495)
#
# 	AE Loss: 207.541931, Monifold Loss: 997.995300, ColAE Loss: 1455.036133
# Epoch 199/499	(J=495)
#
# 	AE Loss: 207.287964, Monifold Loss: 997.137512, ColAE Loss: 1453.709839
# Epoch 200/499	(J=495)
#
# 	AE Loss: 207.024368, Monifold Loss: 995.769958, ColAE Loss: 1451.736816
# Epoch 201/499	(J=495)
#
# 	AE Loss: 206.766708, Monifold Loss: 994.614502, ColAE Loss: 1450.034790
# Epoch 202/499	(J=495)
#
# 	AE Loss: 206.519821, Monifold Loss: 993.784058, ColAE Loss: 1448.749878
# Epoch 203/499	(J=495)
#
# 	AE Loss: 206.268631, Monifold Loss: 992.474243, ColAE Loss: 1446.861450
# Epoch 204/499	(J=495)
#
# 	AE Loss: 206.011520, Monifold Loss: 991.776611, ColAE Loss: 1445.732178
# Epoch 205/499	(J=495)
#
# 	AE Loss: 205.763245, Monifold Loss: 990.643127, ColAE Loss: 1444.067139
# Epoch 206/499	(J=495)
#
# 	AE Loss: 205.512573, Monifold Loss: 989.582520, ColAE Loss: 1442.490723
# Epoch 207/499	(J=495)
#
# 	AE Loss: 205.268646, Monifold Loss: 989.006042, ColAE Loss: 1441.526245
# Epoch 208/499	(J=495)
#
# 	AE Loss: 205.018616, Monifold Loss: 987.804749, ColAE Loss: 1439.774658
# Epoch 209/499	(J=495)
#
# 	AE Loss: 204.780594, Monifold Loss: 987.023987, ColAE Loss: 1438.560669
# Epoch 210/499	(J=495)
#
# 	AE Loss: 204.537979, Monifold Loss: 986.119141, ColAE Loss: 1437.186890
# Epoch 211/499	(J=495)
#
# 	AE Loss: 204.290527, Monifold Loss: 985.501343, ColAE Loss: 1436.167236
# Epoch 212/499	(J=495)
#
# 	AE Loss: 204.049316, Monifold Loss: 984.431274, ColAE Loss: 1434.588379
# Epoch 213/499	(J=495)
#
# 	AE Loss: 203.813904, Monifold Loss: 983.763123, ColAE Loss: 1433.517822
# Epoch 214/499	(J=495)
#
# 	AE Loss: 203.572342, Monifold Loss: 982.827881, ColAE Loss: 1432.107300
# Epoch 215/499	(J=495)
#
# 	AE Loss: 203.332230, Monifold Loss: 982.092896, ColAE Loss: 1430.948364
# Epoch 216/499	(J=495)
#
# 	AE Loss: 203.098663, Monifold Loss: 981.457703, ColAE Loss: 1429.920776
# Epoch 217/499	(J=495)
#
# 	AE Loss: 202.866531, Monifold Loss: 980.346313, ColAE Loss: 1428.299438
# Epoch 218/499	(J=495)
#
# 	AE Loss: 202.635605, Monifold Loss: 979.971802, ColAE Loss: 1427.600342
# Epoch 219/499	(J=495)
#
# 	AE Loss: 202.400177, Monifold Loss: 978.937378, ColAE Loss: 1426.071899
# Epoch 220/499	(J=495)
#
# 	AE Loss: 202.168304, Monifold Loss: 978.284729, ColAE Loss: 1425.024292
# Epoch 221/499	(J=495)
#
# 	AE Loss: 201.943680, Monifold Loss: 977.489990, ColAE Loss: 1423.806274
# Epoch 222/499	(J=495)
#
# 	AE Loss: 201.720367, Monifold Loss: 976.669495, ColAE Loss: 1422.557251
# Epoch 223/499	(J=495)
#
# 	AE Loss: 201.493927, Monifold Loss: 976.084778, ColAE Loss: 1421.599854
# Epoch 224/499	(J=495)
#
# 	AE Loss: 201.268402, Monifold Loss: 975.154602, ColAE Loss: 1420.211670
# Epoch 225/499	(J=495)
#
# 	AE Loss: 201.043549, Monifold Loss: 974.596558, ColAE Loss: 1419.289307
# Epoch 226/499	(J=495)
#
# 	AE Loss: 200.820892, Monifold Loss: 973.704224, ColAE Loss: 1417.951172
# Epoch 227/499	(J=495)
#
# 	AE Loss: 200.597412, Monifold Loss: 973.073303, ColAE Loss: 1416.939087
# Epoch 228/499	(J=495)
#
# 	AE Loss: 200.372635, Monifold Loss: 972.272949, ColAE Loss: 1415.713867
# Epoch 229/499	(J=495)
#
# 	AE Loss: 200.149719, Monifold Loss: 971.502136, ColAE Loss: 1414.527344
# Epoch 230/499	(J=495)
#
# 	AE Loss: 199.934586, Monifold Loss: 970.825867, ColAE Loss: 1413.466919
# Epoch 231/499	(J=495)
#
# 	AE Loss: 199.720963, Monifold Loss: 970.012146, ColAE Loss: 1412.236084
# Epoch 232/499	(J=495)
#
# 	AE Loss: 199.504242, Monifold Loss: 969.363464, ColAE Loss: 1411.208618
# Epoch 233/499	(J=495)
#
# 	AE Loss: 199.288193, Monifold Loss: 968.584717, ColAE Loss: 1410.019165
# Epoch 234/499	(J=495)
#
# 	AE Loss: 199.067581, Monifold Loss: 967.932312, ColAE Loss: 1408.983032
# Epoch 235/499	(J=495)
#
# 	AE Loss: 198.854752, Monifold Loss: 967.195740, ColAE Loss: 1407.849365
# Epoch 236/499	(J=495)
#
# 	AE Loss: 198.644653, Monifold Loss: 966.443176, ColAE Loss: 1406.698608
# Epoch 237/499	(J=495)
#
# 	AE Loss: 198.432693, Monifold Loss: 965.934387, ColAE Loss: 1405.850708
# Epoch 238/499	(J=495)
#
# 	AE Loss: 198.225357, Monifold Loss: 965.047424, ColAE Loss: 1404.534668
# Epoch 239/499	(J=495)
#
# 	AE Loss: 198.020172, Monifold Loss: 964.706116, ColAE Loss: 1403.902832
# Epoch 240/499	(J=495)
#
# 	AE Loss: 197.810806, Monifold Loss: 963.627869, ColAE Loss: 1402.345581
# Epoch 241/499	(J=495)
#
# 	AE Loss: 197.604141, Monifold Loss: 963.291870, ColAE Loss: 1401.718994
# Epoch 242/499	(J=495)
#
# 	AE Loss: 197.391373, Monifold Loss: 962.487061, ColAE Loss: 1400.500244
# Epoch 243/499	(J=495)
#
# 	AE Loss: 197.182831, Monifold Loss: 961.834656, ColAE Loss: 1399.476196
# Epoch 244/499	(J=495)
#
# 	AE Loss: 196.980347, Monifold Loss: 961.367615, ColAE Loss: 1398.689819
# Epoch 245/499	(J=495)
#
# 	AE Loss: 196.776932, Monifold Loss: 960.450012, ColAE Loss: 1397.339478
# Epoch 246/499	(J=495)
#
# 	AE Loss: 196.575470, Monifold Loss: 960.080566, ColAE Loss: 1396.676147
# Epoch 247/499	(J=495)
#
# 	AE Loss: 196.371948, Monifold Loss: 959.263123, ColAE Loss: 1395.450806
# Epoch 248/499	(J=495)
#
# 	AE Loss: 196.169861, Monifold Loss: 958.809509, ColAE Loss: 1394.681641
# Epoch 249/499	(J=495)
#
# 	AE Loss: 195.969131, Monifold Loss: 958.208496, ColAE Loss: 1393.729736
# Epoch 250/499	(J=495)
#
# 	AE Loss: 195.766708, Monifold Loss: 957.434265, ColAE Loss: 1392.559570
# Epoch 251/499	(J=495)
#
# 	AE Loss: 195.571854, Monifold Loss: 957.085693, ColAE Loss: 1391.929077
# Epoch 252/499	(J=495)
#
# 	AE Loss: 195.375549, Monifold Loss: 956.193909, ColAE Loss: 1390.617920
# Epoch 253/499	(J=495)
#
# 	AE Loss: 195.180603, Monifold Loss: 955.845764, ColAE Loss: 1389.987793
# Epoch 254/499	(J=495)
#
# 	AE Loss: 194.985001, Monifold Loss: 955.145264, ColAE Loss: 1388.916626
# Epoch 255/499	(J=495)
#
# 	AE Loss: 194.791718, Monifold Loss: 954.586487, ColAE Loss: 1388.024902
# Epoch 256/499	(J=495)
#
# 	AE Loss: 194.600418, Monifold Loss: 954.149048, ColAE Loss: 1387.286743
# Epoch 257/499	(J=495)
#
# 	AE Loss: 194.408218, Monifold Loss: 953.412720, ColAE Loss: 1386.174072
# Epoch 258/499	(J=495)
#
# 	AE Loss: 194.216934, Monifold Loss: 953.013855, ColAE Loss: 1385.484253
# Epoch 259/499	(J=495)
#
# 	AE Loss: 194.029205, Monifold Loss: 952.409790, ColAE Loss: 1384.541382
# Epoch 260/499	(J=495)
#
# 	AE Loss: 193.840668, Monifold Loss: 951.968567, ColAE Loss: 1383.801392
# Epoch 261/499	(J=495)
#
# 	AE Loss: 193.651825, Monifold Loss: 951.378967, ColAE Loss: 1382.875610
# Epoch 262/499	(J=495)
#
# 	AE Loss: 193.465164, Monifold Loss: 950.986694, ColAE Loss: 1382.198608
# Epoch 263/499	(J=495)
#
# 	AE Loss: 193.281204, Monifold Loss: 950.262878, ColAE Loss: 1381.109863
# Epoch 264/499	(J=495)
#
# 	AE Loss: 193.097137, Monifold Loss: 950.020752, ColAE Loss: 1380.623047
# Epoch 265/499	(J=495)
#
# 	AE Loss: 192.913712, Monifold Loss: 949.243896, ColAE Loss: 1379.468628
# Epoch 266/499	(J=495)
#
# 	AE Loss: 192.732040, Monifold Loss: 948.881836, ColAE Loss: 1378.834351
# Epoch 267/499	(J=495)
#
# 	AE Loss: 192.550827, Monifold Loss: 948.451477, ColAE Loss: 1378.115112
# Epoch 268/499	(J=495)
#
# 	AE Loss: 192.372070, Monifold Loss: 947.742493, ColAE Loss: 1377.050171
# Epoch 269/499	(J=495)
#
# 	AE Loss: 192.195145, Monifold Loss: 947.564819, ColAE Loss: 1376.651245
# Epoch 270/499	(J=495)
#
# 	AE Loss: 192.017059, Monifold Loss: 946.824036, ColAE Loss: 1375.547119
# Epoch 271/499	(J=495)
#
# 	AE Loss: 191.839752, Monifold Loss: 946.411743, ColAE Loss: 1374.854370
# Epoch 272/499	(J=495)
#
# 	AE Loss: 191.662796, Monifold Loss: 946.002747, ColAE Loss: 1374.166260
# Epoch 273/499	(J=495)
#
# 	AE Loss: 191.491577, Monifold Loss: 945.307068, ColAE Loss: 1373.125366
# Epoch 274/499	(J=495)
#
# 	AE Loss: 191.319351, Monifold Loss: 945.002319, ColAE Loss: 1372.572266
# Epoch 275/499	(J=495)
#
# 	AE Loss: 191.147202, Monifold Loss: 944.400391, ColAE Loss: 1371.647705
# Epoch 276/499	(J=495)
#
# 	AE Loss: 190.974976, Monifold Loss: 943.920044, ColAE Loss: 1370.875000
# Epoch 277/499	(J=495)
#
# 	AE Loss: 190.804688, Monifold Loss: 943.460083, ColAE Loss: 1370.129761
# Epoch 278/499	(J=495)
#
# 	AE Loss: 190.633118, Monifold Loss: 942.964905, ColAE Loss: 1369.339355
# Epoch 279/499	(J=495)
#
# 	AE Loss: 190.463562, Monifold Loss: 942.413452, ColAE Loss: 1368.480469
# Epoch 280/499	(J=495)
#
# 	AE Loss: 190.296280, Monifold Loss: 942.038513, ColAE Loss: 1367.844360
# Epoch 281/499	(J=495)
#
# 	AE Loss: 190.127655, Monifold Loss: 941.431702, ColAE Loss: 1366.917358
# Epoch 282/499	(J=495)
#
# 	AE Loss: 189.960419, Monifold Loss: 941.020203, ColAE Loss: 1366.235718
# Epoch 283/499	(J=495)
#
# 	AE Loss: 189.796555, Monifold Loss: 940.545715, ColAE Loss: 1365.478638
# Epoch 284/499	(J=495)
#
# 	AE Loss: 189.633026, Monifold Loss: 940.001465, ColAE Loss: 1364.634888
# Epoch 285/499	(J=495)
#
# 	AE Loss: 189.469543, Monifold Loss: 939.595947, ColAE Loss: 1363.964355
# Epoch 286/499	(J=495)
#
# 	AE Loss: 189.306900, Monifold Loss: 939.063599, ColAE Loss: 1363.136353
# Epoch 287/499	(J=495)
#
# 	AE Loss: 189.143463, Monifold Loss: 938.615479, ColAE Loss: 1362.412720
# Epoch 288/499	(J=495)
#
# 	AE Loss: 188.982391, Monifold Loss: 938.140198, ColAE Loss: 1361.657715
# Epoch 289/499	(J=495)
#
# 	AE Loss: 188.822372, Monifold Loss: 937.689392, ColAE Loss: 1360.934082
# Epoch 290/499	(J=495)
#
# 	AE Loss: 188.662643, Monifold Loss: 937.178345, ColAE Loss: 1360.135498
# Epoch 291/499	(J=495)
#
# 	AE Loss: 188.503754, Monifold Loss: 936.807312, ColAE Loss: 1359.512939
# Epoch 292/499	(J=495)
#
# 	AE Loss: 188.347610, Monifold Loss: 936.264160, ColAE Loss: 1358.677856
# Epoch 293/499	(J=495)
#
# 	AE Loss: 188.190857, Monifold Loss: 935.880676, ColAE Loss: 1358.041748
# Epoch 294/499	(J=495)
#
# 	AE Loss: 188.035172, Monifold Loss: 935.412537, ColAE Loss: 1357.300781
# Epoch 295/499	(J=495)
#
# 	AE Loss: 187.879440, Monifold Loss: 934.943970, ColAE Loss: 1356.559326
# Epoch 296/499	(J=495)
#
# 	AE Loss: 187.726715, Monifold Loss: 934.562012, ColAE Loss: 1355.929199
# Epoch 297/499	(J=495)
#
# 	AE Loss: 187.572800, Monifold Loss: 934.059631, ColAE Loss: 1355.147339
# Epoch 298/499	(J=495)
#
# 	AE Loss: 187.420090, Monifold Loss: 933.689392, ColAE Loss: 1354.531738
# Epoch 299/499	(J=495)
#
# 	AE Loss: 187.270233, Monifold Loss: 933.209534, ColAE Loss: 1353.782227
# Epoch 300/499	(J=495)
#
# 	AE Loss: 187.118561, Monifold Loss: 932.828613, ColAE Loss: 1353.154297
# Epoch 301/499	(J=495)
#
# 	AE Loss: 186.968246, Monifold Loss: 932.363586, ColAE Loss: 1352.422729
# Epoch 302/499	(J=495)
#
# 	AE Loss: 186.821045, Monifold Loss: 931.994812, ColAE Loss: 1351.814575
# Epoch 303/499	(J=495)
#
# 	AE Loss: 186.672363, Monifold Loss: 931.527710, ColAE Loss: 1351.082031
# Epoch 304/499	(J=495)
#
# 	AE Loss: 186.524033, Monifold Loss: 931.180542, ColAE Loss: 1350.499756
# Epoch 305/499	(J=495)
#
# 	AE Loss: 186.376968, Monifold Loss: 930.702637, ColAE Loss: 1349.755249
# Epoch 306/499	(J=495)
#
# 	AE Loss: 186.231384, Monifold Loss: 930.325562, ColAE Loss: 1349.138428
# Epoch 307/499	(J=495)
#
# 	AE Loss: 186.085220, Monifold Loss: 929.900085, ColAE Loss: 1348.460327
# Epoch 308/499	(J=495)
#
# 	AE Loss: 185.942734, Monifold Loss: 929.491028, ColAE Loss: 1347.806519
# Epoch 309/499	(J=495)
#
# 	AE Loss: 185.800140, Monifold Loss: 929.082214, ColAE Loss: 1347.152954
# Epoch 310/499	(J=495)
#
# 	AE Loss: 185.658096, Monifold Loss: 928.664124, ColAE Loss: 1346.488281
# Epoch 311/499	(J=495)
#
# 	AE Loss: 185.516617, Monifold Loss: 928.251831, ColAE Loss: 1345.831421
# Epoch 312/499	(J=495)
#
# 	AE Loss: 185.375580, Monifold Loss: 927.836975, ColAE Loss: 1345.171875
# Epoch 313/499	(J=495)
#
# 	AE Loss: 185.236542, Monifold Loss: 927.417908, ColAE Loss: 1344.508911
# Epoch 314/499	(J=495)
#
# 	AE Loss: 185.097290, Monifold Loss: 927.017151, ColAE Loss: 1343.868774
# Epoch 315/499	(J=495)
#
# 	AE Loss: 184.959457, Monifold Loss: 926.561401, ColAE Loss: 1343.161255
# Epoch 316/499	(J=495)
#
# 	AE Loss: 184.823517, Monifold Loss: 926.195740, ColAE Loss: 1342.568115
# Epoch 317/499	(J=495)
#
# 	AE Loss: 184.686752, Monifold Loss: 925.725403, ColAE Loss: 1341.843506
# Epoch 318/499	(J=495)
#
# 	AE Loss: 184.547806, Monifold Loss: 925.332214, ColAE Loss: 1341.213135
# Epoch 319/499	(J=495)
#
# 	AE Loss: 184.413147, Monifold Loss: 924.913757, ColAE Loss: 1340.555420
# Epoch 320/499	(J=495)
#
# 	AE Loss: 184.281387, Monifold Loss: 924.446960, ColAE Loss: 1339.840088
# Epoch 321/499	(J=495)
#
# 	AE Loss: 184.145981, Monifold Loss: 924.065735, ColAE Loss: 1339.228149
# Epoch 322/499	(J=495)
#
# 	AE Loss: 184.012589, Monifold Loss: 923.582642, ColAE Loss: 1338.490845
# Epoch 323/499	(J=495)
#
# 	AE Loss: 183.882309, Monifold Loss: 923.187622, ColAE Loss: 1337.866821
# Epoch 324/499	(J=495)
#
# 	AE Loss: 183.750610, Monifold Loss: 922.741333, ColAE Loss: 1337.177246
# Epoch 325/499	(J=495)
#
# 	AE Loss: 183.620575, Monifold Loss: 922.294983, ColAE Loss: 1336.489380
# Epoch 326/499	(J=495)
#
# 	AE Loss: 183.490784, Monifold Loss: 921.873413, ColAE Loss: 1335.832520
# Epoch 327/499	(J=495)
#
# 	AE Loss: 183.360001, Monifold Loss: 921.415161, ColAE Loss: 1335.128906
# Epoch 328/499	(J=495)
#
# 	AE Loss: 183.233063, Monifold Loss: 920.970459, ColAE Loss: 1334.446167
# Epoch 329/499	(J=495)
#
# 	AE Loss: 183.105911, Monifold Loss: 920.552307, ColAE Loss: 1333.796387
# Epoch 330/499	(J=495)
#
# 	AE Loss: 182.981079, Monifold Loss: 920.058044, ColAE Loss: 1333.053589
# Epoch 331/499	(J=495)
#
# 	AE Loss: 182.853516, Monifold Loss: 919.682190, ColAE Loss: 1332.456299
# Epoch 332/499	(J=495)
#
# 	AE Loss: 182.729187, Monifold Loss: 919.173950, ColAE Loss: 1331.696533
# Epoch 333/499	(J=495)
#
# 	AE Loss: 182.605209, Monifold Loss: 918.834900, ColAE Loss: 1331.148804
# Epoch 334/499	(J=495)
#
# 	AE Loss: 182.484146, Monifold Loss: 918.325134, ColAE Loss: 1330.390503
# Epoch 335/499	(J=495)
#
# 	AE Loss: 182.362518, Monifold Loss: 918.020752, ColAE Loss: 1329.888428
# Epoch 336/499	(J=495)
#
# 	AE Loss: 182.240799, Monifold Loss: 917.514587, ColAE Loss: 1329.134033
# Epoch 337/499	(J=495)
#
# 	AE Loss: 182.118668, Monifold Loss: 917.193298, ColAE Loss: 1328.610229
# Epoch 338/499	(J=495)
#
# 	AE Loss: 181.998779, Monifold Loss: 916.750061, ColAE Loss: 1327.936401
# Epoch 339/499	(J=495)
#
# 	AE Loss: 181.879257, Monifold Loss: 916.348877, ColAE Loss: 1327.315308
# Epoch 340/499	(J=495)
#
# 	AE Loss: 181.761154, Monifold Loss: 915.987732, ColAE Loss: 1326.745728
# Epoch 341/499	(J=495)
#
# 	AE Loss: 181.644012, Monifold Loss: 915.516479, ColAE Loss: 1326.039673
# Epoch 342/499	(J=495)
#
# 	AE Loss: 181.526886, Monifold Loss: 915.177429, ColAE Loss: 1325.498657
# Epoch 343/499	(J=495)
#
# 	AE Loss: 181.413193, Monifold Loss: 914.733154, ColAE Loss: 1324.829712
# Epoch 344/499	(J=495)
#
# 	AE Loss: 181.298782, Monifold Loss: 914.336548, ColAE Loss: 1324.219482
# Epoch 345/499	(J=495)
#
# 	AE Loss: 181.184113, Monifold Loss: 913.968506, ColAE Loss: 1323.644775
# Epoch 346/499	(J=495)
#
# 	AE Loss: 181.071030, Monifold Loss: 913.519287, ColAE Loss: 1322.970215
# Epoch 347/499	(J=495)
#
# 	AE Loss: 180.956558, Monifold Loss: 913.165527, ColAE Loss: 1322.413452
# Epoch 348/499	(J=495)
#
# 	AE Loss: 180.845093, Monifold Loss: 912.756348, ColAE Loss: 1321.790527
# Epoch 349/499	(J=495)
#
# 	AE Loss: 180.734543, Monifold Loss: 912.337830, ColAE Loss: 1321.156738
# Epoch 350/499	(J=495)
#
# 	AE Loss: 180.623184, Monifold Loss: 912.001099, ColAE Loss: 1320.624512
# Epoch 351/499	(J=495)
#
# 	AE Loss: 180.512573, Monifold Loss: 911.548401, ColAE Loss: 1319.948120
# Epoch 352/499	(J=495)
#
# 	AE Loss: 180.402954, Monifold Loss: 911.207031, ColAE Loss: 1319.411743
# Epoch 353/499	(J=495)
#
# 	AE Loss: 180.295166, Monifold Loss: 910.802979, ColAE Loss: 1318.798828
# Epoch 354/499	(J=495)
#
# 	AE Loss: 180.188538, Monifold Loss: 910.392944, ColAE Loss: 1318.179688
# Epoch 355/499	(J=495)
#
# 	AE Loss: 180.080444, Monifold Loss: 910.050537, ColAE Loss: 1317.643677
# Epoch 356/499	(J=495)
#
# 	AE Loss: 179.974533, Monifold Loss: 909.615662, ColAE Loss: 1316.994019
# Epoch 357/499	(J=495)
#
# 	AE Loss: 179.867401, Monifold Loss: 909.265503, ColAE Loss: 1316.449341
# Epoch 358/499	(J=495)
#
# 	AE Loss: 179.763733, Monifold Loss: 908.870056, ColAE Loss: 1315.851318
# Epoch 359/499	(J=495)
#
# 	AE Loss: 179.662369, Monifold Loss: 908.467590, ColAE Loss: 1315.246826
# Epoch 360/499	(J=495)
#
# 	AE Loss: 179.560181, Monifold Loss: 908.114441, ColAE Loss: 1314.703247
# Epoch 361/499	(J=495)
#
# 	AE Loss: 179.459076, Monifold Loss: 907.700073, ColAE Loss: 1314.084229
# Epoch 362/499	(J=495)
#
# 	AE Loss: 179.357178, Monifold Loss: 907.335205, ColAE Loss: 1313.526123
# Epoch 363/499	(J=495)
#
# 	AE Loss: 179.256210, Monifold Loss: 906.952698, ColAE Loss: 1312.947144
# Epoch 364/499	(J=495)
#
# 	AE Loss: 179.157303, Monifold Loss: 906.560303, ColAE Loss: 1312.357788
# Epoch 365/499	(J=495)
#
# 	AE Loss: 179.056564, Monifold Loss: 906.199951, ColAE Loss: 1311.806519
# Epoch 366/499	(J=495)
#
# 	AE Loss: 178.959290, Monifold Loss: 905.808899, ColAE Loss: 1311.220459
# Epoch 367/499	(J=495)
#
# 	AE Loss: 178.861664, Monifold Loss: 905.442932, ColAE Loss: 1310.665405
# Epoch 368/499	(J=495)
#
# 	AE Loss: 178.764359, Monifold Loss: 905.071228, ColAE Loss: 1310.103394
# Epoch 369/499	(J=495)
#
# 	AE Loss: 178.668304, Monifold Loss: 904.692749, ColAE Loss: 1309.534302
# Epoch 370/499	(J=495)
#
# 	AE Loss: 178.573013, Monifold Loss: 904.341919, ColAE Loss: 1309.000366
# Epoch 371/499	(J=495)
#
# 	AE Loss: 178.478546, Monifold Loss: 903.956238, ColAE Loss: 1308.423828
# Epoch 372/499	(J=495)
#
# 	AE Loss: 178.383179, Monifold Loss: 903.613403, ColAE Loss: 1307.899902
# Epoch 373/499	(J=495)
#
# 	AE Loss: 178.291000, Monifold Loss: 903.236389, ColAE Loss: 1307.336548
# Epoch 374/499	(J=495)
#
# 	AE Loss: 178.197784, Monifold Loss: 902.881104, ColAE Loss: 1306.799072
# Epoch 375/499	(J=495)
#
# 	AE Loss: 178.106171, Monifold Loss: 902.524536, ColAE Loss: 1306.261841
# Epoch 376/499	(J=495)
#
# 	AE Loss: 178.014999, Monifold Loss: 902.159180, ColAE Loss: 1305.713989
# Epoch 377/499	(J=495)
#
# 	AE Loss: 177.925690, Monifold Loss: 901.816284, ColAE Loss: 1305.196045
# Epoch 378/499	(J=495)
#
# 	AE Loss: 177.837799, Monifold Loss: 901.452332, ColAE Loss: 1304.653198
# Epoch 379/499	(J=495)
#
# 	AE Loss: 177.747589, Monifold Loss: 901.110779, ColAE Loss: 1304.135986
# Epoch 380/499	(J=495)
#
# 	AE Loss: 177.660721, Monifold Loss: 900.753357, ColAE Loss: 1303.602417
# Epoch 381/499	(J=495)
#
# 	AE Loss: 177.573776, Monifold Loss: 900.407288, ColAE Loss: 1303.082886
# Epoch 382/499	(J=495)
#
# 	AE Loss: 177.487274, Monifold Loss: 900.056824, ColAE Loss: 1302.558350
# Epoch 383/499	(J=495)
#
# 	AE Loss: 177.400452, Monifold Loss: 899.709290, ColAE Loss: 1302.037109
# Epoch 384/499	(J=495)
#
# 	AE Loss: 177.315811, Monifold Loss: 899.363037, ColAE Loss: 1301.519653
# Epoch 385/499	(J=495)
#
# 	AE Loss: 177.230652, Monifold Loss: 899.022827, ColAE Loss: 1301.009277
# Epoch 386/499	(J=495)
#
# 	AE Loss: 177.148010, Monifold Loss: 898.673767, ColAE Loss: 1300.490234
# Epoch 387/499	(J=495)
#
# 	AE Loss: 177.066147, Monifold Loss: 898.341614, ColAE Loss: 1299.993164
# Epoch 388/499	(J=495)
#
# 	AE Loss: 176.982727, Monifold Loss: 897.993469, ColAE Loss: 1299.474609
# Epoch 389/499	(J=495)
#
# 	AE Loss: 176.901276, Monifold Loss: 897.659241, ColAE Loss: 1298.975342
# Epoch 390/499	(J=495)
#
# 	AE Loss: 176.821213, Monifold Loss: 897.319336, ColAE Loss: 1298.470337
# Epoch 391/499	(J=495)
#
# 	AE Loss: 176.739960, Monifold Loss: 896.979553, ColAE Loss: 1297.964478
# Epoch 392/499	(J=495)
#
# 	AE Loss: 176.661148, Monifold Loss: 896.647827, ColAE Loss: 1297.470947
# Epoch 393/499	(J=495)
#
# 	AE Loss: 176.583115, Monifold Loss: 896.308716, ColAE Loss: 1296.968994
# Epoch 394/499	(J=495)
#
# 	AE Loss: 176.505417, Monifold Loss: 895.980225, ColAE Loss: 1296.480713
# Epoch 395/499	(J=495)
#
# 	AE Loss: 176.429871, Monifold Loss: 895.645630, ColAE Loss: 1295.986816
# Epoch 396/499	(J=495)
#
# 	AE Loss: 176.352844, Monifold Loss: 895.313171, ColAE Loss: 1295.494385
# Epoch 397/499	(J=495)
#
# 	AE Loss: 176.278244, Monifold Loss: 894.986633, ColAE Loss: 1295.011475
# Epoch 398/499	(J=495)
#
# 	AE Loss: 176.203003, Monifold Loss: 894.652405, ColAE Loss: 1294.518555
# Epoch 399/499	(J=495)
#
# 	AE Loss: 176.130356, Monifold Loss: 894.330078, ColAE Loss: 1294.042969
# Epoch 400/499	(J=495)
#
# 	AE Loss: 176.055847, Monifold Loss: 894.002625, ColAE Loss: 1293.559082
# Epoch 401/499	(J=495)
#
# 	AE Loss: 175.983383, Monifold Loss: 893.677124, ColAE Loss: 1293.079834
# Epoch 402/499	(J=495)
#
# 	AE Loss: 175.910934, Monifold Loss: 893.356812, ColAE Loss: 1292.606934
# Epoch 403/499	(J=495)
#
# 	AE Loss: 175.840271, Monifold Loss: 893.028748, ColAE Loss: 1292.126221
# Epoch 404/499	(J=495)
#
# 	AE Loss: 175.769608, Monifold Loss: 892.714417, ColAE Loss: 1291.662720
# Epoch 405/499	(J=495)
#
# 	AE Loss: 175.700928, Monifold Loss: 892.391602, ColAE Loss: 1291.190430
# Epoch 406/499	(J=495)
#
# 	AE Loss: 175.631348, Monifold Loss: 892.077881, ColAE Loss: 1290.728760
# Epoch 407/499	(J=495)
#
# 	AE Loss: 175.563629, Monifold Loss: 891.765381, ColAE Loss: 1290.270386
# Epoch 408/499	(J=495)
#
# 	AE Loss: 175.495636, Monifold Loss: 891.450684, ColAE Loss: 1289.808960
# Epoch 409/499	(J=495)
#
# 	AE Loss: 175.429565, Monifold Loss: 891.145203, ColAE Loss: 1289.361084
# Epoch 410/499	(J=495)
#
# 	AE Loss: 175.364075, Monifold Loss: 890.831116, ColAE Loss: 1288.903076
# Epoch 411/499	(J=495)
#
# 	AE Loss: 175.298218, Monifold Loss: 890.528564, ColAE Loss: 1288.458862
# Epoch 412/499	(J=495)
#
# 	AE Loss: 175.233490, Monifold Loss: 890.222351, ColAE Loss: 1288.011475
# Epoch 413/499	(J=495)
#
# 	AE Loss: 175.169525, Monifold Loss: 889.921448, ColAE Loss: 1287.571411
# Epoch 414/499	(J=495)
#
# 	AE Loss: 175.106232, Monifold Loss: 889.624329, ColAE Loss: 1287.136597
# Epoch 415/499	(J=495)
#
# 	AE Loss: 175.043869, Monifold Loss: 889.324036, ColAE Loss: 1286.698853
# Epoch 416/499	(J=495)
#
# 	AE Loss: 174.982559, Monifold Loss: 889.032043, ColAE Loss: 1286.272583
# Epoch 417/499	(J=495)
#
# 	AE Loss: 174.921249, Monifold Loss: 888.736206, ColAE Loss: 1285.841553
# Epoch 418/499	(J=495)
#
# 	AE Loss: 174.861496, Monifold Loss: 888.447144, ColAE Loss: 1285.420410
# Epoch 419/499	(J=495)
#
# 	AE Loss: 174.801575, Monifold Loss: 888.157532, ColAE Loss: 1284.998535
# Epoch 420/499	(J=495)
#
# 	AE Loss: 174.743866, Monifold Loss: 887.870789, ColAE Loss: 1284.582397
# Epoch 421/499	(J=495)
#
# 	AE Loss: 174.685989, Monifold Loss: 887.589783, ColAE Loss: 1284.173218
# Epoch 422/499	(J=495)
#
# 	AE Loss: 174.629120, Monifold Loss: 887.307495, ColAE Loss: 1283.763550
# Epoch 423/499	(J=495)
#
# 	AE Loss: 174.571487, Monifold Loss: 887.032288, ColAE Loss: 1283.361938
# Epoch 424/499	(J=495)
#
# 	AE Loss: 174.516098, Monifold Loss: 886.755737, ColAE Loss: 1282.960815
# Epoch 425/499	(J=495)
#
# 	AE Loss: 174.460007, Monifold Loss: 886.483765, ColAE Loss: 1282.564697
# Epoch 426/499	(J=495)
#
# 	AE Loss: 174.405441, Monifold Loss: 886.212830, ColAE Loss: 1282.171387
# Epoch 427/499	(J=495)
#
# 	AE Loss: 174.351883, Monifold Loss: 885.945129, ColAE Loss: 1281.783325
# Epoch 428/499	(J=495)
#
# 	AE Loss: 174.299973, Monifold Loss: 885.682251, ColAE Loss: 1281.402710
# Epoch 429/499	(J=495)
#
# 	AE Loss: 174.248215, Monifold Loss: 885.419617, ColAE Loss: 1281.022705
# Epoch 430/499	(J=495)
#
# 	AE Loss: 174.195709, Monifold Loss: 885.163574, ColAE Loss: 1280.650146
# Epoch 431/499	(J=495)
#
# 	AE Loss: 174.144409, Monifold Loss: 884.907776, ColAE Loss: 1280.279175
# Epoch 432/499	(J=495)
#
# 	AE Loss: 174.094101, Monifold Loss: 884.656799, ColAE Loss: 1279.915161
# Epoch 433/499	(J=495)
#
# 	AE Loss: 174.044220, Monifold Loss: 884.407898, ColAE Loss: 1279.554077
# Epoch 434/499	(J=495)
#
# 	AE Loss: 173.995972, Monifold Loss: 884.160645, ColAE Loss: 1279.196777
# Epoch 435/499	(J=495)
#
# 	AE Loss: 173.948593, Monifold Loss: 883.918274, ColAE Loss: 1278.846436
# Epoch 436/499	(J=495)
#
# 	AE Loss: 173.902161, Monifold Loss: 883.677490, ColAE Loss: 1278.499023
# Epoch 437/499	(J=495)
#
# 	AE Loss: 173.855576, Monifold Loss: 883.441833, ColAE Loss: 1278.157837
# Epoch 438/499	(J=495)
#
# 	AE Loss: 173.810577, Monifold Loss: 883.208618, ColAE Loss: 1277.821289
# Epoch 439/499	(J=495)
#
# 	AE Loss: 173.766953, Monifold Loss: 882.979187, ColAE Loss: 1277.490967
# Epoch 440/499	(J=495)
#
# 	AE Loss: 173.723618, Monifold Loss: 882.754395, ColAE Loss: 1277.166626
# Epoch 441/499	(J=495)
#
# 	AE Loss: 173.680511, Monifold Loss: 882.532288, ColAE Loss: 1276.845947
# Epoch 442/499	(J=495)
#
# 	AE Loss: 173.638077, Monifold Loss: 882.314331, ColAE Loss: 1276.531006
# Epoch 443/499	(J=495)
#
# 	AE Loss: 173.596420, Monifold Loss: 882.099670, ColAE Loss: 1276.221069
# Epoch 444/499	(J=495)
#
# 	AE Loss: 173.555908, Monifold Loss: 881.887695, ColAE Loss: 1275.915527
# Epoch 445/499	(J=495)
#
# 	AE Loss: 173.515549, Monifold Loss: 881.679993, ColAE Loss: 1275.615479
# Epoch 446/499	(J=495)
#
# 	AE Loss: 173.475800, Monifold Loss: 881.476562, ColAE Loss: 1275.321533
# Epoch 447/499	(J=495)
#
# 	AE Loss: 173.437225, Monifold Loss: 881.276672, ColAE Loss: 1275.033081
# Epoch 448/499	(J=495)
#
# 	AE Loss: 173.400223, Monifold Loss: 881.081726, ColAE Loss: 1274.752441
# Epoch 449/499	(J=495)
#
# 	AE Loss: 173.362671, Monifold Loss: 880.889771, ColAE Loss: 1274.474854
# Epoch 450/499	(J=495)
#
# 	AE Loss: 173.326691, Monifold Loss: 880.701965, ColAE Loss: 1274.204102
# Epoch 451/499	(J=495)
#
# 	AE Loss: 173.291306, Monifold Loss: 880.517761, ColAE Loss: 1273.938477
# Epoch 452/499	(J=495)
#
# 	AE Loss: 173.256058, Monifold Loss: 880.337830, ColAE Loss: 1273.678345
# Epoch 453/499	(J=495)
#
# 	AE Loss: 173.221481, Monifold Loss: 880.161499, ColAE Loss: 1273.423340
# Epoch 454/499	(J=495)
#
# 	AE Loss: 173.188431, Monifold Loss: 879.989380, ColAE Loss: 1273.175171
# Epoch 455/499	(J=495)
#
# 	AE Loss: 173.155746, Monifold Loss: 879.821533, ColAE Loss: 1272.932617
# Epoch 456/499	(J=495)
#
# 	AE Loss: 173.123886, Monifold Loss: 879.657837, ColAE Loss: 1272.696167
# Epoch 457/499	(J=495)
#
# 	AE Loss: 173.092819, Monifold Loss: 879.498474, ColAE Loss: 1272.465820
# Epoch 458/499	(J=495)
#
# 	AE Loss: 173.062347, Monifold Loss: 879.343140, ColAE Loss: 1272.241333
# Epoch 459/499	(J=495)
#
# 	AE Loss: 173.032669, Monifold Loss: 879.191895, ColAE Loss: 1272.022583
# Epoch 460/499	(J=495)
#
# 	AE Loss: 173.003708, Monifold Loss: 879.044739, ColAE Loss: 1271.809570
# Epoch 461/499	(J=495)
#
# 	AE Loss: 172.975540, Monifold Loss: 878.902405, ColAE Loss: 1271.603638
# Epoch 462/499	(J=495)
#
# 	AE Loss: 172.948502, Monifold Loss: 878.762878, ColAE Loss: 1271.402100
# Epoch 463/499	(J=495)
#
# 	AE Loss: 172.922134, Monifold Loss: 878.627991, ColAE Loss: 1271.207153
# Epoch 464/499	(J=495)
#
# 	AE Loss: 172.896027, Monifold Loss: 878.496887, ColAE Loss: 1271.017090
# Epoch 465/499	(J=495)
#
# 	AE Loss: 172.871170, Monifold Loss: 878.370361, ColAE Loss: 1270.834106
# Epoch 466/499	(J=495)
#
# 	AE Loss: 172.846832, Monifold Loss: 878.247742, ColAE Loss: 1270.656494
# Epoch 467/499	(J=495)
#
# 	AE Loss: 172.823456, Monifold Loss: 878.128784, ColAE Loss: 1270.484497
# Epoch 468/499	(J=495)
#
# 	AE Loss: 172.799942, Monifold Loss: 878.014221, ColAE Loss: 1270.317749
# Epoch 469/499	(J=495)
#
# 	AE Loss: 172.777695, Monifold Loss: 877.903809, ColAE Loss: 1270.157471
# Epoch 470/499	(J=495)
#
# 	AE Loss: 172.756454, Monifold Loss: 877.797668, ColAE Loss: 1270.003540
# Epoch 471/499	(J=495)
#
# 	AE Loss: 172.735596, Monifold Loss: 877.694641, ColAE Loss: 1269.853882
# Epoch 472/499	(J=495)
#
# 	AE Loss: 172.715393, Monifold Loss: 877.595947, ColAE Loss: 1269.710205
# Epoch 473/499	(J=495)
#
# 	AE Loss: 172.696884, Monifold Loss: 877.501709, ColAE Loss: 1269.574097
# Epoch 474/499	(J=495)
#
# 	AE Loss: 172.678848, Monifold Loss: 877.411133, ColAE Loss: 1269.442749
# Epoch 475/499	(J=495)
#
# 	AE Loss: 172.661270, Monifold Loss: 877.324707, ColAE Loss: 1269.317139
# Epoch 476/499	(J=495)
#
# 	AE Loss: 172.644455, Monifold Loss: 877.242737, ColAE Loss: 1269.197876
# Epoch 477/499	(J=495)
#
# 	AE Loss: 172.628922, Monifold Loss: 877.164551, ColAE Loss: 1269.084595
# Epoch 478/499	(J=495)
#
# 	AE Loss: 172.613647, Monifold Loss: 877.090698, ColAE Loss: 1268.977051
# Epoch 479/499	(J=495)
#
# 	AE Loss: 172.599258, Monifold Loss: 877.020447, ColAE Loss: 1268.874756
# Epoch 480/499	(J=495)
#
# 	AE Loss: 172.585739, Monifold Loss: 876.953674, ColAE Loss: 1268.777832
# Epoch 481/499	(J=495)
#
# 	AE Loss: 172.572845, Monifold Loss: 876.891296, ColAE Loss: 1268.687012
# Epoch 482/499	(J=495)
#
# 	AE Loss: 172.560608, Monifold Loss: 876.832703, ColAE Loss: 1268.601562
# Epoch 483/499	(J=495)
#
# 	AE Loss: 172.549316, Monifold Loss: 876.778442, ColAE Loss: 1268.522339
# Epoch 484/499	(J=495)
#
# 	AE Loss: 172.539444, Monifold Loss: 876.728149, ColAE Loss: 1268.449585
# Epoch 485/499	(J=495)
#
# 	AE Loss: 172.529892, Monifold Loss: 876.681519, ColAE Loss: 1268.381836
# Epoch 486/499	(J=495)
#
# 	AE Loss: 172.521439, Monifold Loss: 876.638672, ColAE Loss: 1268.319824
# Epoch 487/499	(J=495)
#
# 	AE Loss: 172.513199, Monifold Loss: 876.599915, ColAE Loss: 1268.263062
# Epoch 488/499	(J=495)
#
# 	AE Loss: 172.505905, Monifold Loss: 876.565247, ColAE Loss: 1268.212402
# Epoch 489/499	(J=495)
#
# 	AE Loss: 172.499725, Monifold Loss: 876.534119, ColAE Loss: 1268.167358
# Epoch 490/499	(J=495)
#
# 	AE Loss: 172.493988, Monifold Loss: 876.507141, ColAE Loss: 1268.127930
# Epoch 491/499	(J=495)
#
# 	AE Loss: 172.489288, Monifold Loss: 876.484314, ColAE Loss: 1268.094604
# Epoch 492/499	(J=495)
#
# 	AE Loss: 172.485382, Monifold Loss: 876.465027, ColAE Loss: 1268.066650
# Epoch 493/499	(J=495)
#
# 	AE Loss: 172.482437, Monifold Loss: 876.449768, ColAE Loss: 1268.044678
# Epoch 494/499	(J=495)
#
# 	AE Loss: 172.480148, Monifold Loss: 876.438171, ColAE Loss: 1268.027832
# Epoch 495/499	(J=495)
#
# 	AE Loss: 172.478729, Monifold Loss: 876.430603, ColAE Loss: 1268.016968
# Epoch 496/499	(J=495)
#
# 	AE Loss: 172.478027, Monifold Loss: 876.426697, ColAE Loss: 1268.011353
# Epoch 497/499	(J=495)
#
# 	AE Loss: 172.477188, Monifold Loss: 876.422729, ColAE Loss: 1268.005615
# Epoch 498/499	(J=495)
#
# 	AE Loss: 172.476456, Monifold Loss: 876.418884, ColAE Loss: 1268.000000
# Epoch 499/499	(J=495)
#
# 	AE Loss: 172.475571, Monifold Loss: 876.414856, ColAE Loss: 1267.994141
# Running time of ColAE is 51391.77856469154

# %%
# %cd ~/BachelorResearch/ColAE
img_save_path = data_name
# Out:
# /home/zennakamura/BachelorResearch/ColAE

# %%
#with open(os.path.join(img_save_path, 'info_dadaptation.txt'),'a') as f_dadaptation:
    #for i in range(J): 
        #f_dadaptation.write(f'{i}-th Params')
        #f_dadaptation.write(f'{optimizer[i].param_groups}')
        #f_dadaptation.write('\n')

with open(os.path.join(img_save_path, 'info.txt'),'a') as f:
    f.write(f'Number of Epoch (J) = {J}, L={L}, K={K}, eta={eta}\n')
    for i in range(epochs): 
        f.write(f'Epoch {i}: AE Loss: {plot_AE_loss[i]}, Monifold Loss: {plot_monifold_loss[i]}')
        f.write('\n')
    f.write(f'Running time: {time_diff}')

# %%
# Auto-Encoder plot
fig, ax = plt.subplots()

t = np.linspace(0,epochs,epochs)
ax.set_xlabel('Epoch')
ax.set_ylabel('AE loss')
ax.grid()
ax.plot(t, plot_AE_loss)
fig.tight_layout()
plt.savefig(os.path.join(img_save_path, f'AE_loss_dadaptation.pdf'))
plt.show()

# %%
# Monifolod loss plot
fig, ax = plt.subplots()
t = np.linspace(0,epochs,epochs)
ax.set_xlabel('Epoch')
ax.set_ylabel('Monifolod loss')
ax.grid()
ax.plot(t, plot_monifold_loss)
fig.tight_layout()
plt.savefig(os.path.join(img_save_path, f'monifold_loss_dadaptation.pdf'))
plt.show()

# %%
# from IPython.display import display
# from torchviz import make_dot

# g = make_dot(loss, params={'input': input})

# 自動微分monifoldの部分もできているはず...
print(f'y_ik[0]: {mu_y[0].grad}')
print(f'y_ik[0]: {y_ik[0].grad}')
print(f'AE_loss_: {AE_loss_.grad}')
print(f'AE_loss: {AE_loss.grad}')
print(f'monifold_loss_: {monifold_loss_.grad}')
print(f'monifold_loss: {monifold_loss.grad}')
print(f'loss: {loss.grad}')
# Out:
# y_ik[0]: tensor([ 0.0654,  0.1503,  0.0101,  0.0126, -0.0373, -0.0108, -0.0925, -0.0190,
#          0.0604, -0.0170, -0.0679, -0.0324,  0.1047, -0.0779, -0.0381,  0.0704,
#         -0.0004, -0.0503, -0.0482,  0.0230,  0.0262, -0.0915,  0.0365,  0.0555,
#          0.0301, -0.0477,  0.0201,  0.2454,  0.0743, -0.0210], device='cuda:0')
# y_ik[0]: tensor([-0.0654, -0.1503, -0.0101, -0.0126,  0.0373,  0.0108,  0.0925,  0.0190,
#         -0.0604,  0.0170,  0.0679,  0.0324, -0.1047,  0.0779,  0.0381, -0.0704,
#          0.0004,  0.0503,  0.0482, -0.0230, -0.0262,  0.0915, -0.0365, -0.0555,
#         -0.0301,  0.0477, -0.0201, -0.2454, -0.0743,  0.0210], device='cuda:0')
# AE_loss_: 1.0
# AE_loss: 1.0
# monifold_loss_: 1.25
# monifold_loss: 1.25
# loss: 1.0

# %%
i = 0 # i番目のSuperpixel
print(f'imgs: {len(imgs)}')
print(f'imgs[{i}]: {len(imgs[i])}x{len(imgs[i][i])}')
# X の形状を表示
print(f'X.shape（{J}個のベクトル）: {X.shape}')
print(f'X[{i}].shape  : {X[i].shape}')

# Y の形状を表示
print(f'Y.shape（{J}個のベクトル）: {len(Y)}')
i = 0 # i番目のSuperpixel
#print(f'{i}番目のsuperpixelのサンプル数: {N[i]}')
#print(f'{i}番目のsuperpixelの潜在表現: {Y[i]}')
print(f'Y[{i}].shape: {np.array(Y[i]).shape}')
# Out:
# imgs: 180
# imgs[0]: 501x501
# X.shape（495個のベクトル）: (495,)
# X[0].shape  : (235, 180)
# Y.shape（495個のベクトル）: 495
# Y[0].shape: (235, 30)

# %%
i=0
print(f'pixel: {pixel.shape}')
print(f'pixel[{i}]: {pixel[i].shape}')
#print(f'pixel: {pixel[i]}')
# Out:
# pixel: (495,)
# pixel[0]: (235, 2)

# %%
# セグメンテーション毎のベクトル X_i 作成 (J, N_j, B)
class_data_ = [[] for _ in range(J)]

imgs_DR_output_ = [[[[0] for _ in range(height)] for _ in range(width)] for _ in range(L)]
print(f'imgs_DR_output_: {len(imgs_DR_output_)}')
print(f'imgs_DR_output_[{0}]: {len(imgs_DR_output_[0])}x{len(imgs_DR_output_[0][0])}')

for i in range(J):
    #for y in range(height):
        #for x in range(width):
    for j in range(pixel[i].shape[0]):
        y, x = pixel[i][j]
        #print(f'{i}:({y},{x})', end=' ')
        for l in range(L):
            imgs_DR_output_[l][y][x] = Y[i][j][l]

imgs_DR_output = np.array(imgs_DR_output_)
print(f'imgs_DR_output[0]: {imgs_DR_output[0]}')
# Out:
# imgs_DR_output_: 30
# imgs_DR_output_[0]: 501x501
# imgs_DR_output[0]: [[ 0.5663719   0.5655372   0.56624913 ... -0.78258336 -0.7921588
#   -0.62595576]
#  [ 0.6041485   0.577524    0.57422525 ... -0.7077097  -0.7305275
#   -0.14544457]
#  [ 0.6073216   0.6328138   0.6254479  ... -0.30141947 -0.43319485
#   -0.2879635 ]
#  ...
#  [ 3.473607    3.4047709   3.2869694  ...  0.03216779  0.03935543
#    0.13349539]
#  [ 3.439299    3.3459592   3.2953167  ...  0.03056821  0.03126392
#    0.10278237]
#  [ 3.3613496   3.3273497   3.3022585  ...  0.12705767  0.1333302
#    0.13693726]]

# %% [markdown]
# ### 次元削減した画像の表示

# %% [markdown]
# ##### 次元削減画像の保存

# %%
# 次元削減後の画像の値を0~255
max = [[0] for _ in range(L)]
min = [[0] for _ in range(L)]

for l in range(L):
    max[l] = np.max(np.max(imgs_DR_output[l]))
    print(f'max_{l}: {max[l]},', end=' ')
    min[l] = np.min(np.min(imgs_DR_output[l]))
    print(f'min_{l}: {np.min(np.min(min[l]))}, ', end=' /')
print()
# Out:
# max_0: 7.304506301879883, min_0: -9.889896392822266,  /max_1: 8.851704597473145, min_1: -13.247405052185059,  /max_2: 6.588964939117432, min_2: -4.844663143157959,  /max_3: 6.586037635803223, min_3: -19.03640365600586,  /max_4: 8.119046211242676, min_4: -13.730571746826172,  /max_5: 8.725504875183105, min_5: -8.59630298614502,  /max_6: 7.238755226135254, min_6: -9.427005767822266,  /max_7: 13.702866554260254, min_7: -4.299755573272705,  /max_8: 20.662540435791016, min_8: -4.225891590118408,  /max_9: 5.824620723724365, min_9: -9.166303634643555,  /max_10: 10.940298080444336, min_10: -10.89999008178711,  /max_11: 6.564632892608643, min_11: -5.235882759094238,  /max_12: 9.671003341674805, min_12: -16.847566604614258,  /max_13: 14.379294395446777, min_13: -6.372105121612549,  /max_14: 7.636962413787842, min_14: -20.931522369384766,  /max_15: 6.833227157592773, min_15: -15.518462181091309,  /max_16: 7.576181411743164, min_16: -5.9405951499938965,  /max_17: 4.94417142868042, min_17: -11.67592716217041,  /max_18: 13.578742980957031, min_18: -10.919706344604492,  /max_19: 6.961869716644287, min_19: -7.2136759757995605,  /max_20: 9.538330078125, min_20: -12.805594444274902,  /max_21: 14.035735130310059, min_21: -9.088021278381348,  /max_22: 8.886027336120605, min_22: -8.556591987609863,  /max_23: 12.28024673461914, min_23: -7.693376064300537,  /max_24: 6.20387601852417, min_24: -18.447795867919922,  /max_25: 11.180388450622559, min_25: -10.120171546936035,  /max_26: 6.288697719573975, min_26: -7.543416500091553,  /max_27: 13.113775253295898, min_27: -6.751842021942139,  /max_28: 8.712801933288574, min_28: -5.755305290222168,  /max_29: 17.65628433227539, min_29: -6.069182872772217,  /

# %%
imgs_DR_ = [[[[0] for _ in range(height)] for _ in range(width)] for _ in range(L)]
imgs_DR = [[[[0] for _ in range(height)] for _ in range(width)] for _ in range(L)]
max_ = [[0] for _ in range(L)]
min_ = [[0] for _ in range(L)]

for l in range(L):
    imgs_DR_[l] = np.round((imgs_DR_output[l] - min[l])/(max[l]-min[l]) * 255) # (valud-min)x255/(max-min)により0~255の値に変換

    imgs_DR[l] = np.array(imgs_DR_[l], dtype='int32')

    max_[l] = np.max(np.max(imgs_DR_[l]))
    print(f'max_{l}: {np.max(np.max(max_[l]))},', end=' ')
    min_[l] = np.min(np.min(imgs_DR_[l]))
    print(f'min_{l}: {np.min(np.min(min_[l]))},', end=' /')
print()
# Out:
# max_0: 255.0, min_0: 0.0, /max_1: 255.0, min_1: 0.0, /max_2: 255.0, min_2: 0.0, /max_3: 255.0, min_3: 0.0, /max_4: 255.0, min_4: 0.0, /max_5: 255.0, min_5: 0.0, /max_6: 255.0, min_6: 0.0, /max_7: 255.0, min_7: 0.0, /max_8: 255.0, min_8: 0.0, /max_9: 255.0, min_9: 0.0, /max_10: 255.0, min_10: 0.0, /max_11: 255.0, min_11: 0.0, /max_12: 255.0, min_12: 0.0, /max_13: 255.0, min_13: 0.0, /max_14: 255.0, min_14: 0.0, /max_15: 255.0, min_15: 0.0, /max_16: 255.0, min_16: 0.0, /max_17: 255.0, min_17: 0.0, /max_18: 255.0, min_18: 0.0, /max_19: 255.0, min_19: 0.0, /max_20: 255.0, min_20: 0.0, /max_21: 255.0, min_21: 0.0, /max_22: 255.0, min_22: 0.0, /max_23: 255.0, min_23: 0.0, /max_24: 255.0, min_24: 0.0, /max_25: 255.0, min_25: 0.0, /max_26: 255.0, min_26: 0.0, /max_27: 255.0, min_27: 0.0, /max_28: 255.0, min_28: 0.0, /max_29: 255.0, min_29: 0.0, /

# %%
print(imgs_DR_output[0])
print(imgs_DR_[0])
#print(min[0])
# Out:
# [[ 0.5663719   0.5655372   0.56624913 ... -0.78258336 -0.7921588
#   -0.62595576]
#  [ 0.6041485   0.577524    0.57422525 ... -0.7077097  -0.7305275
#   -0.14544457]
#  [ 0.6073216   0.6328138   0.6254479  ... -0.30141947 -0.43319485
#   -0.2879635 ]
#  ...
#  [ 3.473607    3.4047709   3.2869694  ...  0.03216779  0.03935543
#    0.13349539]
#  [ 3.439299    3.3459592   3.2953167  ...  0.03056821  0.03126392
#    0.10278237]
#  [ 3.3613496   3.3273497   3.3022585  ...  0.12705767  0.1333302
#    0.13693726]]
# [[155. 155. 155. ... 135. 135. 137.]
#  [156. 155. 155. ... 136. 136. 145.]
#  [156. 156. 156. ... 142. 140. 142.]
#  ...
#  [198. 197. 195. ... 147. 147. 149.]
#  [198. 196. 196. ... 147. 147. 148.]
#  [197. 196. 196. ... 149. 149. 149.]]

# %%
#%cd /content/drive/MyDrive

# %%
print(imgs_DR[0])
# Out:
# [[155 155 155 ... 135 135 137]
#  [156 155 155 ... 136 136 145]
#  [156 156 156 ... 142 140 142]
#  ...
#  [198 197 195 ... 147 147 149]
#  [198 196 196 ... 147 147 148]
#  [197 196 196 ... 149 149 149]]

# %%
# %cd ~/BachelorResearch/ColAE
img_save_path = data_name

if not os.path.exists(img_save_path):
    print(f'{img_save_path} is not exists')
    os.makedirs(img_save_path, exist_ok=True)
# Out:
# /home/zennakamura/BachelorResearch/ColAE
# /home/zennakamura/anaconda3/envs/torch/lib/python3.11/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /home/zennakamura/anaconda3/envs/torch/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from PIL import Image

if not os.path.exists(img_save_path):
    print('not exsts')
    os.makedirs(img_save_path, exist_ok=True)

for l in range(L):
    #image_array = np.array(imgs_DR_[l], dtype='int32')
    image = Image.fromarray(imgs_DR[l])
    #img_save_path = f'~/BachelorResearch/ColAE/Schrodinger/DR_img_{l}.tif'
    if os.path.exists(os.path.join(img_save_path, f'DR_img_{l}.tif')):
        print(f'{l},', end=' ')
        image.save(os.path.join(img_save_path, f'DR_img_{l}.tif'))
    else:
        with open(os.path.join(img_save_path, f'DR_img_{l}.tif'), 'x') as f:
            image.save(os.path.join(img_save_path, f'DR_img_{l}.tif'))

# %%
#l = 0
#img_save_path = f'~/BachelorResearch/ColAE/Schrodinger/DR_img_{l}.tif'
#if os.path.exists(img_save_path):
    #print('Yes')
#data_ = cv2.imread(img_save_path, cv2.IMREAD_GRAYSCALE)

#print(data_[0])

# %%
#data_ = data_.astype('float32')/255.
#print(data_)

# %%
#plt.imshow(data_, cmap='gray')

# %%
print(imgs_DR_[0])
# Out:
# [[155. 155. 155. ... 135. 135. 137.]
#  [156. 155. 155. ... 136. 136. 145.]
#  [156. 156. 156. ... 142. 140. 142.]
#  ...
#  [198. 197. 195. ... 147. 147. 149.]
#  [198. 196. 196. ... 147. 147. 148.]
#  [197. 196. 196. ... 149. 149. 149.]]

# %%
plt.imshow(imgs_DR_[0], cmap='gray')

# %%
plt.imshow(imgs_DR_output[0], cmap='gray')

# %%
plt.imshow(imgs_DR_output[1], cmap='gray')

# %%
plt.imshow(imgs_DR_output[2], cmap='gray')

# %%
plt.imshow(imgs_DR_output[3], cmap='gray')

# %%
plt.imshow(imgs_DR_output[4], cmap='gray')

# %%
plt.imshow(imgs_DR_output[5], cmap='gray')

# %%
plt.imshow(imgs_DR_output[6], cmap='gray')

# %%
plt.imshow(imgs_DR_output[7], cmap='gray')

# %% [markdown]
# ## Segmentaion
#
# 潜在表現（コンパクト表現）をSVMに入力し、カテゴリを決定する
